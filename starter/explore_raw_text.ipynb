# %% [markdown]
# # Obtaining and Exploring a Real-World Corpus

# %% [markdown]
# In industry, you almost never start with a perfectly curated list of documents.
# You start by:
#
# - locating an existing corpus
#
# - understanding its scope and structure
#
# - checking what it contains and what it does not
#
# - inspecting it before deciding how to preprocess it
#
# https://stateoftheunion.onetwothree.net/
#
# https://www.kaggle.com/datasets/nltkdata/state-union-corpus

# %% [markdown]
# ## Loading a Real Corpus (State of the Union)
#
# NLTK includes a built-in corpus of all U.S. State of the Union addresses spanning more than two centuries.

# %%
# Import libraries
import nltk
from nltk.corpus import state_union
# Download required NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import state_union
state_union.fileids()
# Out:
# ['1945-Truman.txt',
#  '1946-Truman.txt',
#  '1947-Truman.txt',
#  '1948-Truman.txt',
#  '1949-Truman.txt',
#  '1950-Truman.txt',
#  '1951-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1954-Eisenhower.txt',
#  '1955-Eisenhower.txt',
#  '1956-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1958-Eisenhower.txt',
#  '1959-Eisenhower.txt',
#  '1960-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1962-Kennedy.txt',
#  '1963-Johnson.txt',
#  '1963-Kennedy.txt',
#  '1964-Johnson.txt',
#  '1965-Johnson-1.txt',
#  '1965-Johnson-2.txt',
#  '1966-Johnson.txt',
#  '1967-Johnson.txt',
#  '1968-Johnson.txt',
#  '1969-Johnson.txt',
#  '1970-Nixon.txt',
#  '1971-Nixon.txt',
#  '1972-Nixon.txt',
#  '1973-Nixon.txt',
#  '1974-Nixon.txt',
#  '1975-Ford.txt',
#  '1976-Ford.txt',
#  '1977-Ford.txt',
#  '1978-Carter.txt',
#  '1979-Carter.txt',
#  '1980-Carter.txt',
#  '1981-Reagan.txt',
#  '1982-Reagan.txt',
#  '1983-Reagan.txt',
#  '1984-Reagan.txt',
#  '1985-Reagan.txt',
#  '1986-Reagan.txt',
# ...

# %%
len(state_union.fileids())
# Out:
# 65

# %% [markdown]
# - Each file corresponds to one speech, typically named by year and president.
# - Each file is a document.
# - The full collection is a corpus.

# %% [markdown]
# ## Understanding Corpus Scope

# %%
#Corpus Size
print(f"Corpus Word Count: {len(state_union.words())}")
print(f"Corpus Sentence Count: {len(state_union.sents())}")
print(f"Corpus Documents Count: {len(state_union.fileids())}")
# Out:
# Corpus Word Count: 399822
# Corpus Sentence Count: 17930
# Corpus Documents Count: 65

# %%
#Corpus Language and Representation
print(f"Corpus Words are Exclusively in English: \n{state_union.words()[:25]}\n")
print(f"Corpus Spans 80 Years Showing Historical Progression: \n{state_union.fileids()[:25]}\n")
print(f"Document from Corpus Showing that Corpus Contians Spoken Transcripts: \n{state_union.sents('1945-Truman.txt')[:5]}\n")
print("Since the corpus contains US Presidential speeches, we know that the genre of the corpus is political.")
# Out:
# Corpus Words are Exclusively in English:
# ['PRESIDENT', 'HARRY', 'S', '.', 'TRUMAN', "'", 'S', 'ADDRESS', 'BEFORE', 'A', 'JOINT', 'SESSION', 'OF', 'THE', 'CONGRESS', 'April', '16', ',', '1945', 'Mr', '.', 'Speaker', ',', 'Mr', '.']
#
# Corpus Spans 80 Years Showing Historical Progression:
# ['1945-Truman.txt', '1946-Truman.txt', '1947-Truman.txt', '1948-Truman.txt', '1949-Truman.txt', '1950-Truman.txt', '1951-Truman.txt', '1953-Eisenhower.txt', '1954-Eisenhower.txt', '1955-Eisenhower.txt', '1956-Eisenhower.txt', '1957-Eisenhower.txt', '1958-Eisenhower.txt', '1959-Eisenhower.txt', '1960-Eisenhower.txt', '1961-Kennedy.txt', '1962-Kennedy.txt', '1963-Johnson.txt', '1963-Kennedy.txt', '1964-Johnson.txt', '1965-Johnson-1.txt', '1965-Johnson-2.txt', '1966-Johnson.txt', '1967-Johnson.txt', '1968-Johnson.txt']
#
# Document from Corpus Showing that Corpus Contians Spoken Transcripts:
# ...

# %% [markdown]
# - This corpus spans over 200 years of political language.
# - This makes it suitable for temporal, historical, and policy trend analysis.

# %% [markdown]
# # Inspecting Raw Text (No Processing Yet)
# Before tokenization, normalization, or cleaning, we inspect the raw text.

# %%
truman_1945_raw = state_union.raw('1945-Truman.txt')
truman_1945_raw
# Out:
# 'PRESIDENT HARRY S. TRUMAN\'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.\nOnly yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.\nYet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.\nIn His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.\nNo man could possibly fill the tremendous void left by the passing of that noble soul. No words can ease the aching hearts of untold millions of every race, creed and color. The world knows it has lost a heroic champion of justice and freedom.\nTragic fate h
# ...

# %% [markdown]
# - Is this clean or messy text?
#
# - Do you see formatting artifacts?
#
# - Would you need domain-specific cleaning?

# %%
# Inspect the first 500 words of the 1945 Truman address
truman_1945_words = state_union.words('1945-Truman.txt')[:500]
truman_1945_text = ' '.join(truman_1945_words)  # Join words into a single string
truman_1945_text
# Out:
# "PRESIDENT HARRY S . TRUMAN ' S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS April 16 , 1945 Mr . Speaker , Mr . President , Members of the Congress : It is with a heavy heart that I stand before you , my friends and colleagues , in the Congress of the United States . Only yesterday , we laid to rest the mortal remains of our beloved President , Franklin Delano Roosevelt . At a time like this , words are inadequate . The most eloquent tribute would be a reverent silence . Yet , in this decisive hour , when world events are moving so rapidly , our silence might be misunderstood and might give comfort to our enemies . In His infinite wisdom , Almighty God has seen fit to take from us a great man who loved , and was beloved by , all humanity . No man could possibly fill the tremendous void left by the passing of that noble soul . No words can ease the aching hearts of untold millions of every race , creed and color . The world knows it has lost a heroic champion of justice and freedom
# ...

# %%
truman_1945_words
# Out:
# ['PRESIDENT',
#  'HARRY',
#  'S',
#  '.',
#  'TRUMAN',
#  "'",
#  'S',
#  'ADDRESS',
#  'BEFORE',
#  'A',
#  'JOINT',
#  'SESSION',
#  'OF',
#  'THE',
#  'CONGRESS',
#  'April',
#  '16',
#  ',',
#  '1945',
#  'Mr',
#  '.',
#  'Speaker',
#  ',',
#  'Mr',
#  '.',
#  'President',
#  ',',
#  'Members',
#  'of',
#  'the',
#  'Congress',
#  ':',
#  'It',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'I',
#  'stand',
#  'before',
#  'you',
#  ',',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  ',',
#  'in',
#  'the',
#  'Congress',
#  'of',
#  'the',
#  'United',
#  'States',
#  '.',
#  'Only',
#  'yesterday',
#  ',',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'President',
#  ',',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  '.',
#  'At',
#  'a',
#  'time',
#  'like',
#  'this',
#  ',',
#  'words',
#  'are',
#  'inadequate',
#  '.',
#  'The',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
# ...

# %% [markdown]
# # Words vs Sentences vs Characters?
# At this stage, we only explore structure.

# %%
#Number of words
import nltk
from nltk.tokenize import word_tokenize

truman_1945_words_tokens = word_tokenize(truman_1945_raw)

print(f"Number of Word Tokens: {len(truman_1945_words_tokens)}")

print(f'First 10 Tokens: {truman_1945_words_tokens[:10]}')
# Out:
# Number of Word Tokens: 2108
# First 10 Tokens: ['PRESIDENT', 'HARRY', 'S.', 'TRUMAN', "'S", 'ADDRESS', 'BEFORE', 'A', 'JOINT', 'SESSION']

# %%
#Number of Sentences
from nltk.tokenize import sent_tokenize

truman_1945_sents_tokens = sent_tokenize(truman_1945_raw)

print(f"Number of Word Tokens: {len(truman_1945_sents_tokens)}")

print(f'First 10 Tokens: {truman_1945_sents_tokens[:10]}')
# Out:
# Number of Word Tokens: 114
# ...

# %%
#Number of Characters
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'.')
truman_1945_chars_tokens = tokenizer.tokenize(truman_1945_raw)

print(f"Number of Word Tokens: {len(truman_1945_chars_tokens)}")

print(f'First 10 Tokens: {truman_1945_chars_tokens[:10]}')
# Out:
# Number of Word Tokens: 10914
# First 10 Tokens: ['P', 'R', 'E', 'S', 'I', 'D', 'E', 'N', 'T', ' ']

# %% [markdown]
# # Quick Corpus-Wide Exploration

# %%
from nltk.tokenize import word_tokenize, sent_tokenize, RegexpTokenizer
from collections import Counter

corpus_raw = state_union.raw(state_union.fileids())

#Word Tokenization
corpus_words_tokens = Counter(word_tokenize(corpus_raw))
corpus_words_top = corpus_words_tokens.most_common(10)

#Character Tokenization
tokenizer = RegexpTokenizer(r'.')
corpus_chars_tokens = Counter(tokenizer.tokenize(corpus_raw))
corpus_chars_top = corpus_chars_tokens.most_common(10)

#Sentence Length Frequency
corpus_sents_tokens = sent_tokenize(corpus_raw)
corpus_sents_len = []
for sent in corpus_sents_tokens:
    corpus_sents_len.append(len(sent))

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

#Word Count Histogram
labels, values = zip(*corpus_words_top)
plt.bar(labels, values)
plt.title("Top 10 Corpus Words")
plt.show()

#Character Count Histogram
labels, values = zip(*corpus_chars_top)
plt.bar(labels, values)
plt.title("Top 10 Corpus Characters")
plt.show()

#Sentence Length Histogram
plt.hist(corpus_sents_len)
plt.title("Corpus Sentence Character Length Histogram")
plt.show()

# %% [markdown]
# In the next section, we will treat each State of the Union address as a document and the full collection as a corpus. We will begin designing preprocessing pipelines using both NLTK and spaCy, and we will compare how each library handles the same steps.
