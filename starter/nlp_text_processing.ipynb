# %% [markdown]
# # AIG 230 – Week 2 Lab
# ## From Raw Text to Corpus: Tokenization, Normalization, and Vocabulary
#
# Industry Context: Exploring the State of the Union Corpus

# %%
# !pip install nltk spacy
# Out:
# Requirement already satisfied: nltk in c:\users\sowar\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: spacy in c:\users\sowar\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: click in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (0.21.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (2.12.4)
# Requirement already satisfied: jinja2 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sowar\anaconda3\lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sowar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sowar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\sowar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sowar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sowar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sowar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sowar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sowar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\sowar\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sowar\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\sowar\anaconda3\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\sowar\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\sowar\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\sowar\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sowar\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)

# %% [markdown]
# ## Learning Objectives
# - Understand raw text, documents, and corpora
# - Explore a real-world corpus
# - Compare NLTK and spaCy preprocessing pipelines
# - Perform tokenization, normalization, and vocabulary analysis

# %%
import nltk
import spacy
import string
from collections import Counter

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("state_union")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# True

# %%
# Load spaCy English model
# Run once if needed:
# !python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 2.1 MB/s eta 0:00:06
#      --- ------------------------------------ 1.0/12.8 MB 2.4 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.6/12.8 MB 2.3 MB/s eta 0:00:05
#      ------ --------------------------------- 2.1/12.8 MB 2.4 MB/s eta 0:00:05
#      ------- -------------------------------- 2.4/12.8 MB 2.3 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/12.8 MB 2.1 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.4/12.8 MB 2.1 MB/s eta 0:00:05
#      ----------- ---------------------------- 3.7/12.8 MB 2.1 MB/s eta 0:00:05
#      ------------- -------------------------- 4.2/12.8 MB 2.1 MB/s eta 0:00:05
#      -------------- ------------------------- 4.7/12.8 MB 2.1 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.2 MB/s eta 0:00:04
#      ------------------ --------------------- 5.8/12.8 MB 2.2 MB/s eta 0:00:04
#      ------------------- -------------------- 6.3/12.8 MB 2.2 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 2.3 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.3/12.8 MB 2.3 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 2.3 MB/s eta 0:00:03
#      --------------------------- ------------ 8.7/12.8 MB 2.4 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 2.4 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 2.4 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 2.4 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.5 MB/s  0:00:05
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# Breaking it down:
#
# ```
# spacy.load() - loads a pre-trained language model
# ```
#
# "en_core_web_sm" - the small English model that includes:
#
# - Tokenizer - splits text into words/sentences
# - Part-of-speech tagger - identifies noun, verb, adjective, etc.
# - Dependency parser - analyzes grammatical relationships
# - Named entity recognizer - identifies people, places, organizations
# - Word vectors - semantic meaning of words
#
# nlp = - stores the loaded model in a variable so you can use it to process text

# %% [markdown]
# ## Part 1 – Obtaining the Corpus

# %%
from nltk.corpus import state_union
state_union.fileids()[:10]
# Out:
# ['1945-Truman.txt',
#  '1946-Truman.txt',
#  '1947-Truman.txt',
#  '1948-Truman.txt',
#  '1949-Truman.txt',
#  '1950-Truman.txt',
#  '1951-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1954-Eisenhower.txt',
#  '1955-Eisenhower.txt']

# %% [markdown]
# Each file is a document. The collection is the corpus.

# %%
len(state_union.fileids())
# Out:
# 65

# %% [markdown]
# ## Part 2 – Inspect Raw Text

# %%
sample_file = state_union.fileids()[0]
raw_text = state_union.raw(sample_file)
raw_text[:1000]
# Out:
# "PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.\nOnly yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.\nYet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.\nIn His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.\nNo man could possibly fill the tremendous void left by the passing of that noble soul. No words can ease the aching hearts of untold millions of every race, creed and color. The world knows it has lost a heroic champion of justice and freedom.\nTragic fate has thrust upon"

# %% [markdown]
# ## Part 3 – Word Tokenization

# %% [markdown]
# 📌 Tokenization splits text into meaningful units (tokens).
# There is no universal standard, but conventions vary by task and language.

# %%
from nltk.tokenize import word_tokenize
tokens_nltk = word_tokenize(raw_text)
tokens_nltk
# Out:
# ['PRESIDENT',
#  'HARRY',
#  'S.',
#  'TRUMAN',
#  "'S",
#  'ADDRESS',
#  'BEFORE',
#  'A',
#  'JOINT',
#  'SESSION',
#  'OF',
#  'THE',
#  'CONGRESS',
#  'April',
#  '16',
#  ',',
#  '1945',
#  'Mr.',
#  'Speaker',
#  ',',
#  'Mr.',
#  'President',
#  ',',
#  'Members',
#  'of',
#  'the',
#  'Congress',
#  ':',
#  'It',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'I',
#  'stand',
#  'before',
#  'you',
#  ',',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  ',',
#  'in',
#  'the',
#  'Congress',
#  'of',
#  'the',
#  'United',
#  'States',
#  '.',
#  'Only',
#  'yesterday',
#  ',',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'President',
#  ',',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  '.',
#  'At',
#  'a',
#  'time',
#  'like',
#  'this',
#  ',',
#  'words',
#  'are',
#  'inadequate',
#  '.',
#  'The',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  '.',
#  'Yet',
#  ',',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  ',',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  ',',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  '.',
#  'In',
#  'His',
#  'infinite',
#  'wisdom',
#  ',',
#  'Almighty',
#  'God',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  ',',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  ',',
#  'all',
#  'humanity',
#  '.',
#  'No',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  '.',
#  'No',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  ',',
#  'creed',
#  'and',
#  'color',
#  '.',
#  'The',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  '.',
#  'Tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  '.',
#  'We',
#  'must',
#  'carry',
#  'on.Our',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  '.',
#  'He',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  '.',
#  'That',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  '.',
#  'That',
#  'is',
#  'what',
#  'America',
#  'will',
#  'do',
#  '.',
#  'So',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  ',',
#  'and',
#  'for',
#  'which',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  'lived',
#  'and',
#  'died',
#  ',',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  '.',
#  'Today',
#  ',',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'America',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  '.',
#  'Such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  ',',
#  'courage',
#  'and',
#  'tolerance',
#  '.',
#  'It',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  '.',
#  'With',
#  'great',
#  'humility',
#  'I',
#  'call',
#  'upon',
#  'all',
#  'Americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'Franklin',
#  'Roosevelt',
#  '.',
#  'I',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'Americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'I',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  '.',
#  'That',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'I',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  '.',
#  'So',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  ',',
#  'both',
#  'Germany',
#  'and',
#  'Japan',
#  'can',
#  'be',
#  'certain',
#  ',',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  ',',
#  'that',
#  'America',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  '!',
#  'We',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  '.',
#  'Having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  ',',
#  'America',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  '!',
#  'To',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  '.',
#  'Our',
#  'demand',
#  'has',
#  'been',
#  ',',
#  'and',
#  'it',
#  'remains-Unconditional',
#  'Surrender',
#  '!',
#  'We',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  '.',
#  'The',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'peace-and',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'responsibility-must',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  '.',
#  'We',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  '.',
#  'We',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  '.',
#  'But',
#  'the',
#  'laws',
#  'of',
#  'Go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  '.',
#  'Nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  '.',
#  'Lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  '-',
#  'however',
#  'distant',
#  '.',
#  'In',
#  'this',
#  'shrinking',
#  'world',
#  ',',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  '.',
#  'Real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  '.',
#  'Here',
#  'in',
#  'America',
#  ',',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  '.',
#  'In',
#  'our',
#  'time',
#  ',',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  '.',
#  'Let',
#  'me',
#  'assure',
#  'the',
#  'forward-looking',
#  'people',
#  'of',
#  'America',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  '.',
#  'In',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  ',',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  '.',
#  'However',
#  ',',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  ',',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  '.',
#  'On',
#  'the',
#  'battlefields',
#  ',',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  '-',
#  'and',
#  'won',
#  '!',
#  'At',
#  'home',
#  ',',
#  'Americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  '!',
#  'We',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'American',
#  'way',
#  'of',
#  'life',
#  '.',
#  'At',
#  'this',
#  'moment',
#  ',',
#  'America',
#  ',',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'Allies',
#  ',',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  '.',
#  'With',
#  'characteristic',
#  'energy',
#  ',',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  '.',
#  'Gradually',
#  ',',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  '.',
#  'All',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  '.',
#  'Every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  '.',
#  'The',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'Hitler',
#  "'s",
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  '.',
#  'Tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  '.',
#  'The',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'United',
#  'Nations',
#  "'",
#  'war',
#  'has',
#  'been',
#  'determined',
#  '-',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'Commander',
#  'in',
#  'Chief',
#  '.',
#  'We',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'Admiral',
#  'Leahy',
#  ',',
#  'General',
#  'Marshall',
#  ',',
#  'A',
#  'dmiral',
#  'King',
#  ',',
#  'General',
#  'Arnold',
#  ',',
#  'General',
#  'Eisenhower',
#  ',',
#  'Admiral',
#  'Nimitz',
#  'and',
#  'General',
#  'MacArthur',
#  '.',
#  'I',
#  'want',
#  'the',
#  'entire',
#  'world',
#  'to',
#  'know',
#  'that',
#  'this',
#  'direction',
#  'must',
#  'and',
#  'will',
#  'remain-unchanged',
#  'and',
#  'unhampered',
#  '!',
#  'Our',
#  'debt',
#  'to',
#  'the',
#  'heroic',
#  'men',
#  'and',
#  'valiant',
#  'women',
#  ...]

# %%
doc = nlp(raw_text)
doc
# Out:
# PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS
#
# April 16, 1945
#
# Mr. Speaker, Mr. President, Members of the Congress:
# It is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.
# Only yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.
# Yet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.
# In His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.
# No man could possibly fill the tremendous void left by the passing of that noble soul. No words can ease the aching hearts of untold millions of every race, creed and color. The world knows it has lost a heroic champion of justice and freedom.
# Tragic fate has thrust upon us grave responsibilities. We must carry on.Our departed leader never looked backward. He looked forward and moved forward. That is what he would want us to do. That is what America will do.
# So much blood has already been shed for the ideals which we cherish, and for which Franklin Delano Roosevelt lived and died, that we dare not permit even a momentary pause in the hard fight for victory.
# Today, the entire world is looking to America for enlightened leadership to peace and progress. Such a leadership requires vision, courage and tolerance. It can be provided only by a united nation deeply devoted to the highest ideals.
# With great humility I call upon all Americans to help me keep our nation united in defense of those ideals which have been so eloquently proclaimed by Franklin Roosevelt.
# I want in turn to assure my fellow Americans and all of those who love peace and liberty throughout the world that I will support and defend those ideals with all my strength and all my heart. That is my duty and I shall not shirk it.
# So that there can be no possible misunderstanding, both Germany and Japan can be certain, beyond any shadow of a doubt, that America will continue the fight for freedom until no vestige of resistance remains!
# We are deeply conscious of the fact that much hard fighting is still ahead of us.
# Having to pay such a heavy price to make complete victory certain, America will never become a party to any plan for partial victory!
# To settle for merely another temporary respite would surely jeopardize the future security of all the world.
# Our demand has been, and it remains-Unconditional Surrender! We will not traffic with the breakers of the peace on the terms of the peace.
# The responsibility for making of the peace-and it is a very grave responsibility-must rest with the defenders of the peace. We are not unconscious of the dictates of humanity. We do not wish to see unnecessary or unjustified suffering. But the laws of Go d and of man have been violated and the guilty must not go unpunished. Nothing shall shake our determination to punish the war criminals even though we must pursue them to the ends of the earth.
# Lasting peace can never be secured if we permit our dangerous opponents to plot future wars with impunity at any mountain retreat - however distant.
# In this shrinking world, it is futile to seek safety behind geographical barriers. Real security will be found only in law and in justice.
# Here in America, we have labored long and hard to achieve a social order worthy of our great heritage. In our time, tremendous progress has been made toward a really democratic way of life. Let me assure the forward-looking people of America that there w ill be no relaxation in our efforts to improve the lot of the common people.
# In the difficult days ahead, unquestionably we shall face problems of staggering proportions. However, with the faith of our fathers in our hearts, we do not fear the future.
# On the battlefields, we have frequently faced overwhelming odds - and won! At home, Americans will not be less resolute! We shall never cease our struggle to preserve and maintain our American way of life.
# At this moment, America, along with her brave Allies, is paying again a heavy price for the defense of our freedom. With characteristic energy, we are assisting in the liberation of entire nations. Gradually, the shackles of slavery are being broken by t he forces of freedom.
# All of us are praying for a speedy victory. Every day peace is delayed costs a terrible toll.
# The armies of liberation today are bringing to an end Hitler's ghastly threat to dominate the world. Tokyo rocks under the weight of our bombs.
# The grand strategy of the United Nations' war has been determined - due in no small measure to the vision of our departed Commander in Chief. We are now carrying out our part of that strategy under the able direction of Admiral Leahy, General Marshall, A dmiral King, General Arnold, General Eisenhower, Admiral Nimitz and General MacArthur.
# I want the entire world to know that this direction must and will remain-unchanged and unhampered!
# Our debt to the heroic men and valiant women in the service of our country can never be repaid. They have earned our undying gratitude. America will never forget their sacrifices. Because of these sacrifices, the dawn of justice and freedom throughout th e world slowly casts its gleam across the horizon.
# Our forefathers came to our rugged shores in search of religious tolerance, political freedom and economic opportunity. For those fundamental rights, they risked their lives. We well know today that such rights can be preserved only by constant vigilance , the eternal price of liberty!
# Within an hour after I took the oath of office, I announced that the San Francisco Conference would proceed. We will face the problems of peace with the same courage that we have faced and mastered the problems of war.
# In the memory of those who have made the supreme sacrifice-in the memory of our fallen President-we shall not fail!
# It is not enough to yearn for peace. We must work, and if necessary, fight for it. The task of creating a sound international organization is complicated and difficult. Yet, without such organization, the rights of man on earth cannot be protected. Machi nery for the just settlement of international differences must be found. Without such machinery, the entire world will have to remain an armed camp. The world will be doomed to deadly conflict, devoid of hope for real peace.
# Fortunately, people have retained hope for a durable peace. Thoughtful people have always had faith that ultimately justice must triumph. Past experience surely indicates that, without justice, an enduring peace becomes impossible.
# In bitter despair, some people have come to believe that wars are inevitable. With tragic fatalism, they insist that wars have always been, of necessity, and of necessity wars always will be. To such defeatism, men and women of good will must not and can not yield. The outlook for humanity is not so hopeless.
# During the dark hours of this horrible war, entire nations were kept going by something intangible-hope! When warned that abject submission offered the only salvation against overwhelming power, hope showed the way to victory.
# Hope has become the secret weapon of the forces of liberation!
# Aggressors could not dominate the human mind. As long as hope remains, the spirit of man will never be crushed.
# But hope alone was not and is not sufficient to avert war. We must not only have hope but we must have faith enough to work with other peace-loving nations to maintain the peace. Hope was not enough to beat back the aggressors as long as the peace-loving nations were unwilling to come to each other's defense. The aggressors were beaten back only when the peace-loving nations united to defend themselves.
# If wars in the future are to be prevented the nations must be united in their determination to keep the peace under law.
# Nothing is more essential to the future peace of the world than continued cooperation of the nations which had to muster the force necessary to defeat the conspiracy of the Axis powers to dominate the world.
# While these great states have a special responsibility to enforce the peace, their responsibility is based upon the obligations resting upon all states, large and small, not to use force in international relations except in the defense of law. The respon sibility of the great states is to serve and not to dominate the world.
# To build a foundation of enduring peace we must not only work in harmony with our friends abroad, but we must have the united support of our own people.
# Even the most experienced pilot cannot bring a ship safely into harbor, unless he has the full cooperation of the crew. For the benefit of all, every individual must do his duty.
# I appeal to every American, regardless of party, race, creed, or color, to support our efforts to build a strong and lasting United Nations Organization.
# You, the Members of the Congress, surely know how I feel. Only with your help can I hope to complete one of the greatest tasks ever assigned to a public servant. With Divine guidance, and your help, we will find the new passage to a far better world, a kindly and friendly world, with just and lasting peace.
# With confidence, I am depending upon all of you.
# To destroy greedy tyrants with dreams of world domination, we cannot continue in successive generations to sacrifice our finest youth.
# In the name of human decency and civilization, a more rational method of deciding national differences must and will be found!
# America must assist suffering humanity back along the path of peaceful progress. This will require time and tolerance. We shall need also an abiding faith in the people, the kind of faith and courage which Franklin Delano Roosevelt always had!
# Today, America has become one of the most powerful forces for good on earth. We must keep it so. We have achieved a world leadership which does not depend solely upon our military and naval might.
# We have learned to fight with other nations in common defense of our freedom. We must now learn to live with other nations for our mutual good. We must learn to trade more with other nations so that there may be-for our mutual advantage-increased product ion, increased employment and better standards of living throughout the world.
# May we Americans all live up to our glorious heritage.
# In that way, America may well lead the world to peace and prosperity.
# At this moment, I have in my heart a prayer. As I have assumed my heavy duties, I humbly pray Almighty God, in the words of King Solomon:
# "Give therefore thy servant an understanding heart to judge thy people, that I may discern between good and bad; for who is able to judge this thy so great a people?"
# I ask only to be a good and faithful servant of my Lord and my people.

# %% [markdown]
# ## Part 4 – Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize
sentences_nltk = sent_tokenize(raw_text)
sentences_nltk
# Out:
# ["PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.",
#  'Only yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt.',
#  'At a time like this, words are inadequate.',
#  'The most eloquent tribute would be a reverent silence.',
#  'Yet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.',
#  'In His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.',
#  'No man could possibly fill the tremendous void left by the passing of that noble soul.',
#  'No words can ease the aching hearts of untold millions of every race, creed and color.',
#  'The world knows it has lost a heroic champion of justice and freedom.',
#  'Tragic fate has thrust upon us grave responsibilities.',
#  'We must carry on.Our departed leader never looked backward.',
#  'He looked forward and moved forward.',
#  'That is what he would want us to do.',
#  'That is what America will do.',
#  'So much blood has already been shed for the ideals which we cherish, and for which Franklin Delano Roosevelt lived and died, that we dare not permit even a momentary pause in the hard fight for victory.',
#  'Today, the entire world is looking to America for enlightened leadership to peace and progress.',
#  'Such a leadership requires vision, courage and tolerance.',
#  'It can be provided only by a united nation deeply devoted to the highest ideals.',
#  'With great humility I call upon all Americans to help me keep our nation united in defense of those ideals which have been so eloquently proclaimed by Franklin Roosevelt.',
#  'I want in turn to assure my fellow Americans and all of those who love peace and liberty throughout the world that I will support and defend those ideals with all my strength and all my heart.',
#  'That is my duty and I shall not shirk it.',
#  'So that there can be no possible misunderstanding, both Germany and Japan can be certain, beyond any shadow of a doubt, that America will continue the fight for freedom until no vestige of resistance remains!',
#  'We are deeply conscious of the fact that much hard fighting is still ahead of us.',
#  'Having to pay such a heavy price to make complete victory certain, America will never become a party to any plan for partial victory!',
#  'To settle for merely another temporary respite would surely jeopardize the future security of all the world.',
#  'Our demand has been, and it remains-Unconditional Surrender!',
#  'We will not traffic with the breakers of the peace on the terms of the peace.',
#  'The responsibility for making of the peace-and it is a very grave responsibility-must rest with the defenders of the peace.',
#  'We are not unconscious of the dictates of humanity.',
#  'We do not wish to see unnecessary or unjustified suffering.',
#  'But the laws of Go d and of man have been violated and the guilty must not go unpunished.',
#  'Nothing shall shake our determination to punish the war criminals even though we must pursue them to the ends of the earth.',
#  'Lasting peace can never be secured if we permit our dangerous opponents to plot future wars with impunity at any mountain retreat - however distant.',
#  'In this shrinking world, it is futile to seek safety behind geographical barriers.',
#  'Real security will be found only in law and in justice.',
#  'Here in America, we have labored long and hard to achieve a social order worthy of our great heritage.',
#  'In our time, tremendous progress has been made toward a really democratic way of life.',
#  'Let me assure the forward-looking people of America that there w ill be no relaxation in our efforts to improve the lot of the common people.',
#  'In the difficult days ahead, unquestionably we shall face problems of staggering proportions.',
#  'However, with the faith of our fathers in our hearts, we do not fear the future.',
#  'On the battlefields, we have frequently faced overwhelming odds - and won!',
#  'At home, Americans will not be less resolute!',
#  'We shall never cease our struggle to preserve and maintain our American way of life.',
#  'At this moment, America, along with her brave Allies, is paying again a heavy price for the defense of our freedom.',
#  'With characteristic energy, we are assisting in the liberation of entire nations.',
#  'Gradually, the shackles of slavery are being broken by t he forces of freedom.',
#  'All of us are praying for a speedy victory.',
#  'Every day peace is delayed costs a terrible toll.',
#  "The armies of liberation today are bringing to an end Hitler's ghastly threat to dominate the world.",
#  'Tokyo rocks under the weight of our bombs.',
#  "The grand strategy of the United Nations' war has been determined - due in no small measure to the vision of our departed Commander in Chief.",
#  'We are now carrying out our part of that strategy under the able direction of Admiral Leahy, General Marshall, A dmiral King, General Arnold, General Eisenhower, Admiral Nimitz and General MacArthur.',
#  'I want the entire world to know that this direction must and will remain-unchanged and unhampered!',
#  'Our debt to the heroic men and valiant women in the service of our country can never be repaid.',
#  'They have earned our undying gratitude.',
#  'America will never forget their sacrifices.',
#  'Because of these sacrifices, the dawn of justice and freedom throughout th e world slowly casts its gleam across the horizon.',
#  'Our forefathers came to our rugged shores in search of religious tolerance, political freedom and economic opportunity.',
#  'For those fundamental rights, they risked their lives.',
#  'We well know today that such rights can be preserved only by constant vigilance , the eternal price of liberty!',
#  'Within an hour after I took the oath of office, I announced that the San Francisco Conference would proceed.',
#  'We will face the problems of peace with the same courage that we have faced and mastered the problems of war.',
#  'In the memory of those who have made the supreme sacrifice-in the memory of our fallen President-we shall not fail!',
#  'It is not enough to yearn for peace.',
#  'We must work, and if necessary, fight for it.',
#  'The task of creating a sound international organization is complicated and difficult.',
#  'Yet, without such organization, the rights of man on earth cannot be protected.',
#  'Machi nery for the just settlement of international differences must be found.',
#  'Without such machinery, the entire world will have to remain an armed camp.',
#  'The world will be doomed to deadly conflict, devoid of hope for real peace.',
#  'Fortunately, people have retained hope for a durable peace.',
#  'Thoughtful people have always had faith that ultimately justice must triumph.',
#  'Past experience surely indicates that, without justice, an enduring peace becomes impossible.',
#  'In bitter despair, some people have come to believe that wars are inevitable.',
#  'With tragic fatalism, they insist that wars have always been, of necessity, and of necessity wars always will be.',
#  'To such defeatism, men and women of good will must not and can not yield.',
#  'The outlook for humanity is not so hopeless.',
#  'During the dark hours of this horrible war, entire nations were kept going by something intangible-hope!',
#  'When warned that abject submission offered the only salvation against overwhelming power, hope showed the way to victory.',
#  'Hope has become the secret weapon of the forces of liberation!',
#  'Aggressors could not dominate the human mind.',
#  'As long as hope remains, the spirit of man will never be crushed.',
#  'But hope alone was not and is not sufficient to avert war.',
#  'We must not only have hope but we must have faith enough to work with other peace-loving nations to maintain the peace.',
#  "Hope was not enough to beat back the aggressors as long as the peace-loving nations were unwilling to come to each other's defense.",
#  'The aggressors were beaten back only when the peace-loving nations united to defend themselves.',
#  'If wars in the future are to be prevented the nations must be united in their determination to keep the peace under law.',
#  'Nothing is more essential to the future peace of the world than continued cooperation of the nations which had to muster the force necessary to defeat the conspiracy of the Axis powers to dominate the world.',
#  'While these great states have a special responsibility to enforce the peace, their responsibility is based upon the obligations resting upon all states, large and small, not to use force in international relations except in the defense of law.',
#  'The respon sibility of the great states is to serve and not to dominate the world.',
#  'To build a foundation of enduring peace we must not only work in harmony with our friends abroad, but we must have the united support of our own people.',
#  'Even the most experienced pilot cannot bring a ship safely into harbor, unless he has the full cooperation of the crew.',
#  'For the benefit of all, every individual must do his duty.',
#  'I appeal to every American, regardless of party, race, creed, or color, to support our efforts to build a strong and lasting United Nations Organization.',
#  'You, the Members of the Congress, surely know how I feel.',
#  'Only with your help can I hope to complete one of the greatest tasks ever assigned to a public servant.',
#  'With Divine guidance, and your help, we will find the new passage to a far better world, a kindly and friendly world, with just and lasting peace.',
#  'With confidence, I am depending upon all of you.',
#  'To destroy greedy tyrants with dreams of world domination, we cannot continue in successive generations to sacrifice our finest youth.',
#  'In the name of human decency and civilization, a more rational method of deciding national differences must and will be found!',
#  'America must assist suffering humanity back along the path of peaceful progress.',
#  'This will require time and tolerance.',
#  'We shall need also an abiding faith in the people, the kind of faith and courage which Franklin Delano Roosevelt always had!',
#  'Today, America has become one of the most powerful forces for good on earth.',
#  'We must keep it so.',
#  'We have achieved a world leadership which does not depend solely upon our military and naval might.',
#  'We have learned to fight with other nations in common defense of our freedom.',
#  'We must now learn to live with other nations for our mutual good.',
#  'We must learn to trade more with other nations so that there may be-for our mutual advantage-increased product ion, increased employment and better standards of living throughout the world.',
#  'May we Americans all live up to our glorious heritage.',
#  'In that way, America may well lead the world to peace and prosperity.',
#  'At this moment, I have in my heart a prayer.',
#  'As I have assumed my heavy duties, I humbly pray Almighty God, in the words of King Solomon:\n"Give therefore thy servant an understanding heart to judge thy people, that I may discern between good and bad; for who is able to judge this thy so great a people?"',
#  'I ask only to be a good and faithful servant of my Lord and my people.']

# %%
sentences_spacy =list(doc.sents)
sentences_spacy
# Out:
# [PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS
#
#  April 16, 1945
#
#  Mr. Speaker, Mr. President, Members of the Congress:,
#  It is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.,
#  Only yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt.,
#  At a time like this, words are inadequate.,
#  The most eloquent tribute would be a reverent silence.,
#  Yet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.,
#  In His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.,
#  No man could possibly fill the tremendous void left by the passing of that noble soul.,
#  No words can ease the aching hearts of untold millions of every race, creed and color.,
#  The world knows it has lost a heroic champion of justice and freedom.,
#  Tragic fate has thrust upon us grave responsibilities.,
#  We must carry on.,
#  Our departed leader never looked backward.,
#  He looked forward and moved forward.,
#  That is what he would want us to do.,
#  That is what America will do.,
#  So much blood has already been shed for the ideals which we cherish, and for which Franklin Delano Roosevelt lived and died, that we dare not permit even a momentary pause in the hard fight for victory.,
#  Today, the entire world is looking to America for enlightened leadership to peace and progress.,
#  Such a leadership requires vision, courage and tolerance.,
#  It can be provided only by a united nation deeply devoted to the highest ideals.,
#  With great humility I call upon all Americans to help me keep our nation united in defense of those ideals which have been so eloquently proclaimed by Franklin Roosevelt.,
#  I want in turn to assure my fellow Americans and all of those who love peace and liberty throughout the world that I will support and defend those ideals with all my strength and all my heart.,
#  That is my duty and I shall not shirk it.,
#  So that there can be no possible misunderstanding, both Germany and Japan can be certain, beyond any shadow of a doubt, that America will continue the fight for freedom until no vestige of resistance remains!,
#  We are deeply conscious of the fact that much hard fighting is still ahead of us.,
#  Having to pay such a heavy price to make complete victory certain, America will never become a party to any plan for partial victory!,
#  To settle for merely another temporary respite would surely jeopardize the future security of all the world.,
#  Our demand has been, and it remains-Unconditional Surrender!,
#  We will not traffic with the breakers of the peace on the terms of the peace.,
#  The responsibility for making of the peace-and it is a very grave responsibility-must rest with the defenders of the peace.,
#  We are not unconscious of the dictates of humanity.,
#  We do not wish to see unnecessary or unjustified suffering.,
#  But the laws of Go d and of man have been violated and the guilty must not go unpunished.,
#  Nothing shall shake our determination to punish the war criminals even though we must pursue them to the ends of the earth.,
#  Lasting peace can never be secured if we permit our dangerous opponents to plot future wars with impunity at any mountain retreat - however distant.,
#  In this shrinking world, it is futile to seek safety behind geographical barriers.,
#  Real security will be found only in law and in justice.,
#  Here in America, we have labored long and hard to achieve a social order worthy of our great heritage.,
#  In our time, tremendous progress has been made toward a really democratic way of life.,
#  Let me assure the forward-looking people of America that there w ill be no relaxation in our efforts to improve the lot of the common people.,
#  In the difficult days ahead, unquestionably we shall face problems of staggering proportions.,
#  However, with the faith of our fathers in our hearts, we do not fear the future.,
#  On the battlefields, we have frequently faced overwhelming odds - and won!,
#  At home, Americans will not be less resolute!,
#  We shall never cease our struggle to preserve and maintain our American way of life.,
#  At this moment, America, along with her brave Allies, is paying again a heavy price for the defense of our freedom.,
#  With characteristic energy, we are assisting in the liberation of entire nations.,
#  Gradually, the shackles of slavery are being broken by t he forces of freedom.,
#  All of us are praying for a speedy victory.,
#  Every day peace is delayed costs a terrible toll.,
#  The armies of liberation today are bringing to an end Hitler's ghastly threat to dominate the world.,
#  Tokyo rocks under the weight of our bombs.,
#  The grand strategy of the United Nations' war has been determined - due in no small measure to the vision of our departed Commander in Chief.,
#  We are now carrying out our part of that strategy under the able direction of Admiral Leahy, General Marshall, A dmiral King, General Arnold, General Eisenhower, Admiral Nimitz and General MacArthur.,
#  I want the entire world to know that this direction must and will remain-unchanged and unhampered!,
#  Our debt to the heroic men and valiant women in the service of our country can never be repaid.,
#  They have earned our undying gratitude.,
#  America will never forget their sacrifices.,
#  Because of these sacrifices, the dawn of justice and freedom throughout th e world slowly casts its gleam across the horizon.,
#  Our forefathers came to our rugged shores in search of religious tolerance, political freedom and economic opportunity.,
#  For those fundamental rights, they risked their lives.,
#  We well know today that such rights can be preserved only by constant vigilance , the eternal price of liberty!,
#  Within an hour after I took the oath of office, I announced that the San Francisco Conference would proceed.,
#  We will face the problems of peace with the same courage that we have faced and mastered the problems of war.,
#  In the memory of those who have made the supreme sacrifice-in the memory of our fallen President-we shall not fail!,
#  It is not enough to yearn for peace.,
#  We must work, and if necessary, fight for it.,
#  The task of creating a sound international organization is complicated and difficult.,
#  Yet, without such organization, the rights of man on earth cannot be protected.,
#  Machi nery for the just settlement of international differences must be found.,
#  Without such machinery, the entire world will have to remain an armed camp.,
#  The world will be doomed to deadly conflict, devoid of hope for real peace.,
#  Fortunately, people have retained hope for a durable peace.,
#  Thoughtful people have always had faith that ultimately justice must triumph.,
#  Past experience surely indicates that, without justice, an enduring peace becomes impossible.,
#  In bitter despair, some people have come to believe that wars are inevitable.,
#  With tragic fatalism, they insist that wars have always been, of necessity, and of necessity wars always will be.,
#  To such defeatism, men and women of good will must not and can not yield.,
#  The outlook for humanity is not so hopeless.,
#  During the dark hours of this horrible war, entire nations were kept going by something intangible-hope!,
#  When warned that abject submission offered the only salvation against overwhelming power, hope showed the way to victory.,
#  Hope has become the secret weapon of the forces of liberation!,
#  Aggressors could not dominate the human mind.,
#  As long as hope remains, the spirit of man will never be crushed.,
#  But hope alone was not and is not sufficient to avert war.,
#  We must not only have hope but we must have faith enough to work with other peace-loving nations to maintain the peace.,
#  Hope was not enough to beat back the aggressors as long as the peace-loving nations were unwilling to come to each other's defense.,
#  The aggressors were beaten back only when the peace-loving nations united to defend themselves.,
#  If wars in the future are to be prevented the nations must be united in their determination to keep the peace under law.,
#  Nothing is more essential to the future peace of the world than continued cooperation of the nations which had to muster the force necessary to defeat the conspiracy of the Axis powers to dominate the world.,
#  While these great states have a special responsibility to enforce the peace, their responsibility is based upon the obligations resting upon all states, large and small, not to use force in international relations except in the defense of law.,
#  The respon sibility of the great states is to serve and not to dominate the world.,
#  To build a foundation of enduring peace we must not only work in harmony with our friends abroad, but we must have the united support of our own people.,
#  Even the most experienced pilot cannot bring a ship safely into harbor, unless he has the full cooperation of the crew.,
#  For the benefit of all, every individual must do his duty.,
#  I appeal to every American, regardless of party, race, creed, or color, to support our efforts to build a strong and lasting United Nations Organization.,
#  You, the Members of the Congress, surely know how I feel.,
#  Only with your help can I hope to complete one of the greatest tasks ever assigned to a public servant.,
#  With Divine guidance, and your help, we will find the new passage to a far better world, a kindly and friendly world, with just and lasting peace.,
#  With confidence, I am depending upon all of you.,
#  To destroy greedy tyrants with dreams of world domination, we cannot continue in successive generations to sacrifice our finest youth.,
#  In the name of human decency and civilization, a more rational method of deciding national differences must and will be found!,
#  America must assist suffering humanity back along the path of peaceful progress.,
#  This will require time and tolerance.,
#  We shall need also an abiding faith in the people, the kind of faith and courage which Franklin Delano Roosevelt always had!,
#  Today, America has become one of the most powerful forces for good on earth.,
#  We must keep it so.,
#  We have achieved a world leadership which does not depend solely upon our military and naval might.,
#  We have learned to fight with other nations in common defense of our freedom.,
#  We must now learn to live with other nations for our mutual good.,
#  We must learn to trade more with other nations so that there may be-for our mutual advantage-increased product ion, increased employment and better standards of living throughout the world.,
#  May we Americans all live up to our glorious heritage.,
#  In that way, America may well lead the world to peace and prosperity.,
#  At this moment, I have in my heart a prayer.,
#  As I have assumed my heavy duties, I humbly pray Almighty God, in the words of King Solomon:
#  "Give therefore thy servant an understanding heart to judge thy people, that I may discern between good and bad; for who is able to judge this thy so great a people?,
#  "
#  I ask only to be a good and faithful servant of my Lord and my people.]

# %% [markdown]
# ## Part 5 – Normalization
# Normalization makes text more consistent.

# %%
normalized_nltk = [t.lower() for t in tokens_nltk if t.isalpha()]
normalized_nltk
# Out:
# ['president',
#  'harry',
#  'truman',
#  'address',
#  'before',
#  'a',
#  'joint',
#  'session',
#  'of',
#  'the',
#  'congress',
#  'april',
#  'speaker',
#  'president',
#  'members',
#  'of',
#  'the',
#  'congress',
#  'it',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'i',
#  'stand',
#  'before',
#  'you',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  'in',
#  'the',
#  'congress',
#  'of',
#  'the',
#  'united',
#  'states',
#  'only',
#  'yesterday',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'president',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'at',
#  'a',
#  'time',
#  'like',
#  'this',
#  'words',
#  'are',
#  'inadequate',
#  'the',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  'yet',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  'in',
#  'his',
#  'infinite',
#  'wisdom',
#  'almighty',
#  'god',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  'all',
#  'humanity',
#  'no',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  'no',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  'creed',
#  'and',
#  'color',
#  'the',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  'we',
#  'must',
#  'carry',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'he',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  'that',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  'that',
#  'is',
#  'what',
#  'america',
#  'will',
#  'do',
#  'so',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  'and',
#  'for',
#  'which',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'lived',
#  'and',
#  'died',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  'today',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'america',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  'such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'and',
#  'tolerance',
#  'it',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  'with',
#  'great',
#  'humility',
#  'i',
#  'call',
#  'upon',
#  'all',
#  'americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'franklin',
#  'roosevelt',
#  'i',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'i',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  'that',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'i',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  'so',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  'both',
#  'germany',
#  'and',
#  'japan',
#  'can',
#  'be',
#  'certain',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  'that',
#  'america',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  'we',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  'having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'america',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  'to',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  'our',
#  'demand',
#  'has',
#  'been',
#  'and',
#  'it',
#  'surrender',
#  'we',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  'the',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  'we',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  'we',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  'but',
#  'the',
#  'laws',
#  'of',
#  'go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  'nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  'lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'in',
#  'this',
#  'shrinking',
#  'world',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  'real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  'here',
#  'in',
#  'america',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  'in',
#  'our',
#  'time',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  'let',
#  'me',
#  'assure',
#  'the',
#  'people',
#  'of',
#  'america',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  'in',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  'however',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  'on',
#  'the',
#  'battlefields',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'and',
#  'won',
#  'at',
#  'home',
#  'americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  'we',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'american',
#  'way',
#  'of',
#  'life',
#  'at',
#  'this',
#  'moment',
#  'america',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'allies',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  'with',
#  'characteristic',
#  'energy',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  'gradually',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  'all',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  'every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  'the',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'hitler',
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  'tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  'the',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'united',
#  'nations',
#  'war',
#  'has',
#  'been',
#  'determined',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'commander',
#  'in',
#  'chief',
#  'we',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'admiral',
#  'leahy',
#  'general',
#  'marshall',
#  'a',
#  'dmiral',
#  'king',
#  'general',
#  'arnold',
#  'general',
#  'eisenhower',
#  'admiral',
#  'nimitz',
#  'and',
#  'general',
#  'macarthur',
#  'i',
#  'want',
#  'the',
#  'entire',
#  'world',
#  'to',
#  'know',
#  'that',
#  'this',
#  'direction',
#  'must',
#  'and',
#  'will',
#  'and',
#  'unhampered',
#  'our',
#  'debt',
#  'to',
#  'the',
#  'heroic',
#  'men',
#  'and',
#  'valiant',
#  'women',
#  'in',
#  'the',
#  'service',
#  'of',
#  'our',
#  'country',
#  'can',
#  'never',
#  'be',
#  'repaid',
#  'they',
#  'have',
#  'earned',
#  'our',
#  'undying',
#  'gratitude',
#  'america',
#  'will',
#  'never',
#  'forget',
#  'their',
#  'sacrifices',
#  'because',
#  'of',
#  'these',
#  'sacrifices',
#  'the',
#  'dawn',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'casts',
#  'its',
#  'gleam',
#  'across',
#  'the',
#  'horizon',
#  'our',
#  'forefathers',
#  'came',
#  'to',
#  'our',
#  'rugged',
#  'shores',
#  'in',
#  'search',
#  'of',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'and',
#  'economic',
#  'opportunity',
#  'for',
#  'those',
#  'fundamental',
#  'rights',
#  'they',
#  'risked',
#  'their',
#  'lives',
#  'we',
#  'well',
#  'know',
#  'today',
#  'that',
#  'such',
#  'rights',
#  'can',
#  'be',
#  'preserved',
#  'only',
#  'by',
#  'constant',
#  'vigilance',
#  'the',
#  'eternal',
#  'price',
#  'of',
#  'liberty',
#  'within',
#  'an',
#  'hour',
#  'after',
#  'i',
#  'took',
#  'the',
#  'oath',
#  'of',
#  'office',
#  'i',
#  'announced',
#  'that',
#  'the',
#  'san',
#  'francisco',
#  'conference',
#  'would',
#  'proceed',
#  'we',
#  'will',
#  'face',
#  'the',
#  'problems',
#  'of',
#  'peace',
#  ...]

# %%
def normalize(tokens):
    return [
        token.lower()
        for token in tokens
        if token.isalpha()
    ]

# %%
normalize(tokens_nltk)
# Out:
# ['president',
#  'harry',
#  'truman',
#  'address',
#  'before',
#  'a',
#  'joint',
#  'session',
#  'of',
#  'the',
#  'congress',
#  'april',
#  'speaker',
#  'president',
#  'members',
#  'of',
#  'the',
#  'congress',
#  'it',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'i',
#  'stand',
#  'before',
#  'you',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  'in',
#  'the',
#  'congress',
#  'of',
#  'the',
#  'united',
#  'states',
#  'only',
#  'yesterday',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'president',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'at',
#  'a',
#  'time',
#  'like',
#  'this',
#  'words',
#  'are',
#  'inadequate',
#  'the',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  'yet',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  'in',
#  'his',
#  'infinite',
#  'wisdom',
#  'almighty',
#  'god',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  'all',
#  'humanity',
#  'no',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  'no',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  'creed',
#  'and',
#  'color',
#  'the',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  'we',
#  'must',
#  'carry',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'he',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  'that',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  'that',
#  'is',
#  'what',
#  'america',
#  'will',
#  'do',
#  'so',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  'and',
#  'for',
#  'which',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'lived',
#  'and',
#  'died',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  'today',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'america',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  'such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'and',
#  'tolerance',
#  'it',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  'with',
#  'great',
#  'humility',
#  'i',
#  'call',
#  'upon',
#  'all',
#  'americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'franklin',
#  'roosevelt',
#  'i',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'i',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  'that',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'i',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  'so',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  'both',
#  'germany',
#  'and',
#  'japan',
#  'can',
#  'be',
#  'certain',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  'that',
#  'america',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  'we',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  'having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'america',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  'to',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  'our',
#  'demand',
#  'has',
#  'been',
#  'and',
#  'it',
#  'surrender',
#  'we',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  'the',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  'we',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  'we',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  'but',
#  'the',
#  'laws',
#  'of',
#  'go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  'nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  'lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'in',
#  'this',
#  'shrinking',
#  'world',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  'real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  'here',
#  'in',
#  'america',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  'in',
#  'our',
#  'time',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  'let',
#  'me',
#  'assure',
#  'the',
#  'people',
#  'of',
#  'america',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  'in',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  'however',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  'on',
#  'the',
#  'battlefields',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'and',
#  'won',
#  'at',
#  'home',
#  'americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  'we',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'american',
#  'way',
#  'of',
#  'life',
#  'at',
#  'this',
#  'moment',
#  'america',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'allies',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  'with',
#  'characteristic',
#  'energy',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  'gradually',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  'all',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  'every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  'the',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'hitler',
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  'tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  'the',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'united',
#  'nations',
#  'war',
#  'has',
#  'been',
#  'determined',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'commander',
#  'in',
#  'chief',
#  'we',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'admiral',
#  'leahy',
#  'general',
#  'marshall',
#  'a',
#  'dmiral',
#  'king',
#  'general',
#  'arnold',
#  'general',
#  'eisenhower',
#  'admiral',
#  'nimitz',
#  'and',
#  'general',
#  'macarthur',
#  'i',
#  'want',
#  'the',
#  'entire',
#  'world',
#  'to',
#  'know',
#  'that',
#  'this',
#  'direction',
#  'must',
#  'and',
#  'will',
#  'and',
#  'unhampered',
#  'our',
#  'debt',
#  'to',
#  'the',
#  'heroic',
#  'men',
#  'and',
#  'valiant',
#  'women',
#  'in',
#  'the',
#  'service',
#  'of',
#  'our',
#  'country',
#  'can',
#  'never',
#  'be',
#  'repaid',
#  'they',
#  'have',
#  'earned',
#  'our',
#  'undying',
#  'gratitude',
#  'america',
#  'will',
#  'never',
#  'forget',
#  'their',
#  'sacrifices',
#  'because',
#  'of',
#  'these',
#  'sacrifices',
#  'the',
#  'dawn',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'casts',
#  'its',
#  'gleam',
#  'across',
#  'the',
#  'horizon',
#  'our',
#  'forefathers',
#  'came',
#  'to',
#  'our',
#  'rugged',
#  'shores',
#  'in',
#  'search',
#  'of',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'and',
#  'economic',
#  'opportunity',
#  'for',
#  'those',
#  'fundamental',
#  'rights',
#  'they',
#  'risked',
#  'their',
#  'lives',
#  'we',
#  'well',
#  'know',
#  'today',
#  'that',
#  'such',
#  'rights',
#  'can',
#  'be',
#  'preserved',
#  'only',
#  'by',
#  'constant',
#  'vigilance',
#  'the',
#  'eternal',
#  'price',
#  'of',
#  'liberty',
#  'within',
#  'an',
#  'hour',
#  'after',
#  'i',
#  'took',
#  'the',
#  'oath',
#  'of',
#  'office',
#  'i',
#  'announced',
#  'that',
#  'the',
#  'san',
#  'francisco',
#  'conference',
#  'would',
#  'proceed',
#  'we',
#  'will',
#  'face',
#  'the',
#  'problems',
#  'of',
#  'peace',
#  ...]

# %% [markdown]
# ## Part 6 – Stop Word Removal

# %% [markdown]
# 📌 Stop words are common words that often add little semantic meaning.

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))
filtered_nltk = [t for t in normalized_nltk if t not in stop_words]
filtered_nltk
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['president',
#  'harry',
#  'truman',
#  'address',
#  'joint',
#  'session',
#  'congress',
#  'april',
#  'speaker',
#  'president',
#  'members',
#  'congress',
#  'heavy',
#  'heart',
#  'stand',
#  'friends',
#  'colleagues',
#  'congress',
#  'united',
#  'states',
#  'yesterday',
#  'laid',
#  'rest',
#  'mortal',
#  'remains',
#  'beloved',
#  'president',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'time',
#  'like',
#  'words',
#  'inadequate',
#  'eloquent',
#  'tribute',
#  'would',
#  'reverent',
#  'silence',
#  'yet',
#  'decisive',
#  'hour',
#  'world',
#  'events',
#  'moving',
#  'rapidly',
#  'silence',
#  'might',
#  'misunderstood',
#  'might',
#  'give',
#  'comfort',
#  'enemies',
#  'infinite',
#  'wisdom',
#  'almighty',
#  'god',
#  'seen',
#  'fit',
#  'take',
#  'us',
#  'great',
#  'man',
#  'loved',
#  'beloved',
#  'humanity',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'tremendous',
#  'void',
#  'left',
#  'passing',
#  'noble',
#  'soul',
#  'words',
#  'ease',
#  'aching',
#  'hearts',
#  'untold',
#  'millions',
#  'every',
#  'race',
#  'creed',
#  'color',
#  'world',
#  'knows',
#  'lost',
#  'heroic',
#  'champion',
#  'justice',
#  'freedom',
#  'tragic',
#  'fate',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  'must',
#  'carry',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'looked',
#  'forward',
#  'moved',
#  'forward',
#  'would',
#  'want',
#  'us',
#  'america',
#  'much',
#  'blood',
#  'already',
#  'shed',
#  'ideals',
#  'cherish',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'lived',
#  'died',
#  'dare',
#  'permit',
#  'even',
#  'momentary',
#  'pause',
#  'hard',
#  'fight',
#  'victory',
#  'today',
#  'entire',
#  'world',
#  'looking',
#  'america',
#  'enlightened',
#  'leadership',
#  'peace',
#  'progress',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'tolerance',
#  'provided',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'highest',
#  'ideals',
#  'great',
#  'humility',
#  'call',
#  'upon',
#  'americans',
#  'help',
#  'keep',
#  'nation',
#  'united',
#  'defense',
#  'ideals',
#  'eloquently',
#  'proclaimed',
#  'franklin',
#  'roosevelt',
#  'want',
#  'turn',
#  'assure',
#  'fellow',
#  'americans',
#  'love',
#  'peace',
#  'liberty',
#  'throughout',
#  'world',
#  'support',
#  'defend',
#  'ideals',
#  'strength',
#  'heart',
#  'duty',
#  'shall',
#  'shirk',
#  'possible',
#  'misunderstanding',
#  'germany',
#  'japan',
#  'certain',
#  'beyond',
#  'shadow',
#  'doubt',
#  'america',
#  'continue',
#  'fight',
#  'freedom',
#  'vestige',
#  'resistance',
#  'remains',
#  'deeply',
#  'conscious',
#  'fact',
#  'much',
#  'hard',
#  'fighting',
#  'still',
#  'ahead',
#  'us',
#  'pay',
#  'heavy',
#  'price',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'america',
#  'never',
#  'become',
#  'party',
#  'plan',
#  'partial',
#  'victory',
#  'settle',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'future',
#  'security',
#  'world',
#  'demand',
#  'surrender',
#  'traffic',
#  'breakers',
#  'peace',
#  'terms',
#  'peace',
#  'responsibility',
#  'making',
#  'grave',
#  'rest',
#  'defenders',
#  'peace',
#  'unconscious',
#  'dictates',
#  'humanity',
#  'wish',
#  'see',
#  'unnecessary',
#  'unjustified',
#  'suffering',
#  'laws',
#  'go',
#  'man',
#  'violated',
#  'guilty',
#  'must',
#  'go',
#  'unpunished',
#  'nothing',
#  'shall',
#  'shake',
#  'determination',
#  'punish',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'must',
#  'pursue',
#  'ends',
#  'earth',
#  'lasting',
#  'peace',
#  'never',
#  'secured',
#  'permit',
#  'dangerous',
#  'opponents',
#  'plot',
#  'future',
#  'wars',
#  'impunity',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'shrinking',
#  'world',
#  'futile',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  'real',
#  'security',
#  'found',
#  'law',
#  'justice',
#  'america',
#  'labored',
#  'long',
#  'hard',
#  'achieve',
#  'social',
#  'order',
#  'worthy',
#  'great',
#  'heritage',
#  'time',
#  'tremendous',
#  'progress',
#  'made',
#  'toward',
#  'really',
#  'democratic',
#  'way',
#  'life',
#  'let',
#  'assure',
#  'people',
#  'america',
#  'w',
#  'ill',
#  'relaxation',
#  'efforts',
#  'improve',
#  'lot',
#  'common',
#  'people',
#  'difficult',
#  'days',
#  'ahead',
#  'unquestionably',
#  'shall',
#  'face',
#  'problems',
#  'staggering',
#  'proportions',
#  'however',
#  'faith',
#  'fathers',
#  'hearts',
#  'fear',
#  'future',
#  'battlefields',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'home',
#  'americans',
#  'less',
#  'resolute',
#  'shall',
#  'never',
#  'cease',
#  'struggle',
#  'preserve',
#  'maintain',
#  'american',
#  'way',
#  'life',
#  'moment',
#  'america',
#  'along',
#  'brave',
#  'allies',
#  'paying',
#  'heavy',
#  'price',
#  'defense',
#  'freedom',
#  'characteristic',
#  'energy',
#  'assisting',
#  'liberation',
#  'entire',
#  'nations',
#  'gradually',
#  'shackles',
#  'slavery',
#  'broken',
#  'forces',
#  'freedom',
#  'us',
#  'praying',
#  'speedy',
#  'victory',
#  'every',
#  'day',
#  'peace',
#  'delayed',
#  'costs',
#  'terrible',
#  'toll',
#  'armies',
#  'liberation',
#  'today',
#  'bringing',
#  'end',
#  'hitler',
#  'ghastly',
#  'threat',
#  'dominate',
#  'world',
#  'tokyo',
#  'rocks',
#  'weight',
#  'bombs',
#  'grand',
#  'strategy',
#  'united',
#  'nations',
#  'war',
#  'determined',
#  'due',
#  'small',
#  'measure',
#  'vision',
#  'departed',
#  'commander',
#  'chief',
#  'carrying',
#  'part',
#  'strategy',
#  'able',
#  'direction',
#  'admiral',
#  'leahy',
#  'general',
#  'marshall',
#  'dmiral',
#  'king',
#  'general',
#  'arnold',
#  'general',
#  'eisenhower',
#  'admiral',
#  'nimitz',
#  'general',
#  'macarthur',
#  'want',
#  'entire',
#  'world',
#  'know',
#  'direction',
#  'must',
#  'unhampered',
#  'debt',
#  'heroic',
#  'men',
#  'valiant',
#  'women',
#  'service',
#  'country',
#  'never',
#  'repaid',
#  'earned',
#  'undying',
#  'gratitude',
#  'america',
#  'never',
#  'forget',
#  'sacrifices',
#  'sacrifices',
#  'dawn',
#  'justice',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'casts',
#  'gleam',
#  'across',
#  'horizon',
#  'forefathers',
#  'came',
#  'rugged',
#  'shores',
#  'search',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'economic',
#  'opportunity',
#  'fundamental',
#  'rights',
#  'risked',
#  'lives',
#  'well',
#  'know',
#  'today',
#  'rights',
#  'preserved',
#  'constant',
#  'vigilance',
#  'eternal',
#  'price',
#  'liberty',
#  'within',
#  'hour',
#  'took',
#  'oath',
#  'office',
#  'announced',
#  'san',
#  'francisco',
#  'conference',
#  'would',
#  'proceed',
#  'face',
#  'problems',
#  'peace',
#  'courage',
#  'faced',
#  'mastered',
#  'problems',
#  'war',
#  'memory',
#  'made',
#  'supreme',
#  'memory',
#  'fallen',
#  'shall',
#  'fail',
#  'enough',
#  'yearn',
#  'peace',
#  'must',
#  'work',
#  'necessary',
#  'fight',
#  'task',
#  'creating',
#  'sound',
#  'international',
#  'organization',
#  'complicated',
#  'difficult',
#  'yet',
#  'without',
#  'organization',
#  'rights',
#  'man',
#  'earth',
#  'protected',
#  'machi',
#  'nery',
#  'settlement',
#  'international',
#  'differences',
#  'must',
#  'found',
#  'without',
#  'machinery',
#  'entire',
#  'world',
#  'remain',
#  'armed',
#  'camp',
#  'world',
#  'doomed',
#  'deadly',
#  'conflict',
#  'devoid',
#  'hope',
#  'real',
#  'peace',
#  'fortunately',
#  'people',
#  'retained',
#  'hope',
#  'durable',
#  'peace',
#  'thoughtful',
#  'people',
#  'always',
#  'faith',
#  'ultimately',
#  'justice',
#  'must',
#  'triumph',
#  'past',
#  'experience',
#  'surely',
#  'indicates',
#  'without',
#  'justice',
#  'enduring',
#  'peace',
#  'becomes',
#  'impossible',
#  'bitter',
#  'despair',
#  'people',
#  'come',
#  'believe',
#  'wars',
#  'inevitable',
#  'tragic',
#  'fatalism',
#  'insist',
#  'wars',
#  'always',
#  'necessity',
#  'necessity',
#  'wars',
#  'always',
#  'defeatism',
#  'men',
#  'women',
#  'good',
#  'must',
#  'yield',
#  'outlook',
#  'humanity',
#  'hopeless',
#  'dark',
#  'hours',
#  'horrible',
#  'war',
#  'entire',
#  'nations',
#  'kept',
#  'going',
#  'something',
#  'warned',
#  'abject',
#  'submission',
#  'offered',
#  'salvation',
#  'overwhelming',
#  'power',
#  'hope',
#  'showed',
#  'way',
#  'victory',
#  'hope',
#  'become',
#  'secret',
#  'weapon',
#  'forces',
#  'liberation',
#  'aggressors',
#  'could',
#  'dominate',
#  'human',
#  'mind',
#  'long',
#  'hope',
#  'remains',
#  'spirit',
#  'man',
#  'never',
#  'crushed',
#  'hope',
#  'alone',
#  'sufficient',
#  'avert',
#  'war',
#  'must',
#  'hope',
#  'must',
#  'faith',
#  'enough',
#  'work',
#  'nations',
#  'maintain',
#  'peace',
#  'hope',
#  'enough',
#  'beat',
#  'back',
#  'aggressors',
#  'long',
#  'nations',
#  'unwilling',
#  'come',
#  'defense',
#  'aggressors',
#  'beaten',
#  'back',
#  'nations',
#  'united',
#  'defend',
#  'wars',
#  'future',
#  'prevented',
#  'nations',
#  'must',
#  'united',
#  'determination',
#  'keep',
#  'peace',
#  'law',
#  'nothing',
#  'essential',
#  'future',
#  'peace',
#  'world',
#  'continued',
#  'cooperation',
#  'nations',
#  'muster',
#  'force',
#  'necessary',
#  'defeat',
#  'conspiracy',
#  'axis',
#  'powers',
#  'dominate',
#  'world',
#  'great',
#  'states',
#  'special',
#  'responsibility',
#  'enforce',
#  'peace',
#  'responsibility',
#  'based',
#  'upon',
#  'obligations',
#  'resting',
#  'upon',
#  'states',
#  'large',
#  'small',
#  'use',
#  'force',
#  'international',
#  'relations',
#  'except',
#  'defense',
#  'law',
#  'respon',
#  'sibility',
#  'great',
#  'states',
#  'serve',
#  'dominate',
#  'world',
#  'build',
#  'foundation',
#  'enduring',
#  'peace',
#  'must',
#  'work',
#  'harmony',
#  'friends',
#  'abroad',
#  'must',
#  'united',
#  'support',
#  'people',
#  'even',
#  'experienced',
#  'pilot',
#  'bring',
#  'ship',
#  'safely',
#  'harbor',
#  'unless',
#  'full',
#  'cooperation',
#  'crew',
#  'benefit',
#  'every',
#  'individual',
#  'must',
#  'duty',
#  'appeal',
#  'every',
#  'american',
#  'regardless',
#  'party',
#  'race',
#  'creed',
#  'color',
#  'support',
#  'efforts',
#  'build',
#  'strong',
#  'lasting',
#  'united',
#  'nations',
#  'organization',
#  'members',
#  'congress',
#  'surely',
#  'know',
#  'feel',
#  'help',
#  'hope',
#  'complete',
#  'one',
#  'greatest',
#  'tasks',
#  'ever',
#  'assigned',
#  'public',
#  'servant',
#  'divine',
#  'guidance',
#  'help',
#  'find',
#  'new',
#  'passage',
#  'far',
#  'better',
#  'world',
#  'kindly',
#  'friendly',
#  'world',
#  'lasting',
#  'peace',
#  'confidence',
#  'depending',
#  'upon',
#  'destroy',
#  'greedy',
#  'tyrants',
#  'dreams',
#  'world',
#  'domination',
#  'continue',
#  'successive',
#  'generations',
#  'sacrifice',
#  'finest',
#  'youth',
#  'name',
#  'human',
#  'decency',
#  'civilization',
#  'rational',
#  'method',
#  'deciding',
#  'national',
#  'differences',
#  'must',
#  'found',
#  'america',
#  'must',
#  'assist',
#  'suffering',
#  'humanity',
#  'back',
#  'along',
#  'path',
#  'peaceful',
#  'progress',
#  'require',
#  'time',
#  'tolerance',
#  'shall',
#  'need',
#  'also',
#  'abiding',
#  'faith',
#  'people',
#  'kind',
#  'faith',
#  'courage',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'always',
#  'today',
#  'america',
#  'become',
#  'one',
#  'powerful',
#  'forces',
#  'good',
#  'earth',
#  'must',
#  'keep',
#  'achieved',
#  'world',
#  'leadership',
#  'depend',
#  'solely',
#  'upon',
#  'military',
#  'naval',
#  'might',
#  'learned',
#  'fight',
#  'nations',
#  'common',
#  'defense',
#  'freedom',
#  'must',
#  'learn',
#  'live',
#  'nations',
#  'mutual',
#  'good',
#  'must',
#  'learn',
#  'trade',
#  'nations',
#  'may',
#  'mutual',
#  'product',
#  'ion',
#  'increased',
#  'employment',
#  'better',
#  'standards',
#  'living',
#  'throughout',
#  'world',
#  'may',
#  'americans',
#  'live',
#  'glorious',
#  'heritage',
#  'way',
#  'america',
#  'may',
#  'well',
#  'lead',
#  'world',
#  'peace',
#  'prosperity',
#  'moment',
#  'heart',
#  'prayer',
#  'assumed',
#  'heavy',
#  'duties',
#  'humbly',
#  'pray',
#  'almighty',
#  'god',
#  'words',
#  'king',
#  'solomon',
#  'give',
#  'therefore',
#  'thy',
#  'servant',
#  'understanding',
#  'heart',
#  'judge',
#  'thy',
#  'people',
#  'may',
#  'discern',
#  'good',
#  'bad',
#  'able',
#  'judge',
#  'thy',
#  'great',
#  'people',
#  'ask',
#  'good',
#  'faithful',
#  'servant',
#  'lord',
#  'people']

# %% [markdown]
# ## Part 7 – Vocabulary and Frequency

# %% [markdown]
# 📌 The vocabulary is the set of unique tokens in a corpus.

# %% [markdown]
# # Stemming vs Lemmatization
#
# Stemming and lemmatization are both normalization techniques, but they make very different trade-offs.
#
# Stemming is fast and rule-based but can distort meaning
#
# Lemmatization is slower but linguistically informed
#
# In industry, the choice depends on task, domain, and interpretability requirements.

# %%
import nltk
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stem_nltk = []

for word in filtered_nltk:
    stem = ps.stem(word)
    stem_nltk.append(stem)
    print(f"{word} ------> {stem}")

stem_nltk
# Out:
# president ------> presid
# harry ------> harri
# truman ------> truman
# address ------> address
# joint ------> joint
# session ------> session
# congress ------> congress
# april ------> april
# speaker ------> speaker
# president ------> presid
# members ------> member
# congress ------> congress
# heavy ------> heavi
# heart ------> heart
# stand ------> stand
# friends ------> friend
# colleagues ------> colleagu
# congress ------> congress
# united ------> unit
# states ------> state
# yesterday ------> yesterday
# laid ------> laid
# rest ------> rest
# mortal ------> mortal
# remains ------> remain
# beloved ------> belov
# president ------> presid
# franklin ------> franklin
# delano ------> delano
# roosevelt ------> roosevelt
# time ------> time
# like ------> like
# words ------> word
# inadequate ------> inadequ
# eloquent ------> eloqu
# tribute ------> tribut
# would ------> would
# reverent ------> rever
# silence ------> silenc
# yet ------> yet
# decisive ------> decis
# hour ------> hour
# world ------> world
# events ------> event
# moving ------> move
# rapidly ------> rapidli
# silence ------> silenc
# might ------> might
# misunderstood ------> misunderstood
# might ------> might
# give ------> give
# comfort ------> comfort
# enemies ------> enemi
# infinite ------> infinit
# wisdom ------> wisdom
# almighty ------> almighti
# god ------> god
# seen ------> seen
# fit ------> fit
# take ------> take
# us ------> us
# great ------> great
# man ------> man
# loved ------> love
# beloved ------> belov
# humanity ------> human
# man ------> man
# could ------> could
# possibly ------> possibl
# fill ------> fill
# tremendous ------> tremend
# void ------> void
# left ------> left
# passing ------> pass
# noble ------> nobl
# soul ------> soul
# words ------> word
# ease ------> eas
# aching ------> ach
# hearts ------> heart
# untold ------> untold
# millions ------> million
# every ------> everi
# race ------> race
# creed ------> creed
# color ------> color
# world ------> world
# knows ------> know
# lost ------> lost
# heroic ------> heroic
# champion ------> champion
# justice ------> justic
# freedom ------> freedom
# tragic ------> tragic
# fate ------> fate
# thrust ------> thrust
# upon ------> upon
# us ------> us
# grave ------> grave
# responsibilities ------> respons
# must ------> must
# carry ------> carri
# departed ------> depart
# leader ------> leader
# never ------> never
# looked ------> look
# backward ------> backward
# looked ------> look
# forward ------> forward
# moved ------> move
# forward ------> forward
# would ------> would
# want ------> want
# us ------> us
# america ------> america
# much ------> much
# blood ------> blood
# already ------> alreadi
# shed ------> shed
# ideals ------> ideal
# cherish ------> cherish
# franklin ------> franklin
# delano ------> delano
# roosevelt ------> roosevelt
# lived ------> live
# died ------> die
# dare ------> dare
# permit ------> permit
# even ------> even
# momentary ------> momentari
# pause ------> paus
# hard ------> hard
# fight ------> fight
# victory ------> victori
# today ------> today
# entire ------> entir
# world ------> world
# looking ------> look
# america ------> america
# enlightened ------> enlighten
# leadership ------> leadership
# peace ------> peac
# progress ------> progress
# leadership ------> leadership
# requires ------> requir
# vision ------> vision
# courage ------> courag
# tolerance ------> toler
# provided ------> provid
# united ------> unit
# nation ------> nation
# deeply ------> deepli
# devoted ------> devot
# highest ------> highest
# ideals ------> ideal
# great ------> great
# humility ------> humil
# call ------> call
# upon ------> upon
# americans ------> american
# help ------> help
# keep ------> keep
# nation ------> nation
# united ------> unit
# defense ------> defens
# ideals ------> ideal
# eloquently ------> eloqu
# proclaimed ------> proclaim
# franklin ------> franklin
# roosevelt ------> roosevelt
# want ------> want
# turn ------> turn
# assure ------> assur
# fellow ------> fellow
# americans ------> american
# love ------> love
# peace ------> peac
# liberty ------> liberti
# throughout ------> throughout
# world ------> world
# support ------> support
# defend ------> defend
# ideals ------> ideal
# strength ------> strength
# heart ------> heart
# duty ------> duti
# shall ------> shall
# shirk ------> shirk
# possible ------> possibl
# misunderstanding ------> misunderstand
# germany ------> germani
# japan ------> japan
# certain ------> certain
# beyond ------> beyond
# shadow ------> shadow
# doubt ------> doubt
# america ------> america
# continue ------> continu
# fight ------> fight
# freedom ------> freedom
# vestige ------> vestig
# resistance ------> resist
# remains ------> remain
# deeply ------> deepli
# conscious ------> consciou
# fact ------> fact
# much ------> much
# hard ------> hard
# fighting ------> fight
# still ------> still
# ahead ------> ahead
# us ------> us
# pay ------> pay
# heavy ------> heavi
# price ------> price
# make ------> make
# complete ------> complet
# victory ------> victori
# certain ------> certain
# america ------> america
# never ------> never
# become ------> becom
# party ------> parti
# plan ------> plan
# partial ------> partial
# victory ------> victori
# settle ------> settl
# merely ------> mere
# another ------> anoth
# temporary ------> temporari
# respite ------> respit
# would ------> would
# surely ------> sure
# jeopardize ------> jeopard
# future ------> futur
# security ------> secur
# world ------> world
# demand ------> demand
# surrender ------> surrend
# traffic ------> traffic
# breakers ------> breaker
# peace ------> peac
# terms ------> term
# peace ------> peac
# responsibility ------> respons
# making ------> make
# grave ------> grave
# rest ------> rest
# defenders ------> defend
# peace ------> peac
# unconscious ------> unconsci
# dictates ------> dictat
# humanity ------> human
# wish ------> wish
# see ------> see
# unnecessary ------> unnecessari
# unjustified ------> unjustifi
# suffering ------> suffer
# laws ------> law
# go ------> go
# man ------> man
# violated ------> violat
# guilty ------> guilti
# must ------> must
# go ------> go
# unpunished ------> unpunish
# nothing ------> noth
# shall ------> shall
# shake ------> shake
# determination ------> determin
# punish ------> punish
# war ------> war
# criminals ------> crimin
# even ------> even
# though ------> though
# must ------> must
# pursue ------> pursu
# ends ------> end
# earth ------> earth
# lasting ------> last
# peace ------> peac
# never ------> never
# secured ------> secur
# permit ------> permit
# dangerous ------> danger
# opponents ------> oppon
# plot ------> plot
# future ------> futur
# wars ------> war
# impunity ------> impun
# mountain ------> mountain
# retreat ------> retreat
# however ------> howev
# distant ------> distant
# shrinking ------> shrink
# world ------> world
# futile ------> futil
# seek ------> seek
# safety ------> safeti
# behind ------> behind
# geographical ------> geograph
# barriers ------> barrier
# real ------> real
# security ------> secur
# found ------> found
# law ------> law
# justice ------> justic
# america ------> america
# labored ------> labor
# long ------> long
# hard ------> hard
# achieve ------> achiev
# social ------> social
# order ------> order
# worthy ------> worthi
# great ------> great
# heritage ------> heritag
# time ------> time
# tremendous ------> tremend
# progress ------> progress
# made ------> made
# toward ------> toward
# really ------> realli
# democratic ------> democrat
# way ------> way
# life ------> life
# let ------> let
# assure ------> assur
# people ------> peopl
# america ------> america
# w ------> w
# ill ------> ill
# relaxation ------> relax
# efforts ------> effort
# improve ------> improv
# lot ------> lot
# common ------> common
# people ------> peopl
# difficult ------> difficult
# days ------> day
# ahead ------> ahead
# unquestionably ------> unquestion
# shall ------> shall
# face ------> face
# problems ------> problem
# staggering ------> stagger
# proportions ------> proport
# however ------> howev
# faith ------> faith
# fathers ------> father
# hearts ------> heart
# fear ------> fear
# future ------> futur
# battlefields ------> battlefield
# frequently ------> frequent
# faced ------> face
# overwhelming ------> overwhelm
# odds ------> odd
# home ------> home
# americans ------> american
# less ------> less
# resolute ------> resolut
# shall ------> shall
# never ------> never
# cease ------> ceas
# struggle ------> struggl
# preserve ------> preserv
# maintain ------> maintain
# american ------> american
# way ------> way
# life ------> life
# moment ------> moment
# america ------> america
# along ------> along
# brave ------> brave
# allies ------> alli
# paying ------> pay
# heavy ------> heavi
# price ------> price
# defense ------> defens
# freedom ------> freedom
# characteristic ------> characterist
# energy ------> energi
# assisting ------> assist
# liberation ------> liber
# entire ------> entir
# nations ------> nation
# gradually ------> gradual
# shackles ------> shackl
# slavery ------> slaveri
# broken ------> broken
# forces ------> forc
# freedom ------> freedom
# us ------> us
# praying ------> pray
# speedy ------> speedi
# victory ------> victori
# every ------> everi
# day ------> day
# peace ------> peac
# delayed ------> delay
# costs ------> cost
# terrible ------> terribl
# toll ------> toll
# armies ------> armi
# liberation ------> liber
# today ------> today
# bringing ------> bring
# end ------> end
# hitler ------> hitler
# ghastly ------> ghastli
# threat ------> threat
# dominate ------> domin
# world ------> world
# tokyo ------> tokyo
# rocks ------> rock
# weight ------> weight
# bombs ------> bomb
# grand ------> grand
# strategy ------> strategi
# united ------> unit
# nations ------> nation
# war ------> war
# determined ------> determin
# due ------> due
# small ------> small
# measure ------> measur
# vision ------> vision
# departed ------> depart
# commander ------> command
# chief ------> chief
# carrying ------> carri
# part ------> part
# strategy ------> strategi
# able ------> abl
# direction ------> direct
# admiral ------> admir
# leahy ------> leahi
# general ------> gener
# marshall ------> marshal
# dmiral ------> dmiral
# king ------> king
# general ------> gener
# arnold ------> arnold
# general ------> gener
# eisenhower ------> eisenhow
# admiral ------> admir
# nimitz ------> nimitz
# general ------> gener
# macarthur ------> macarthur
# want ------> want
# entire ------> entir
# world ------> world
# know ------> know
# direction ------> direct
# must ------> must
# unhampered ------> unhamp
# debt ------> debt
# heroic ------> heroic
# men ------> men
# valiant ------> valiant
# women ------> women
# service ------> servic
# country ------> countri
# never ------> never
# repaid ------> repaid
# earned ------> earn
# undying ------> undi
# gratitude ------> gratitud
# america ------> america
# never ------> never
# forget ------> forget
# sacrifices ------> sacrific
# sacrifices ------> sacrific
# dawn ------> dawn
# justice ------> justic
# freedom ------> freedom
# throughout ------> throughout
# th ------> th
# e ------> e
# world ------> world
# slowly ------> slowli
# casts ------> cast
# gleam ------> gleam
# across ------> across
# horizon ------> horizon
# forefathers ------> forefath
# came ------> came
# rugged ------> rug
# shores ------> shore
# search ------> search
# religious ------> religi
# tolerance ------> toler
# political ------> polit
# freedom ------> freedom
# economic ------> econom
# opportunity ------> opportun
# fundamental ------> fundament
# rights ------> right
# risked ------> risk
# lives ------> live
# well ------> well
# know ------> know
# today ------> today
# rights ------> right
# preserved ------> preserv
# constant ------> constant
# vigilance ------> vigil
# eternal ------> etern
# price ------> price
# liberty ------> liberti
# within ------> within
# hour ------> hour
# took ------> took
# oath ------> oath
# office ------> offic
# announced ------> announc
# san ------> san
# francisco ------> francisco
# conference ------> confer
# would ------> would
# proceed ------> proceed
# face ------> face
# problems ------> problem
# peace ------> peac
# courage ------> courag
# faced ------> face
# mastered ------> master
# problems ------> problem
# war ------> war
# memory ------> memori
# made ------> made
# supreme ------> suprem
# memory ------> memori
# fallen ------> fallen
# shall ------> shall
# fail ------> fail
# enough ------> enough
# yearn ------> yearn
# peace ------> peac
# must ------> must
# work ------> work
# necessary ------> necessari
# fight ------> fight
# task ------> task
# creating ------> creat
# sound ------> sound
# international ------> intern
# organization ------> organ
# complicated ------> complic
# difficult ------> difficult
# yet ------> yet
# without ------> without
# organization ------> organ
# rights ------> right
# man ------> man
# earth ------> earth
# protected ------> protect
# machi ------> machi
# nery ------> neri
# settlement ------> settlement
# international ------> intern
# differences ------> differ
# must ------> must
# found ------> found
# without ------> without
# machinery ------> machineri
# entire ------> entir
# world ------> world
# remain ------> remain
# armed ------> arm
# camp ------> camp
# world ------> world
# doomed ------> doom
# deadly ------> deadli
# conflict ------> conflict
# devoid ------> devoid
# hope ------> hope
# real ------> real
# peace ------> peac
# fortunately ------> fortun
# people ------> peopl
# retained ------> retain
# hope ------> hope
# durable ------> durabl
# peace ------> peac
# thoughtful ------> thought
# people ------> peopl
# always ------> alway
# faith ------> faith
# ultimately ------> ultim
# justice ------> justic
# must ------> must
# triumph ------> triumph
# past ------> past
# experience ------> experi
# surely ------> sure
# indicates ------> indic
# without ------> without
# justice ------> justic
# enduring ------> endur
# peace ------> peac
# becomes ------> becom
# impossible ------> imposs
# bitter ------> bitter
# despair ------> despair
# people ------> peopl
# come ------> come
# believe ------> believ
# wars ------> war
# inevitable ------> inevit
# tragic ------> tragic
# fatalism ------> fatal
# insist ------> insist
# wars ------> war
# always ------> alway
# necessity ------> necess
# necessity ------> necess
# wars ------> war
# always ------> alway
# defeatism ------> defeat
# men ------> men
# women ------> women
# good ------> good
# must ------> must
# yield ------> yield
# outlook ------> outlook
# humanity ------> human
# hopeless ------> hopeless
# dark ------> dark
# hours ------> hour
# horrible ------> horribl
# war ------> war
# entire ------> entir
# nations ------> nation
# kept ------> kept
# going ------> go
# something ------> someth
# warned ------> warn
# abject ------> abject
# submission ------> submiss
# offered ------> offer
# salvation ------> salvat
# overwhelming ------> overwhelm
# power ------> power
# hope ------> hope
# showed ------> show
# way ------> way
# victory ------> victori
# hope ------> hope
# become ------> becom
# secret ------> secret
# weapon ------> weapon
# forces ------> forc
# liberation ------> liber
# aggressors ------> aggressor
# could ------> could
# dominate ------> domin
# human ------> human
# mind ------> mind
# long ------> long
# hope ------> hope
# remains ------> remain
# spirit ------> spirit
# man ------> man
# never ------> never
# crushed ------> crush
# hope ------> hope
# alone ------> alon
# sufficient ------> suffici
# avert ------> avert
# war ------> war
# must ------> must
# hope ------> hope
# must ------> must
# faith ------> faith
# enough ------> enough
# work ------> work
# nations ------> nation
# maintain ------> maintain
# peace ------> peac
# hope ------> hope
# enough ------> enough
# beat ------> beat
# back ------> back
# aggressors ------> aggressor
# long ------> long
# nations ------> nation
# unwilling ------> unwil
# come ------> come
# defense ------> defens
# aggressors ------> aggressor
# beaten ------> beaten
# back ------> back
# nations ------> nation
# united ------> unit
# defend ------> defend
# wars ------> war
# future ------> futur
# prevented ------> prevent
# nations ------> nation
# must ------> must
# united ------> unit
# determination ------> determin
# keep ------> keep
# peace ------> peac
# law ------> law
# nothing ------> noth
# essential ------> essenti
# future ------> futur
# peace ------> peac
# world ------> world
# continued ------> continu
# cooperation ------> cooper
# nations ------> nation
# muster ------> muster
# force ------> forc
# necessary ------> necessari
# defeat ------> defeat
# conspiracy ------> conspiraci
# axis ------> axi
# powers ------> power
# dominate ------> domin
# world ------> world
# great ------> great
# states ------> state
# special ------> special
# responsibility ------> respons
# enforce ------> enforc
# peace ------> peac
# responsibility ------> respons
# based ------> base
# upon ------> upon
# obligations ------> oblig
# resting ------> rest
# upon ------> upon
# states ------> state
# large ------> larg
# small ------> small
# use ------> use
# force ------> forc
# international ------> intern
# relations ------> relat
# except ------> except
# defense ------> defens
# law ------> law
# respon ------> respon
# sibility ------> sibil
# great ------> great
# states ------> state
# serve ------> serv
# dominate ------> domin
# world ------> world
# build ------> build
# foundation ------> foundat
# enduring ------> endur
# peace ------> peac
# must ------> must
# work ------> work
# harmony ------> harmoni
# friends ------> friend
# abroad ------> abroad
# must ------> must
# united ------> unit
# support ------> support
# people ------> peopl
# even ------> even
# experienced ------> experienc
# pilot ------> pilot
# bring ------> bring
# ship ------> ship
# safely ------> safe
# harbor ------> harbor
# unless ------> unless
# full ------> full
# cooperation ------> cooper
# crew ------> crew
# benefit ------> benefit
# every ------> everi
# individual ------> individu
# must ------> must
# duty ------> duti
# appeal ------> appeal
# every ------> everi
# american ------> american
# regardless ------> regardless
# party ------> parti
# race ------> race
# creed ------> creed
# color ------> color
# support ------> support
# efforts ------> effort
# build ------> build
# strong ------> strong
# lasting ------> last
# united ------> unit
# nations ------> nation
# organization ------> organ
# members ------> member
# congress ------> congress
# surely ------> sure
# know ------> know
# feel ------> feel
# help ------> help
# hope ------> hope
# complete ------> complet
# one ------> one
# greatest ------> greatest
# tasks ------> task
# ever ------> ever
# assigned ------> assign
# public ------> public
# servant ------> servant
# divine ------> divin
# guidance ------> guidanc
# help ------> help
# find ------> find
# new ------> new
# passage ------> passag
# far ------> far
# better ------> better
# world ------> world
# kindly ------> kindli
# friendly ------> friendli
# world ------> world
# lasting ------> last
# peace ------> peac
# confidence ------> confid
# depending ------> depend
# upon ------> upon
# destroy ------> destroy
# greedy ------> greedi
# tyrants ------> tyrant
# dreams ------> dream
# world ------> world
# domination ------> domin
# continue ------> continu
# successive ------> success
# generations ------> gener
# sacrifice ------> sacrific
# finest ------> finest
# youth ------> youth
# name ------> name
# human ------> human
# decency ------> decenc
# civilization ------> civil
# rational ------> ration
# method ------> method
# deciding ------> decid
# national ------> nation
# differences ------> differ
# must ------> must
# found ------> found
# america ------> america
# must ------> must
# assist ------> assist
# suffering ------> suffer
# humanity ------> human
# back ------> back
# along ------> along
# path ------> path
# peaceful ------> peac
# progress ------> progress
# require ------> requir
# time ------> time
# tolerance ------> toler
# shall ------> shall
# need ------> need
# also ------> also
# abiding ------> abid
# faith ------> faith
# people ------> peopl
# kind ------> kind
# faith ------> faith
# courage ------> courag
# franklin ------> franklin
# delano ------> delano
# roosevelt ------> roosevelt
# always ------> alway
# today ------> today
# america ------> america
# become ------> becom
# one ------> one
# powerful ------> power
# forces ------> forc
# good ------> good
# earth ------> earth
# must ------> must
# keep ------> keep
# achieved ------> achiev
# world ------> world
# leadership ------> leadership
# depend ------> depend
# solely ------> sole
# upon ------> upon
# military ------> militari
# naval ------> naval
# might ------> might
# learned ------> learn
# fight ------> fight
# nations ------> nation
# common ------> common
# defense ------> defens
# freedom ------> freedom
# must ------> must
# learn ------> learn
# live ------> live
# nations ------> nation
# mutual ------> mutual
# good ------> good
# must ------> must
# learn ------> learn
# trade ------> trade
# nations ------> nation
# may ------> may
# mutual ------> mutual
# product ------> product
# ion ------> ion
# increased ------> increas
# employment ------> employ
# better ------> better
# standards ------> standard
# living ------> live
# throughout ------> throughout
# world ------> world
# may ------> may
# americans ------> american
# live ------> live
# glorious ------> gloriou
# heritage ------> heritag
# way ------> way
# america ------> america
# may ------> may
# well ------> well
# lead ------> lead
# world ------> world
# peace ------> peac
# prosperity ------> prosper
# moment ------> moment
# heart ------> heart
# prayer ------> prayer
# assumed ------> assum
# heavy ------> heavi
# duties ------> duti
# humbly ------> humbl
# pray ------> pray
# almighty ------> almighti
# god ------> god
# words ------> word
# king ------> king
# solomon ------> solomon
# give ------> give
# therefore ------> therefor
# thy ------> thi
# servant ------> servant
# understanding ------> understand
# heart ------> heart
# judge ------> judg
# thy ------> thi
# people ------> peopl
# may ------> may
# discern ------> discern
# good ------> good
# bad ------> bad
# able ------> abl
# judge ------> judg
# thy ------> thi
# great ------> great
# people ------> peopl
# ask ------> ask
# good ------> good
# faithful ------> faith
# servant ------> servant
# lord ------> lord
# people ------> peopl
# ['presid',
#  'harri',
#  'truman',
#  'address',
#  'joint',
#  'session',
#  'congress',
#  'april',
#  'speaker',
#  'presid',
#  'member',
#  'congress',
#  'heavi',
#  'heart',
#  'stand',
#  'friend',
#  'colleagu',
#  'congress',
#  'unit',
#  'state',
#  'yesterday',
#  'laid',
#  'rest',
#  'mortal',
#  'remain',
#  'belov',
#  'presid',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'time',
#  'like',
#  'word',
#  'inadequ',
#  'eloqu',
#  'tribut',
#  'would',
#  'rever',
#  'silenc',
#  'yet',
#  'decis',
#  'hour',
#  'world',
#  'event',
#  'move',
#  'rapidli',
#  'silenc',
#  'might',
#  'misunderstood',
#  'might',
#  'give',
#  'comfort',
#  'enemi',
#  'infinit',
#  'wisdom',
#  'almighti',
#  'god',
#  'seen',
#  'fit',
#  'take',
#  'us',
#  'great',
#  'man',
#  'love',
#  'belov',
#  'human',
#  'man',
#  'could',
#  'possibl',
#  'fill',
#  'tremend',
#  'void',
#  'left',
#  'pass',
#  'nobl',
#  'soul',
#  'word',
#  'eas',
#  'ach',
#  'heart',
#  'untold',
#  'million',
#  'everi',
#  'race',
#  'creed',
#  'color',
#  'world',
#  'know',
#  'lost',
#  'heroic',
#  'champion',
#  'justic',
#  'freedom',
#  'tragic',
#  'fate',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'respons',
#  'must',
#  'carri',
#  'depart',
#  'leader',
#  'never',
#  'look',
#  'backward',
#  'look',
#  'forward',
#  'move',
#  'forward',
#  'would',
#  'want',
#  'us',
#  'america',
#  'much',
#  'blood',
#  'alreadi',
#  'shed',
#  'ideal',
#  'cherish',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'live',
#  'die',
#  'dare',
#  'permit',
#  'even',
#  'momentari',
#  'paus',
#  'hard',
#  'fight',
#  'victori',
#  'today',
#  'entir',
#  'world',
#  'look',
#  'america',
#  'enlighten',
#  'leadership',
#  'peac',
#  'progress',
#  'leadership',
#  'requir',
#  'vision',
#  'courag',
#  'toler',
#  'provid',
#  'unit',
#  'nation',
#  'deepli',
#  'devot',
#  'highest',
#  'ideal',
#  'great',
#  'humil',
#  'call',
#  'upon',
#  'american',
#  'help',
#  'keep',
#  'nation',
#  'unit',
#  'defens',
#  'ideal',
#  'eloqu',
#  'proclaim',
#  'franklin',
#  'roosevelt',
#  'want',
#  'turn',
#  'assur',
#  'fellow',
#  'american',
#  'love',
#  'peac',
#  'liberti',
#  'throughout',
#  'world',
#  'support',
#  'defend',
#  'ideal',
#  'strength',
#  'heart',
#  'duti',
#  'shall',
#  'shirk',
#  'possibl',
#  'misunderstand',
#  'germani',
#  'japan',
#  'certain',
#  'beyond',
#  'shadow',
#  'doubt',
#  'america',
#  'continu',
#  'fight',
#  'freedom',
#  'vestig',
#  'resist',
#  'remain',
#  'deepli',
#  'consciou',
#  'fact',
#  'much',
#  'hard',
#  'fight',
#  'still',
#  'ahead',
#  'us',
#  'pay',
#  'heavi',
#  'price',
#  'make',
#  'complet',
#  'victori',
#  'certain',
#  'america',
#  'never',
#  'becom',
#  'parti',
#  'plan',
#  'partial',
#  'victori',
#  'settl',
#  'mere',
#  'anoth',
#  'temporari',
#  'respit',
#  'would',
#  'sure',
#  'jeopard',
#  'futur',
#  'secur',
#  'world',
#  'demand',
#  'surrend',
#  'traffic',
#  'breaker',
#  'peac',
#  'term',
#  'peac',
#  'respons',
#  'make',
#  'grave',
#  'rest',
#  'defend',
#  'peac',
#  'unconsci',
#  'dictat',
#  'human',
#  'wish',
#  'see',
#  'unnecessari',
#  'unjustifi',
#  'suffer',
#  'law',
#  'go',
#  'man',
#  'violat',
#  'guilti',
#  'must',
#  'go',
#  'unpunish',
#  'noth',
#  'shall',
#  'shake',
#  'determin',
#  'punish',
#  'war',
#  'crimin',
#  'even',
#  'though',
#  'must',
#  'pursu',
#  'end',
#  'earth',
#  'last',
#  'peac',
#  'never',
#  'secur',
#  'permit',
#  'danger',
#  'oppon',
#  'plot',
#  'futur',
#  'war',
#  'impun',
#  'mountain',
#  'retreat',
#  'howev',
#  'distant',
#  'shrink',
#  'world',
#  'futil',
#  'seek',
#  'safeti',
#  'behind',
#  'geograph',
#  'barrier',
#  'real',
#  'secur',
#  'found',
#  'law',
#  'justic',
#  'america',
#  'labor',
#  'long',
#  'hard',
#  'achiev',
#  'social',
#  'order',
#  'worthi',
#  'great',
#  'heritag',
#  'time',
#  'tremend',
#  'progress',
#  'made',
#  'toward',
#  'realli',
#  'democrat',
#  'way',
#  'life',
#  'let',
#  'assur',
#  'peopl',
#  'america',
#  'w',
#  'ill',
#  'relax',
#  'effort',
#  'improv',
#  'lot',
#  'common',
#  'peopl',
#  'difficult',
#  'day',
#  'ahead',
#  'unquestion',
#  'shall',
#  'face',
#  'problem',
#  'stagger',
#  'proport',
#  'howev',
#  'faith',
#  'father',
#  'heart',
#  'fear',
#  'futur',
#  'battlefield',
#  'frequent',
#  'face',
#  'overwhelm',
#  'odd',
#  'home',
#  'american',
#  'less',
#  'resolut',
#  'shall',
#  'never',
#  'ceas',
#  'struggl',
#  'preserv',
#  'maintain',
#  'american',
#  'way',
#  'life',
#  'moment',
#  'america',
#  'along',
#  'brave',
#  'alli',
#  'pay',
#  'heavi',
#  'price',
#  'defens',
#  'freedom',
#  'characterist',
#  'energi',
#  'assist',
#  'liber',
#  'entir',
#  'nation',
#  'gradual',
#  'shackl',
#  'slaveri',
#  'broken',
#  'forc',
#  'freedom',
#  'us',
#  'pray',
#  'speedi',
#  'victori',
#  'everi',
#  'day',
#  'peac',
#  'delay',
#  'cost',
#  'terribl',
#  'toll',
#  'armi',
#  'liber',
#  'today',
#  'bring',
#  'end',
#  'hitler',
#  'ghastli',
#  'threat',
#  'domin',
#  'world',
#  'tokyo',
#  'rock',
#  'weight',
#  'bomb',
#  'grand',
#  'strategi',
#  'unit',
#  'nation',
#  'war',
#  'determin',
#  'due',
#  'small',
#  'measur',
#  'vision',
#  'depart',
#  'command',
#  'chief',
#  'carri',
#  'part',
#  'strategi',
#  'abl',
#  'direct',
#  'admir',
#  'leahi',
#  'gener',
#  'marshal',
#  'dmiral',
#  'king',
#  'gener',
#  'arnold',
#  'gener',
#  'eisenhow',
#  'admir',
#  'nimitz',
#  'gener',
#  'macarthur',
#  'want',
#  'entir',
#  'world',
#  'know',
#  'direct',
#  'must',
#  'unhamp',
#  'debt',
#  'heroic',
#  'men',
#  'valiant',
#  'women',
#  'servic',
#  'countri',
#  'never',
#  'repaid',
#  'earn',
#  'undi',
#  'gratitud',
#  'america',
#  'never',
#  'forget',
#  'sacrific',
#  'sacrific',
#  'dawn',
#  'justic',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowli',
#  'cast',
#  'gleam',
#  'across',
#  'horizon',
#  'forefath',
#  'came',
#  'rug',
#  'shore',
#  'search',
#  'religi',
#  'toler',
#  'polit',
#  'freedom',
#  'econom',
#  'opportun',
#  'fundament',
#  'right',
#  'risk',
#  'live',
#  'well',
#  'know',
#  'today',
#  'right',
#  'preserv',
#  'constant',
#  'vigil',
#  'etern',
#  'price',
#  'liberti',
#  'within',
#  'hour',
#  'took',
#  'oath',
#  'offic',
#  'announc',
#  'san',
#  'francisco',
#  'confer',
#  'would',
#  'proceed',
#  'face',
#  'problem',
#  'peac',
#  'courag',
#  'face',
#  'master',
#  'problem',
#  'war',
#  'memori',
#  'made',
#  'suprem',
#  'memori',
#  'fallen',
#  'shall',
#  'fail',
#  'enough',
#  'yearn',
#  'peac',
#  'must',
#  'work',
#  'necessari',
#  'fight',
#  'task',
#  'creat',
#  'sound',
#  'intern',
#  'organ',
#  'complic',
#  'difficult',
#  'yet',
#  'without',
#  'organ',
#  'right',
#  'man',
#  'earth',
#  'protect',
#  'machi',
#  'neri',
#  'settlement',
#  'intern',
#  'differ',
#  'must',
#  'found',
#  'without',
#  'machineri',
#  'entir',
#  'world',
#  'remain',
#  'arm',
#  'camp',
#  'world',
#  'doom',
#  'deadli',
#  'conflict',
#  'devoid',
#  'hope',
#  'real',
#  'peac',
#  'fortun',
#  'peopl',
#  'retain',
#  'hope',
#  'durabl',
#  'peac',
#  'thought',
#  'peopl',
#  'alway',
#  'faith',
#  'ultim',
#  'justic',
#  'must',
#  'triumph',
#  'past',
#  'experi',
#  'sure',
#  'indic',
#  'without',
#  'justic',
#  'endur',
#  'peac',
#  'becom',
#  'imposs',
#  'bitter',
#  'despair',
#  'peopl',
#  'come',
#  'believ',
#  'war',
#  'inevit',
#  'tragic',
#  'fatal',
#  'insist',
#  'war',
#  'alway',
#  'necess',
#  'necess',
#  'war',
#  'alway',
#  'defeat',
#  'men',
#  'women',
#  'good',
#  'must',
#  'yield',
#  'outlook',
#  'human',
#  'hopeless',
#  'dark',
#  'hour',
#  'horribl',
#  'war',
#  'entir',
#  'nation',
#  'kept',
#  'go',
#  'someth',
#  'warn',
#  'abject',
#  'submiss',
#  'offer',
#  'salvat',
#  'overwhelm',
#  'power',
#  'hope',
#  'show',
#  'way',
#  'victori',
#  'hope',
#  'becom',
#  'secret',
#  'weapon',
#  'forc',
#  'liber',
#  'aggressor',
#  'could',
#  'domin',
#  'human',
#  'mind',
#  'long',
#  'hope',
#  'remain',
#  'spirit',
#  'man',
#  'never',
#  'crush',
#  'hope',
#  'alon',
#  'suffici',
#  'avert',
#  'war',
#  'must',
#  'hope',
#  'must',
#  'faith',
#  'enough',
#  'work',
#  'nation',
#  'maintain',
#  'peac',
#  'hope',
#  'enough',
#  'beat',
#  'back',
#  'aggressor',
#  'long',
#  'nation',
#  'unwil',
#  'come',
#  'defens',
#  'aggressor',
#  'beaten',
#  'back',
#  'nation',
#  'unit',
#  'defend',
#  'war',
#  'futur',
#  'prevent',
#  'nation',
#  'must',
#  'unit',
#  'determin',
#  'keep',
#  'peac',
#  'law',
#  'noth',
#  'essenti',
#  'futur',
#  'peac',
#  'world',
#  'continu',
#  'cooper',
#  'nation',
#  'muster',
#  'forc',
#  'necessari',
#  'defeat',
#  'conspiraci',
#  'axi',
#  'power',
#  'domin',
#  'world',
#  'great',
#  'state',
#  'special',
#  'respons',
#  'enforc',
#  'peac',
#  'respons',
#  'base',
#  'upon',
#  'oblig',
#  'rest',
#  'upon',
#  'state',
#  'larg',
#  'small',
#  'use',
#  'forc',
#  'intern',
#  'relat',
#  'except',
#  'defens',
#  'law',
#  'respon',
#  'sibil',
#  'great',
#  'state',
#  'serv',
#  'domin',
#  'world',
#  'build',
#  'foundat',
#  'endur',
#  'peac',
#  'must',
#  'work',
#  'harmoni',
#  'friend',
#  'abroad',
#  'must',
#  'unit',
#  'support',
#  'peopl',
#  'even',
#  'experienc',
#  'pilot',
#  'bring',
#  'ship',
#  'safe',
#  'harbor',
#  'unless',
#  'full',
#  'cooper',
#  'crew',
#  'benefit',
#  'everi',
#  'individu',
#  'must',
#  'duti',
#  'appeal',
#  'everi',
#  'american',
#  'regardless',
#  'parti',
#  'race',
#  'creed',
#  'color',
#  'support',
#  'effort',
#  'build',
#  'strong',
#  'last',
#  'unit',
#  'nation',
#  'organ',
#  'member',
#  'congress',
#  'sure',
#  'know',
#  'feel',
#  'help',
#  'hope',
#  'complet',
#  'one',
#  'greatest',
#  'task',
#  'ever',
#  'assign',
#  'public',
#  'servant',
#  'divin',
#  'guidanc',
#  'help',
#  'find',
#  'new',
#  'passag',
#  'far',
#  'better',
#  'world',
#  'kindli',
#  'friendli',
#  'world',
#  'last',
#  'peac',
#  'confid',
#  'depend',
#  'upon',
#  'destroy',
#  'greedi',
#  'tyrant',
#  'dream',
#  'world',
#  'domin',
#  'continu',
#  'success',
#  'gener',
#  'sacrific',
#  'finest',
#  'youth',
#  'name',
#  'human',
#  'decenc',
#  'civil',
#  'ration',
#  'method',
#  'decid',
#  'nation',
#  'differ',
#  'must',
#  'found',
#  'america',
#  'must',
#  'assist',
#  'suffer',
#  'human',
#  'back',
#  'along',
#  'path',
#  'peac',
#  'progress',
#  'requir',
#  'time',
#  'toler',
#  'shall',
#  'need',
#  'also',
#  'abid',
#  'faith',
#  'peopl',
#  'kind',
#  'faith',
#  'courag',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'alway',
#  'today',
#  'america',
#  'becom',
#  'one',
#  'power',
#  'forc',
#  'good',
#  'earth',
#  'must',
#  'keep',
#  'achiev',
#  'world',
#  'leadership',
#  'depend',
#  'sole',
#  'upon',
#  'militari',
#  'naval',
#  'might',
#  'learn',
#  'fight',
#  'nation',
#  'common',
#  'defens',
#  'freedom',
#  'must',
#  'learn',
#  'live',
#  'nation',
#  'mutual',
#  'good',
#  'must',
#  'learn',
#  'trade',
#  'nation',
#  'may',
#  'mutual',
#  'product',
#  'ion',
#  'increas',
#  'employ',
#  'better',
#  'standard',
#  'live',
#  'throughout',
#  'world',
#  'may',
#  'american',
#  'live',
#  'gloriou',
#  'heritag',
#  'way',
#  'america',
#  'may',
#  'well',
#  'lead',
#  'world',
#  'peac',
#  'prosper',
#  'moment',
#  'heart',
#  'prayer',
#  'assum',
#  'heavi',
#  'duti',
#  'humbl',
#  'pray',
#  'almighti',
#  'god',
#  'word',
#  'king',
#  'solomon',
#  'give',
#  'therefor',
#  'thi',
#  'servant',
#  'understand',
#  'heart',
#  'judg',
#  'thi',
#  'peopl',
#  'may',
#  'discern',
#  'good',
#  'bad',
#  'abl',
#  'judg',
#  'thi',
#  'great',
#  'peopl',
#  'ask',
#  'good',
#  'faith',
#  'servant',
#  'lord',
#  'peopl']

# %% [markdown]
# “democracy” → “democraci”
#
# stems are not necessarily real words

# %% [markdown]
# ### spaCy does not include a built-in stemmer by default.
#
# This is not a limitation. It is a design choice.
#
# spaCy prioritizes:
#
# - linguistically informed processing
#
# - lemmatization over stemming
#
# However, in real pipelines, you can still perform stemming alongside spaCy.

# %%
#spaCy lemmatizer
for token in doc:
    print(f"{token} ----> {token.lemma_}")
# Out:
# PRESIDENT ----> PRESIDENT
# HARRY ----> HARRY
# S. ----> S.
# TRUMAN ----> TRUMAN
# 'S ----> 'S
# ADDRESS ----> ADDRESS
# BEFORE ----> before
# A ----> a
# JOINT ----> JOINT
# SESSION ----> session
# OF ----> of
# THE ----> the
# CONGRESS ----> CONGRESS
#
#
#  ---->
#
#
# April ----> April
# 16 ----> 16
# , ----> ,
# 1945 ----> 1945
#
#
#  ---->
#
#
# Mr. ----> Mr.
# Speaker ----> Speaker
# , ----> ,
# Mr. ----> Mr.
# President ----> President
# , ----> ,
# Members ----> Members
# of ----> of
# the ----> the
# Congress ----> Congress
# : ----> :
#
#  ---->
#
# It ----> it
# is ----> be
# with ----> with
# a ----> a
# heavy ----> heavy
# heart ----> heart
# that ----> that
# I ----> I
# stand ----> stand
# before ----> before
# you ----> you
# , ----> ,
# my ----> my
# friends ----> friend
# and ----> and
# colleagues ----> colleague
# , ----> ,
# in ----> in
# the ----> the
# Congress ----> Congress
# of ----> of
# the ----> the
# United ----> United
# States ----> States
# . ----> .
#
#  ---->
#
# Only ----> only
# yesterday ----> yesterday
# , ----> ,
# we ----> we
# laid ----> lay
# to ----> to
# rest ----> rest
# the ----> the
# mortal ----> mortal
# remains ----> remain
# of ----> of
# our ----> our
# beloved ----> beloved
# President ----> President
# , ----> ,
# Franklin ----> Franklin
# Delano ----> Delano
# Roosevelt ----> Roosevelt
# . ----> .
# At ----> at
# a ----> a
# time ----> time
# like ----> like
# this ----> this
# , ----> ,
# words ----> word
# are ----> be
# inadequate ----> inadequate
# . ----> .
# The ----> the
# most ----> most
# eloquent ----> eloquent
# tribute ----> tribute
# would ----> would
# be ----> be
# a ----> a
# reverent ----> reverent
# silence ----> silence
# . ----> .
#
#  ---->
#
# Yet ----> yet
# , ----> ,
# in ----> in
# this ----> this
# decisive ----> decisive
# hour ----> hour
# , ----> ,
# when ----> when
# world ----> world
# events ----> event
# are ----> be
# moving ----> move
# so ----> so
# rapidly ----> rapidly
# , ----> ,
# our ----> our
# silence ----> silence
# might ----> might
# be ----> be
# misunderstood ----> misunderstood
# and ----> and
# might ----> might
# give ----> give
# comfort ----> comfort
# to ----> to
# our ----> our
# enemies ----> enemy
# . ----> .
#
#  ---->
#
# In ----> in
# His ----> his
# infinite ----> infinite
# wisdom ----> wisdom
# , ----> ,
# Almighty ----> Almighty
# God ----> God
# has ----> have
# seen ----> see
# fit ----> fit
# to ----> to
# take ----> take
# from ----> from
# us ----> we
# a ----> a
# great ----> great
# man ----> man
# who ----> who
# loved ----> love
# , ----> ,
# and ----> and
# was ----> be
# beloved ----> belove
# by ----> by
# , ----> ,
# all ----> all
# humanity ----> humanity
# . ----> .
#
#  ---->
#
# No ----> no
# man ----> man
# could ----> could
# possibly ----> possibly
# fill ----> fill
# the ----> the
# tremendous ----> tremendous
# void ----> void
# left ----> leave
# by ----> by
# the ----> the
# passing ----> passing
# of ----> of
# that ----> that
# noble ----> noble
# soul ----> soul
# . ----> .
# No ----> no
# words ----> word
# can ----> can
# ease ----> ease
# the ----> the
# aching ----> aching
# hearts ----> heart
# of ----> of
# untold ----> untold
# millions ----> million
# of ----> of
# every ----> every
# race ----> race
# , ----> ,
# creed ----> creed
# and ----> and
# color ----> color
# . ----> .
# The ----> the
# world ----> world
# knows ----> know
# it ----> it
# has ----> have
# lost ----> lose
# a ----> a
# heroic ----> heroic
# champion ----> champion
# of ----> of
# justice ----> justice
# and ----> and
# freedom ----> freedom
# . ----> .
#
#  ---->
#
# Tragic ----> tragic
# fate ----> fate
# has ----> have
# thrust ----> thrust
# upon ----> upon
# us ----> us
# grave ----> grave
# responsibilities ----> responsibility
# . ----> .
# We ----> we
# must ----> must
# carry ----> carry
# on ----> on
# . ----> .
# Our ----> our
# departed ----> depart
# leader ----> leader
# never ----> never
# looked ----> look
# backward ----> backward
# . ----> .
# He ----> he
# looked ----> look
# forward ----> forward
# and ----> and
# moved ----> move
# forward ----> forward
# . ----> .
# That ----> that
# is ----> be
# what ----> what
# he ----> he
# would ----> would
# want ----> want
# us ----> we
# to ----> to
# do ----> do
# . ----> .
# That ----> that
# is ----> be
# what ----> what
# America ----> America
# will ----> will
# do ----> do
# . ----> .
#
#  ---->
#
# So ----> so
# much ----> much
# blood ----> blood
# has ----> have
# already ----> already
# been ----> be
# shed ----> shed
# for ----> for
# the ----> the
# ideals ----> ideal
# which ----> which
# we ----> we
# cherish ----> cherish
# , ----> ,
# and ----> and
# for ----> for
# which ----> which
# Franklin ----> Franklin
# Delano ----> Delano
# Roosevelt ----> Roosevelt
# lived ----> live
# and ----> and
# died ----> die
# , ----> ,
# that ----> that
# we ----> we
# dare ----> dare
# not ----> not
# permit ----> permit
# even ----> even
# a ----> a
# momentary ----> momentary
# pause ----> pause
# in ----> in
# the ----> the
# hard ----> hard
# fight ----> fight
# for ----> for
# victory ----> victory
# . ----> .
#
#  ---->
#
# Today ----> today
# , ----> ,
# the ----> the
# entire ----> entire
# world ----> world
# is ----> be
# looking ----> look
# to ----> to
# America ----> America
# for ----> for
# enlightened ----> enlightened
# leadership ----> leadership
# to ----> to
# peace ----> peace
# and ----> and
# progress ----> progress
# . ----> .
# Such ----> such
# a ----> a
# leadership ----> leadership
# requires ----> require
# vision ----> vision
# , ----> ,
# courage ----> courage
# and ----> and
# tolerance ----> tolerance
# . ----> .
# It ----> it
# can ----> can
# be ----> be
# provided ----> provide
# only ----> only
# by ----> by
# a ----> a
# united ----> united
# nation ----> nation
# deeply ----> deeply
# devoted ----> devoted
# to ----> to
# the ----> the
# highest ----> high
# ideals ----> ideal
# . ----> .
#
#  ---->
#
# With ----> with
# great ----> great
# humility ----> humility
# I ----> I
# call ----> call
# upon ----> upon
# all ----> all
# Americans ----> Americans
# to ----> to
# help ----> help
# me ----> I
# keep ----> keep
# our ----> our
# nation ----> nation
# united ----> unite
# in ----> in
# defense ----> defense
# of ----> of
# those ----> those
# ideals ----> ideal
# which ----> which
# have ----> have
# been ----> be
# so ----> so
# eloquently ----> eloquently
# proclaimed ----> proclaim
# by ----> by
# Franklin ----> Franklin
# Roosevelt ----> Roosevelt
# . ----> .
#
#  ---->
#
# I ----> I
# want ----> want
# in ----> in
# turn ----> turn
# to ----> to
# assure ----> assure
# my ----> my
# fellow ----> fellow
# Americans ----> Americans
# and ----> and
# all ----> all
# of ----> of
# those ----> those
# who ----> who
# love ----> love
# peace ----> peace
# and ----> and
# liberty ----> liberty
# throughout ----> throughout
# the ----> the
# world ----> world
# that ----> that
# I ----> I
# will ----> will
# support ----> support
# and ----> and
# defend ----> defend
# those ----> those
# ideals ----> ideal
# with ----> with
# all ----> all
# my ----> my
# strength ----> strength
# and ----> and
# all ----> all
# my ----> my
# heart ----> heart
# . ----> .
# That ----> that
# is ----> be
# my ----> my
# duty ----> duty
# and ----> and
# I ----> I
# shall ----> shall
# not ----> not
# shirk ----> shirk
# it ----> it
# . ----> .
#
#  ---->
#
# So ----> so
# that ----> that
# there ----> there
# can ----> can
# be ----> be
# no ----> no
# possible ----> possible
# misunderstanding ----> misunderstanding
# , ----> ,
# both ----> both
# Germany ----> Germany
# and ----> and
# Japan ----> Japan
# can ----> can
# be ----> be
# certain ----> certain
# , ----> ,
# beyond ----> beyond
# any ----> any
# shadow ----> shadow
# of ----> of
# a ----> a
# doubt ----> doubt
# , ----> ,
# that ----> that
# America ----> America
# will ----> will
# continue ----> continue
# the ----> the
# fight ----> fight
# for ----> for
# freedom ----> freedom
# until ----> until
# no ----> no
# vestige ----> vestige
# of ----> of
# resistance ----> resistance
# remains ----> remain
# ! ----> !
#
#  ---->
#
# We ----> we
# are ----> be
# deeply ----> deeply
# conscious ----> conscious
# of ----> of
# the ----> the
# fact ----> fact
# that ----> that
# much ----> much
# hard ----> hard
# fighting ----> fighting
# is ----> be
# still ----> still
# ahead ----> ahead
# of ----> of
# us ----> we
# . ----> .
#
#  ---->
#
# Having ----> have
# to ----> to
# pay ----> pay
# such ----> such
# a ----> a
# heavy ----> heavy
# price ----> price
# to ----> to
# make ----> make
# complete ----> complete
# victory ----> victory
# certain ----> certain
# , ----> ,
# America ----> America
# will ----> will
# never ----> never
# become ----> become
# a ----> a
# party ----> party
# to ----> to
# any ----> any
# plan ----> plan
# for ----> for
# partial ----> partial
# victory ----> victory
# ! ----> !
#
#  ---->
#
# To ----> to
# settle ----> settle
# for ----> for
# merely ----> merely
# another ----> another
# temporary ----> temporary
# respite ----> respite
# would ----> would
# surely ----> surely
# jeopardize ----> jeopardize
# the ----> the
# future ----> future
# security ----> security
# of ----> of
# all ----> all
# the ----> the
# world ----> world
# . ----> .
#
#  ---->
#
# Our ----> our
# demand ----> demand
# has ----> have
# been ----> be
# , ----> ,
# and ----> and
# it ----> it
# remains ----> remain
# - ----> -
# Unconditional ----> unconditional
# Surrender ----> Surrender
# ! ----> !
# We ----> we
# will ----> will
# not ----> not
# traffic ----> traffic
# with ----> with
# the ----> the
# breakers ----> breaker
# of ----> of
# the ----> the
# peace ----> peace
# on ----> on
# the ----> the
# terms ----> term
# of ----> of
# the ----> the
# peace ----> peace
# . ----> .
#
#  ---->
#
# The ----> the
# responsibility ----> responsibility
# for ----> for
# making ----> making
# of ----> of
# the ----> the
# peace ----> peace
# - ----> -
# and ----> and
# it ----> it
# is ----> be
# a ----> a
# very ----> very
# grave ----> grave
# responsibility ----> responsibility
# - ----> -
# must ----> must
# rest ----> rest
# with ----> with
# the ----> the
# defenders ----> defender
# of ----> of
# the ----> the
# peace ----> peace
# . ----> .
# We ----> we
# are ----> be
# not ----> not
# unconscious ----> unconscious
# of ----> of
# the ----> the
# dictates ----> dictate
# of ----> of
# humanity ----> humanity
# . ----> .
# We ----> we
# do ----> do
# not ----> not
# wish ----> wish
# to ----> to
# see ----> see
# unnecessary ----> unnecessary
# or ----> or
# unjustified ----> unjustified
# suffering ----> suffering
# . ----> .
# But ----> but
# the ----> the
# laws ----> law
# of ----> of
# Go ----> Go
# d ----> d
# and ----> and
# of ----> of
# man ----> man
# have ----> have
# been ----> be
# violated ----> violate
# and ----> and
# the ----> the
# guilty ----> guilty
# must ----> must
# not ----> not
# go ----> go
# unpunished ----> unpunished
# . ----> .
# Nothing ----> nothing
# shall ----> shall
# shake ----> shake
# our ----> our
# determination ----> determination
# to ----> to
# punish ----> punish
# the ----> the
# war ----> war
# criminals ----> criminal
# even ----> even
# though ----> though
# we ----> we
# must ----> must
# pursue ----> pursue
# them ----> they
# to ----> to
# the ----> the
# ends ----> end
# of ----> of
# the ----> the
# earth ----> earth
# . ----> .
#
#  ---->
#
# Lasting ----> last
# peace ----> peace
# can ----> can
# never ----> never
# be ----> be
# secured ----> secure
# if ----> if
# we ----> we
# permit ----> permit
# our ----> our
# dangerous ----> dangerous
# opponents ----> opponent
# to ----> to
# plot ----> plot
# future ----> future
# wars ----> war
# with ----> with
# impunity ----> impunity
# at ----> at
# any ----> any
# mountain ----> mountain
# retreat ----> retreat
# - ----> -
# however ----> however
# distant ----> distant
# . ----> .
#
#  ---->
#
# In ----> in
# this ----> this
# shrinking ----> shrink
# world ----> world
# , ----> ,
# it ----> it
# is ----> be
# futile ----> futile
# to ----> to
# seek ----> seek
# safety ----> safety
# behind ----> behind
# geographical ----> geographical
# barriers ----> barrier
# . ----> .
# Real ----> real
# security ----> security
# will ----> will
# be ----> be
# found ----> find
# only ----> only
# in ----> in
# law ----> law
# and ----> and
# in ----> in
# justice ----> justice
# . ----> .
#
#  ---->
#
# Here ----> here
# in ----> in
# America ----> America
# , ----> ,
# we ----> we
# have ----> have
# labored ----> labor
# long ----> long
# and ----> and
# hard ----> hard
# to ----> to
# achieve ----> achieve
# a ----> a
# social ----> social
# order ----> order
# worthy ----> worthy
# of ----> of
# our ----> our
# great ----> great
# heritage ----> heritage
# . ----> .
# In ----> in
# our ----> our
# time ----> time
# , ----> ,
# tremendous ----> tremendous
# progress ----> progress
# has ----> have
# been ----> be
# made ----> make
# toward ----> toward
# a ----> a
# really ----> really
# democratic ----> democratic
# way ----> way
# of ----> of
# life ----> life
# . ----> .
# Let ----> let
# me ----> I
# assure ----> assure
# the ----> the
# forward ----> forward
# - ----> -
# looking ----> look
# people ----> people
# of ----> of
# America ----> America
# that ----> that
# there ----> there
# w ----> w
# ill ----> ill
# be ----> be
# no ----> no
# relaxation ----> relaxation
# in ----> in
# our ----> our
# efforts ----> effort
# to ----> to
# improve ----> improve
# the ----> the
# lot ----> lot
# of ----> of
# the ----> the
# common ----> common
# people ----> people
# . ----> .
#
#  ---->
#
# In ----> in
# the ----> the
# difficult ----> difficult
# days ----> day
# ahead ----> ahead
# , ----> ,
# unquestionably ----> unquestionably
# we ----> we
# shall ----> shall
# face ----> face
# problems ----> problem
# of ----> of
# staggering ----> staggering
# proportions ----> proportion
# . ----> .
# However ----> however
# , ----> ,
# with ----> with
# the ----> the
# faith ----> faith
# of ----> of
# our ----> our
# fathers ----> father
# in ----> in
# our ----> our
# hearts ----> heart
# , ----> ,
# we ----> we
# do ----> do
# not ----> not
# fear ----> fear
# the ----> the
# future ----> future
# . ----> .
#
#  ---->
#
# On ----> on
# the ----> the
# battlefields ----> battlefield
# , ----> ,
# we ----> we
# have ----> have
# frequently ----> frequently
# faced ----> face
# overwhelming ----> overwhelming
# odds ----> odd
# - ----> -
# and ----> and
# won ----> win
# ! ----> !
# At ----> at
# home ----> home
# , ----> ,
# Americans ----> Americans
# will ----> will
# not ----> not
# be ----> be
# less ----> less
# resolute ----> resolute
# ! ----> !
# We ----> we
# shall ----> shall
# never ----> never
# cease ----> cease
# our ----> our
# struggle ----> struggle
# to ----> to
# preserve ----> preserve
# and ----> and
# maintain ----> maintain
# our ----> our
# American ----> american
# way ----> way
# of ----> of
# life ----> life
# . ----> .
#
#  ---->
#
# At ----> at
# this ----> this
# moment ----> moment
# , ----> ,
# America ----> America
# , ----> ,
# along ----> along
# with ----> with
# her ----> her
# brave ----> brave
# Allies ----> Allies
# , ----> ,
# is ----> be
# paying ----> pay
# again ----> again
# a ----> a
# heavy ----> heavy
# price ----> price
# for ----> for
# the ----> the
# defense ----> defense
# of ----> of
# our ----> our
# freedom ----> freedom
# . ----> .
# With ----> with
# characteristic ----> characteristic
# energy ----> energy
# , ----> ,
# we ----> we
# are ----> be
# assisting ----> assist
# in ----> in
# the ----> the
# liberation ----> liberation
# of ----> of
# entire ----> entire
# nations ----> nation
# . ----> .
# Gradually ----> gradually
# , ----> ,
# the ----> the
# shackles ----> shackle
# of ----> of
# slavery ----> slavery
# are ----> be
# being ----> be
# broken ----> break
# by ----> by
# t ----> t
# he ----> he
# forces ----> force
# of ----> of
# freedom ----> freedom
# . ----> .
#
#  ---->
#
# All ----> all
# of ----> of
# us ----> we
# are ----> be
# praying ----> pray
# for ----> for
# a ----> a
# speedy ----> speedy
# victory ----> victory
# . ----> .
# Every ----> every
# day ----> day
# peace ----> peace
# is ----> be
# delayed ----> delay
# costs ----> cost
# a ----> a
# terrible ----> terrible
# toll ----> toll
# . ----> .
#
#  ---->
#
# The ----> the
# armies ----> army
# of ----> of
# liberation ----> liberation
# today ----> today
# are ----> be
# bringing ----> bring
# to ----> to
# an ----> an
# end ----> end
# Hitler ----> Hitler
# 's ----> 's
# ghastly ----> ghastly
# threat ----> threat
# to ----> to
# dominate ----> dominate
# the ----> the
# world ----> world
# . ----> .
# Tokyo ----> Tokyo
# rocks ----> rock
# under ----> under
# the ----> the
# weight ----> weight
# of ----> of
# our ----> our
# bombs ----> bomb
# . ----> .
#
#  ---->
#
# The ----> the
# grand ----> grand
# strategy ----> strategy
# of ----> of
# the ----> the
# United ----> United
# Nations ----> Nations
# ' ----> '
# war ----> war
# has ----> have
# been ----> be
# determined ----> determine
# - ----> -
# due ----> due
# in ----> in
# no ----> no
# small ----> small
# measure ----> measure
# to ----> to
# the ----> the
# vision ----> vision
# of ----> of
# our ----> our
# departed ----> depart
# Commander ----> Commander
# in ----> in
# Chief ----> Chief
# . ----> .
# We ----> we
# are ----> be
# now ----> now
# carrying ----> carry
# out ----> out
# our ----> our
# part ----> part
# of ----> of
# that ----> that
# strategy ----> strategy
# under ----> under
# the ----> the
# able ----> able
# direction ----> direction
# of ----> of
# Admiral ----> Admiral
# Leahy ----> Leahy
# , ----> ,
# General ----> General
# Marshall ----> Marshall
# , ----> ,
# A ----> a
# dmiral ----> dmiral
# King ----> king
# , ----> ,
# General ----> General
# Arnold ----> Arnold
# , ----> ,
# General ----> General
# Eisenhower ----> Eisenhower
# , ----> ,
# Admiral ----> Admiral
# Nimitz ----> Nimitz
# and ----> and
# General ----> General
# MacArthur ----> MacArthur
# . ----> .
#
#  ---->
#
# I ----> I
# want ----> want
# the ----> the
# entire ----> entire
# world ----> world
# to ----> to
# know ----> know
# that ----> that
# this ----> this
# direction ----> direction
# must ----> must
# and ----> and
# will ----> will
# remain ----> remain
# - ----> -
# unchanged ----> unchanged
# and ----> and
# unhampered ----> unhampered
# ! ----> !
#
#  ---->
#
# Our ----> our
# debt ----> debt
# to ----> to
# the ----> the
# heroic ----> heroic
# men ----> man
# and ----> and
# valiant ----> valiant
# women ----> woman
# in ----> in
# the ----> the
# service ----> service
# of ----> of
# our ----> our
# country ----> country
# can ----> can
# never ----> never
# be ----> be
# repaid ----> repay
# . ----> .
# They ----> they
# have ----> have
# earned ----> earn
# our ----> our
# undying ----> undying
# gratitude ----> gratitude
# . ----> .
# America ----> America
# will ----> will
# never ----> never
# forget ----> forget
# their ----> their
# sacrifices ----> sacrifice
# . ----> .
# Because ----> because
# of ----> of
# these ----> these
# sacrifices ----> sacrifice
# , ----> ,
# the ----> the
# dawn ----> dawn
# of ----> of
# justice ----> justice
# and ----> and
# freedom ----> freedom
# throughout ----> throughout
# th ----> th
# e ----> e
# world ----> world
# slowly ----> slowly
# casts ----> cast
# its ----> its
# gleam ----> gleam
# across ----> across
# the ----> the
# horizon ----> horizon
# . ----> .
#
#  ---->
#
# Our ----> our
# forefathers ----> forefather
# came ----> come
# to ----> to
# our ----> our
# rugged ----> rugged
# shores ----> shore
# in ----> in
# search ----> search
# of ----> of
# religious ----> religious
# tolerance ----> tolerance
# , ----> ,
# political ----> political
# freedom ----> freedom
# and ----> and
# economic ----> economic
# opportunity ----> opportunity
# . ----> .
# For ----> for
# those ----> those
# fundamental ----> fundamental
# rights ----> right
# , ----> ,
# they ----> they
# risked ----> risk
# their ----> their
# lives ----> life
# . ----> .
# We ----> we
# well ----> well
# know ----> know
# today ----> today
# that ----> that
# such ----> such
# rights ----> right
# can ----> can
# be ----> be
# preserved ----> preserve
# only ----> only
# by ----> by
# constant ----> constant
# vigilance ----> vigilance
# , ----> ,
# the ----> the
# eternal ----> eternal
# price ----> price
# of ----> of
# liberty ----> liberty
# ! ----> !
#
#  ---->
#
# Within ----> within
# an ----> an
# hour ----> hour
# after ----> after
# I ----> I
# took ----> take
# the ----> the
# oath ----> oath
# of ----> of
# office ----> office
# , ----> ,
# I ----> I
# announced ----> announce
# that ----> that
# the ----> the
# San ----> San
# Francisco ----> Francisco
# Conference ----> Conference
# would ----> would
# proceed ----> proceed
# . ----> .
# We ----> we
# will ----> will
# face ----> face
# the ----> the
# problems ----> problem
# of ----> of
# peace ----> peace
# with ----> with
# the ----> the
# same ----> same
# courage ----> courage
# that ----> that
# we ----> we
# have ----> have
# faced ----> face
# and ----> and
# mastered ----> master
# the ----> the
# problems ----> problem
# of ----> of
# war ----> war
# . ----> .
#
#  ---->
#
# In ----> in
# the ----> the
# memory ----> memory
# of ----> of
# those ----> those
# who ----> who
# have ----> have
# made ----> make
# the ----> the
# supreme ----> supreme
# sacrifice ----> sacrifice
# - ----> -
# in ----> in
# the ----> the
# memory ----> memory
# of ----> of
# our ----> our
# fallen ----> fallen
# President ----> President
# - ----> -
# we ----> we
# shall ----> shall
# not ----> not
# fail ----> fail
# ! ----> !
#
#  ---->
#
# It ----> it
# is ----> be
# not ----> not
# enough ----> enough
# to ----> to
# yearn ----> yearn
# for ----> for
# peace ----> peace
# . ----> .
# We ----> we
# must ----> must
# work ----> work
# , ----> ,
# and ----> and
# if ----> if
# necessary ----> necessary
# , ----> ,
# fight ----> fight
# for ----> for
# it ----> it
# . ----> .
# The ----> the
# task ----> task
# of ----> of
# creating ----> create
# a ----> a
# sound ----> sound
# international ----> international
# organization ----> organization
# is ----> be
# complicated ----> complicated
# and ----> and
# difficult ----> difficult
# . ----> .
# Yet ----> yet
# , ----> ,
# without ----> without
# such ----> such
# organization ----> organization
# , ----> ,
# the ----> the
# rights ----> right
# of ----> of
# man ----> man
# on ----> on
# earth ----> earth
# can ----> can
# not ----> not
# be ----> be
# protected ----> protect
# . ----> .
# Machi ----> Machi
# nery ----> nery
# for ----> for
# the ----> the
# just ----> just
# settlement ----> settlement
# of ----> of
# international ----> international
# differences ----> difference
# must ----> must
# be ----> be
# found ----> find
# . ----> .
# Without ----> without
# such ----> such
# machinery ----> machinery
# , ----> ,
# the ----> the
# entire ----> entire
# world ----> world
# will ----> will
# have ----> have
# to ----> to
# remain ----> remain
# an ----> an
# armed ----> armed
# camp ----> camp
# . ----> .
# The ----> the
# world ----> world
# will ----> will
# be ----> be
# doomed ----> doom
# to ----> to
# deadly ----> deadly
# conflict ----> conflict
# , ----> ,
# devoid ----> devoid
# of ----> of
# hope ----> hope
# for ----> for
# real ----> real
# peace ----> peace
# . ----> .
#
#  ---->
#
# Fortunately ----> fortunately
# , ----> ,
# people ----> people
# have ----> have
# retained ----> retain
# hope ----> hope
# for ----> for
# a ----> a
# durable ----> durable
# peace ----> peace
# . ----> .
# Thoughtful ----> thoughtful
# people ----> people
# have ----> have
# always ----> always
# had ----> have
# faith ----> faith
# that ----> that
# ultimately ----> ultimately
# justice ----> justice
# must ----> must
# triumph ----> triumph
# . ----> .
# Past ----> past
# experience ----> experience
# surely ----> surely
# indicates ----> indicate
# that ----> that
# , ----> ,
# without ----> without
# justice ----> justice
# , ----> ,
# an ----> an
# enduring ----> endure
# peace ----> peace
# becomes ----> become
# impossible ----> impossible
# . ----> .
#
#  ---->
#
# In ----> in
# bitter ----> bitter
# despair ----> despair
# , ----> ,
# some ----> some
# people ----> people
# have ----> have
# come ----> come
# to ----> to
# believe ----> believe
# that ----> that
# wars ----> war
# are ----> be
# inevitable ----> inevitable
# . ----> .
# With ----> with
# tragic ----> tragic
# fatalism ----> fatalism
# , ----> ,
# they ----> they
# insist ----> insist
# that ----> that
# wars ----> war
# have ----> have
# always ----> always
# been ----> be
# , ----> ,
# of ----> of
# necessity ----> necessity
# , ----> ,
# and ----> and
# of ----> of
# necessity ----> necessity
# wars ----> war
# always ----> always
# will ----> will
# be ----> be
# . ----> .
# To ----> to
# such ----> such
# defeatism ----> defeatism
# , ----> ,
# men ----> man
# and ----> and
# women ----> woman
# of ----> of
# good ----> good
# will ----> will
# must ----> must
# not ----> not
# and ----> and
# can ----> can
# not ----> not
# yield ----> yield
# . ----> .
# The ----> the
# outlook ----> outlook
# for ----> for
# humanity ----> humanity
# is ----> be
# not ----> not
# so ----> so
# hopeless ----> hopeless
# . ----> .
#
#  ---->
#
# During ----> during
# the ----> the
# dark ----> dark
# hours ----> hour
# of ----> of
# this ----> this
# horrible ----> horrible
# war ----> war
# , ----> ,
# entire ----> entire
# nations ----> nation
# were ----> be
# kept ----> keep
# going ----> go
# by ----> by
# something ----> something
# intangible ----> intangible
# - ----> -
# hope ----> hope
# ! ----> !
# When ----> when
# warned ----> warn
# that ----> that
# abject ----> abject
# submission ----> submission
# offered ----> offer
# the ----> the
# only ----> only
# salvation ----> salvation
# against ----> against
# overwhelming ----> overwhelming
# power ----> power
# , ----> ,
# hope ----> hope
# showed ----> show
# the ----> the
# way ----> way
# to ----> to
# victory ----> victory
# . ----> .
#
#  ---->
#
# Hope ----> Hope
# has ----> have
# become ----> become
# the ----> the
# secret ----> secret
# weapon ----> weapon
# of ----> of
# the ----> the
# forces ----> force
# of ----> of
# liberation ----> liberation
# ! ----> !
#
#  ---->
#
# Aggressors ----> aggressor
# could ----> could
# not ----> not
# dominate ----> dominate
# the ----> the
# human ----> human
# mind ----> mind
# . ----> .
# As ----> as
# long ----> long
# as ----> as
# hope ----> hope
# remains ----> remain
# , ----> ,
# the ----> the
# spirit ----> spirit
# of ----> of
# man ----> man
# will ----> will
# never ----> never
# be ----> be
# crushed ----> crush
# . ----> .
#
#  ---->
#
# But ----> but
# hope ----> hope
# alone ----> alone
# was ----> be
# not ----> not
# and ----> and
# is ----> be
# not ----> not
# sufficient ----> sufficient
# to ----> to
# avert ----> avert
# war ----> war
# . ----> .
# We ----> we
# must ----> must
# not ----> not
# only ----> only
# have ----> have
# hope ----> hope
# but ----> but
# we ----> we
# must ----> must
# have ----> have
# faith ----> faith
# enough ----> enough
# to ----> to
# work ----> work
# with ----> with
# other ----> other
# peace ----> peace
# - ----> -
# loving ----> love
# nations ----> nation
# to ----> to
# maintain ----> maintain
# the ----> the
# peace ----> peace
# . ----> .
# Hope ----> Hope
# was ----> be
# not ----> not
# enough ----> enough
# to ----> to
# beat ----> beat
# back ----> back
# the ----> the
# aggressors ----> aggressor
# as ----> as
# long ----> long
# as ----> as
# the ----> the
# peace ----> peace
# - ----> -
# loving ----> love
# nations ----> nation
# were ----> be
# unwilling ----> unwilling
# to ----> to
# come ----> come
# to ----> to
# each ----> each
# other ----> other
# 's ----> 's
# defense ----> defense
# . ----> .
# The ----> the
# aggressors ----> aggressor
# were ----> be
# beaten ----> beat
# back ----> back
# only ----> only
# when ----> when
# the ----> the
# peace ----> peace
# - ----> -
# loving ----> love
# nations ----> nation
# united ----> unite
# to ----> to
# defend ----> defend
# themselves ----> themselves
# . ----> .
#
#  ---->
#
# If ----> if
# wars ----> war
# in ----> in
# the ----> the
# future ----> future
# are ----> be
# to ----> to
# be ----> be
# prevented ----> prevent
# the ----> the
# nations ----> nation
# must ----> must
# be ----> be
# united ----> unite
# in ----> in
# their ----> their
# determination ----> determination
# to ----> to
# keep ----> keep
# the ----> the
# peace ----> peace
# under ----> under
# law ----> law
# . ----> .
#
#  ---->
#
# Nothing ----> nothing
# is ----> be
# more ----> more
# essential ----> essential
# to ----> to
# the ----> the
# future ----> future
# peace ----> peace
# of ----> of
# the ----> the
# world ----> world
# than ----> than
# continued ----> continue
# cooperation ----> cooperation
# of ----> of
# the ----> the
# nations ----> nation
# which ----> which
# had ----> have
# to ----> to
# muster ----> muster
# the ----> the
# force ----> force
# necessary ----> necessary
# to ----> to
# defeat ----> defeat
# the ----> the
# conspiracy ----> conspiracy
# of ----> of
# the ----> the
# Axis ----> Axis
# powers ----> power
# to ----> to
# dominate ----> dominate
# the ----> the
# world ----> world
# . ----> .
#
#  ---->
#
# While ----> while
# these ----> these
# great ----> great
# states ----> state
# have ----> have
# a ----> a
# special ----> special
# responsibility ----> responsibility
# to ----> to
# enforce ----> enforce
# the ----> the
# peace ----> peace
# , ----> ,
# their ----> their
# responsibility ----> responsibility
# is ----> be
# based ----> base
# upon ----> upon
# the ----> the
# obligations ----> obligation
# resting ----> rest
# upon ----> upon
# all ----> all
# states ----> state
# , ----> ,
# large ----> large
# and ----> and
# small ----> small
# , ----> ,
# not ----> not
# to ----> to
# use ----> use
# force ----> force
# in ----> in
# international ----> international
# relations ----> relation
# except ----> except
# in ----> in
# the ----> the
# defense ----> defense
# of ----> of
# law ----> law
# . ----> .
# The ----> the
# respon ----> respon
# sibility ----> sibility
# of ----> of
# the ----> the
# great ----> great
# states ----> state
# is ----> be
# to ----> to
# serve ----> serve
# and ----> and
# not ----> not
# to ----> to
# dominate ----> dominate
# the ----> the
# world ----> world
# . ----> .
#
#  ---->
#
# To ----> to
# build ----> build
# a ----> a
# foundation ----> foundation
# of ----> of
# enduring ----> endure
# peace ----> peace
# we ----> we
# must ----> must
# not ----> not
# only ----> only
# work ----> work
# in ----> in
# harmony ----> harmony
# with ----> with
# our ----> our
# friends ----> friend
# abroad ----> abroad
# , ----> ,
# but ----> but
# we ----> we
# must ----> must
# have ----> have
# the ----> the
# united ----> united
# support ----> support
# of ----> of
# our ----> our
# own ----> own
# people ----> people
# . ----> .
#
#  ---->
#
# Even ----> even
# the ----> the
# most ----> most
# experienced ----> experienced
# pilot ----> pilot
# can ----> can
# not ----> not
# bring ----> bring
# a ----> a
# ship ----> ship
# safely ----> safely
# into ----> into
# harbor ----> harbor
# , ----> ,
# unless ----> unless
# he ----> he
# has ----> have
# the ----> the
# full ----> full
# cooperation ----> cooperation
# of ----> of
# the ----> the
# crew ----> crew
# . ----> .
# For ----> for
# the ----> the
# benefit ----> benefit
# of ----> of
# all ----> all
# , ----> ,
# every ----> every
# individual ----> individual
# must ----> must
# do ----> do
# his ----> his
# duty ----> duty
# . ----> .
#
#  ---->
#
# I ----> I
# appeal ----> appeal
# to ----> to
# every ----> every
# American ----> American
# , ----> ,
# regardless ----> regardless
# of ----> of
# party ----> party
# , ----> ,
# race ----> race
# , ----> ,
# creed ----> creed
# , ----> ,
# or ----> or
# color ----> color
# , ----> ,
# to ----> to
# support ----> support
# our ----> our
# efforts ----> effort
# to ----> to
# build ----> build
# a ----> a
# strong ----> strong
# and ----> and
# lasting ----> last
# United ----> United
# Nations ----> Nations
# Organization ----> Organization
# . ----> .
#
#  ---->
#
# You ----> you
# , ----> ,
# the ----> the
# Members ----> Members
# of ----> of
# the ----> the
# Congress ----> Congress
# , ----> ,
# surely ----> surely
# know ----> know
# how ----> how
# I ----> I
# feel ----> feel
# . ----> .
# Only ----> only
# with ----> with
# your ----> your
# help ----> help
# can ----> can
# I ----> I
# hope ----> hope
# to ----> to
# complete ----> complete
# one ----> one
# of ----> of
# the ----> the
# greatest ----> great
# tasks ----> task
# ever ----> ever
# assigned ----> assign
# to ----> to
# a ----> a
# public ----> public
# servant ----> servant
# . ----> .
# With ----> with
# Divine ----> Divine
# guidance ----> guidance
# , ----> ,
# and ----> and
# your ----> your
# help ----> help
# , ----> ,
# we ----> we
# will ----> will
# find ----> find
# the ----> the
# new ----> new
# passage ----> passage
# to ----> to
# a ----> a
# far ----> far
# better ----> well
# world ----> world
# , ----> ,
# a ----> a
# kindly ----> kindly
# and ----> and
# friendly ----> friendly
# world ----> world
# , ----> ,
# with ----> with
# just ----> just
# and ----> and
# lasting ----> last
# peace ----> peace
# . ----> .
#
#  ---->
#
# With ----> with
# confidence ----> confidence
# , ----> ,
# I ----> I
# am ----> be
# depending ----> depend
# upon ----> upon
# all ----> all
# of ----> of
# you ----> you
# . ----> .
#
#  ---->
#
# To ----> to
# destroy ----> destroy
# greedy ----> greedy
# tyrants ----> tyrant
# with ----> with
# dreams ----> dream
# of ----> of
# world ----> world
# domination ----> domination
# , ----> ,
# we ----> we
# can ----> can
# not ----> not
# continue ----> continue
# in ----> in
# successive ----> successive
# generations ----> generation
# to ----> to
# sacrifice ----> sacrifice
# our ----> our
# finest ----> fine
# youth ----> youth
# . ----> .
#
#  ---->
#
# In ----> in
# the ----> the
# name ----> name
# of ----> of
# human ----> human
# decency ----> decency
# and ----> and
# civilization ----> civilization
# , ----> ,
# a ----> a
# more ----> more
# rational ----> rational
# method ----> method
# of ----> of
# deciding ----> decide
# national ----> national
# differences ----> difference
# must ----> must
# and ----> and
# will ----> will
# be ----> be
# found ----> find
# ! ----> !
#
#  ---->
#
# America ----> America
# must ----> must
# assist ----> assist
# suffering ----> suffer
# humanity ----> humanity
# back ----> back
# along ----> along
# the ----> the
# path ----> path
# of ----> of
# peaceful ----> peaceful
# progress ----> progress
# . ----> .
# This ----> this
# will ----> will
# require ----> require
# time ----> time
# and ----> and
# tolerance ----> tolerance
# . ----> .
# We ----> we
# shall ----> shall
# need ----> need
# also ----> also
# an ----> an
# abiding ----> abide
# faith ----> faith
# in ----> in
# the ----> the
# people ----> people
# , ----> ,
# the ----> the
# kind ----> kind
# of ----> of
# faith ----> faith
# and ----> and
# courage ----> courage
# which ----> which
# Franklin ----> Franklin
# Delano ----> Delano
# Roosevelt ----> Roosevelt
# always ----> always
# had ----> have
# ! ----> !
#
#  ---->
#
# Today ----> today
# , ----> ,
# America ----> America
# has ----> have
# become ----> become
# one ----> one
# of ----> of
# the ----> the
# most ----> most
# powerful ----> powerful
# forces ----> force
# for ----> for
# good ----> good
# on ----> on
# earth ----> earth
# . ----> .
# We ----> we
# must ----> must
# keep ----> keep
# it ----> it
# so ----> so
# . ----> .
# We ----> we
# have ----> have
# achieved ----> achieve
# a ----> a
# world ----> world
# leadership ----> leadership
# which ----> which
# does ----> do
# not ----> not
# depend ----> depend
# solely ----> solely
# upon ----> upon
# our ----> our
# military ----> military
# and ----> and
# naval ----> naval
# might ----> might
# . ----> .
#
#  ---->
#
# We ----> we
# have ----> have
# learned ----> learn
# to ----> to
# fight ----> fight
# with ----> with
# other ----> other
# nations ----> nation
# in ----> in
# common ----> common
# defense ----> defense
# of ----> of
# our ----> our
# freedom ----> freedom
# . ----> .
# We ----> we
# must ----> must
# now ----> now
# learn ----> learn
# to ----> to
# live ----> live
# with ----> with
# other ----> other
# nations ----> nation
# for ----> for
# our ----> our
# mutual ----> mutual
# good ----> good
# . ----> .
# We ----> we
# must ----> must
# learn ----> learn
# to ----> to
# trade ----> trade
# more ----> more
# with ----> with
# other ----> other
# nations ----> nation
# so ----> so
# that ----> that
# there ----> there
# may ----> may
# be ----> be
# - ----> -
# for ----> for
# our ----> our
# mutual ----> mutual
# advantage ----> advantage
# - ----> -
# increased ----> increase
# product ----> product
# ion ----> ion
# , ----> ,
# increased ----> increase
# employment ----> employment
# and ----> and
# better ----> well
# standards ----> standard
# of ----> of
# living ----> live
# throughout ----> throughout
# the ----> the
# world ----> world
# . ----> .
#
#  ---->
#
# May ----> may
# we ----> we
# Americans ----> Americans
# all ----> all
# live ----> live
# up ----> up
# to ----> to
# our ----> our
# glorious ----> glorious
# heritage ----> heritage
# . ----> .
#
#  ---->
#
# In ----> in
# that ----> that
# way ----> way
# , ----> ,
# America ----> America
# may ----> may
# well ----> well
# lead ----> lead
# the ----> the
# world ----> world
# to ----> to
# peace ----> peace
# and ----> and
# prosperity ----> prosperity
# . ----> .
#
#  ---->
#
# At ----> at
# this ----> this
# moment ----> moment
# , ----> ,
# I ----> I
# have ----> have
# in ----> in
# my ----> my
# heart ----> heart
# a ----> a
# prayer ----> prayer
# . ----> .
# As ----> as
# I ----> I
# have ----> have
# assumed ----> assume
# my ----> my
# heavy ----> heavy
# duties ----> duty
# , ----> ,
# I ----> I
# humbly ----> humbly
# pray ----> pray
# Almighty ----> Almighty
# God ----> God
# , ----> ,
# in ----> in
# the ----> the
# words ----> word
# of ----> of
# King ----> King
# Solomon ----> Solomon
# : ----> :
#
#  ---->
#
# " ----> "
# Give ----> give
# therefore ----> therefore
# thy ----> thy
# servant ----> servant
# an ----> an
# understanding ----> understanding
# heart ----> heart
# to ----> to
# judge ----> judge
# thy ----> thy
# people ----> people
# , ----> ,
# that ----> that
# I ----> I
# may ----> may
# discern ----> discern
# between ----> between
# good ----> good
# and ----> and
# bad ----> bad
# ; ----> ;
# for ----> for
# who ----> who
# is ----> be
# able ----> able
# to ----> to
# judge ----> judge
# this ----> this
# thy ----> thy
# so ----> so
# great ----> great
# a ----> a
# people ----> people
# ? ----> ?
# " ----> "
#
#  ---->
#
# I ----> I
# ask ----> ask
# only ----> only
# to ----> to
# be ----> be
# a ----> a
# good ----> good
# and ----> and
# faithful ----> faithful
# servant ----> servant
# of ----> of
# my ----> my
# Lord ----> Lord
# and ----> and
# my ----> my
# people ----> people
# . ----> .
#
#  ---->

# %% [markdown]
# NLTK does support lemmatization, but it requires:
#
# - a lemmatizer
#
# - part-of-speech information to work well
#
# By default, NLTK’s lemmatizer assumes nouns

# %%
#NLTK lemmatizer (default)
from nltk.stem import WordNetLemmatizer

nltk.download('punkt_tab')      
nltk.download('wordnet')    
nltk.download('omw-1.4') 
nltk.download('averaged_perceptron_tagger_eng') 

lemmatizer = WordNetLemmatizer()
nltk_def_lemma = [lemmatizer.lemmatize(token) for token in tokens_nltk]

for i in range(len(nltk_def_lemma)):
    print(f"{tokens_nltk[i]} -----> {nltk_def_lemma[i]}")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# PRESIDENT -----> PRESIDENT
# HARRY -----> HARRY
# S. -----> S.
# TRUMAN -----> TRUMAN
# 'S -----> 'S
# ADDRESS -----> ADDRESS
# BEFORE -----> BEFORE
# A -----> A
# JOINT -----> JOINT
# SESSION -----> SESSION
# OF -----> OF
# THE -----> THE
# CONGRESS -----> CONGRESS
# April -----> April
# 16 -----> 16
# , -----> ,
# 1945 -----> 1945
# Mr. -----> Mr.
# Speaker -----> Speaker
# , -----> ,
# Mr. -----> Mr.
# President -----> President
# , -----> ,
# Members -----> Members
# of -----> of
# the -----> the
# Congress -----> Congress
# : -----> :
# It -----> It
# is -----> is
# with -----> with
# a -----> a
# heavy -----> heavy
# heart -----> heart
# that -----> that
# I -----> I
# stand -----> stand
# before -----> before
# you -----> you
# , -----> ,
# my -----> my
# friends -----> friend
# and -----> and
# colleagues -----> colleague
# , -----> ,
# in -----> in
# the -----> the
# Congress -----> Congress
# of -----> of
# the -----> the
# United -----> United
# States -----> States
# . -----> .
# Only -----> Only
# yesterday -----> yesterday
# , -----> ,
# we -----> we
# laid -----> laid
# to -----> to
# rest -----> rest
# the -----> the
# mortal -----> mortal
# remains -----> remains
# of -----> of
# our -----> our
# beloved -----> beloved
# President -----> President
# , -----> ,
# Franklin -----> Franklin
# Delano -----> Delano
# Roosevelt -----> Roosevelt
# . -----> .
# At -----> At
# a -----> a
# time -----> time
# like -----> like
# this -----> this
# , -----> ,
# words -----> word
# are -----> are
# inadequate -----> inadequate
# . -----> .
# The -----> The
# most -----> most
# eloquent -----> eloquent
# tribute -----> tribute
# would -----> would
# be -----> be
# a -----> a
# reverent -----> reverent
# silence -----> silence
# . -----> .
# Yet -----> Yet
# , -----> ,
# in -----> in
# this -----> this
# decisive -----> decisive
# hour -----> hour
# , -----> ,
# when -----> when
# world -----> world
# events -----> event
# are -----> are
# moving -----> moving
# so -----> so
# rapidly -----> rapidly
# , -----> ,
# our -----> our
# silence -----> silence
# might -----> might
# be -----> be
# misunderstood -----> misunderstood
# and -----> and
# might -----> might
# give -----> give
# comfort -----> comfort
# to -----> to
# our -----> our
# enemies -----> enemy
# . -----> .
# In -----> In
# His -----> His
# infinite -----> infinite
# wisdom -----> wisdom
# , -----> ,
# Almighty -----> Almighty
# God -----> God
# has -----> ha
# seen -----> seen
# fit -----> fit
# to -----> to
# take -----> take
# from -----> from
# us -----> u
# a -----> a
# great -----> great
# man -----> man
# who -----> who
# loved -----> loved
# , -----> ,
# and -----> and
# was -----> wa
# beloved -----> beloved
# by -----> by
# , -----> ,
# all -----> all
# humanity -----> humanity
# . -----> .
# No -----> No
# man -----> man
# could -----> could
# possibly -----> possibly
# fill -----> fill
# the -----> the
# tremendous -----> tremendous
# void -----> void
# left -----> left
# by -----> by
# the -----> the
# passing -----> passing
# of -----> of
# that -----> that
# noble -----> noble
# soul -----> soul
# . -----> .
# No -----> No
# words -----> word
# can -----> can
# ease -----> ease
# the -----> the
# aching -----> aching
# hearts -----> heart
# of -----> of
# untold -----> untold
# millions -----> million
# of -----> of
# every -----> every
# race -----> race
# , -----> ,
# creed -----> creed
# and -----> and
# color -----> color
# . -----> .
# The -----> The
# world -----> world
# knows -----> know
# it -----> it
# has -----> ha
# lost -----> lost
# a -----> a
# heroic -----> heroic
# champion -----> champion
# of -----> of
# justice -----> justice
# and -----> and
# freedom -----> freedom
# . -----> .
# Tragic -----> Tragic
# fate -----> fate
# has -----> ha
# thrust -----> thrust
# upon -----> upon
# us -----> u
# grave -----> grave
# responsibilities -----> responsibility
# . -----> .
# We -----> We
# must -----> must
# carry -----> carry
# on.Our -----> on.Our
# departed -----> departed
# leader -----> leader
# never -----> never
# looked -----> looked
# backward -----> backward
# . -----> .
# He -----> He
# looked -----> looked
# forward -----> forward
# and -----> and
# moved -----> moved
# forward -----> forward
# . -----> .
# That -----> That
# is -----> is
# what -----> what
# he -----> he
# would -----> would
# want -----> want
# us -----> u
# to -----> to
# do -----> do
# . -----> .
# That -----> That
# is -----> is
# what -----> what
# America -----> America
# will -----> will
# do -----> do
# . -----> .
# So -----> So
# much -----> much
# blood -----> blood
# has -----> ha
# already -----> already
# been -----> been
# shed -----> shed
# for -----> for
# the -----> the
# ideals -----> ideal
# which -----> which
# we -----> we
# cherish -----> cherish
# , -----> ,
# and -----> and
# for -----> for
# which -----> which
# Franklin -----> Franklin
# Delano -----> Delano
# Roosevelt -----> Roosevelt
# lived -----> lived
# and -----> and
# died -----> died
# , -----> ,
# that -----> that
# we -----> we
# dare -----> dare
# not -----> not
# permit -----> permit
# even -----> even
# a -----> a
# momentary -----> momentary
# pause -----> pause
# in -----> in
# the -----> the
# hard -----> hard
# fight -----> fight
# for -----> for
# victory -----> victory
# . -----> .
# Today -----> Today
# , -----> ,
# the -----> the
# entire -----> entire
# world -----> world
# is -----> is
# looking -----> looking
# to -----> to
# America -----> America
# for -----> for
# enlightened -----> enlightened
# leadership -----> leadership
# to -----> to
# peace -----> peace
# and -----> and
# progress -----> progress
# . -----> .
# Such -----> Such
# a -----> a
# leadership -----> leadership
# requires -----> requires
# vision -----> vision
# , -----> ,
# courage -----> courage
# and -----> and
# tolerance -----> tolerance
# . -----> .
# It -----> It
# can -----> can
# be -----> be
# provided -----> provided
# only -----> only
# by -----> by
# a -----> a
# united -----> united
# nation -----> nation
# deeply -----> deeply
# devoted -----> devoted
# to -----> to
# the -----> the
# highest -----> highest
# ideals -----> ideal
# . -----> .
# With -----> With
# great -----> great
# humility -----> humility
# I -----> I
# call -----> call
# upon -----> upon
# all -----> all
# Americans -----> Americans
# to -----> to
# help -----> help
# me -----> me
# keep -----> keep
# our -----> our
# nation -----> nation
# united -----> united
# in -----> in
# defense -----> defense
# of -----> of
# those -----> those
# ideals -----> ideal
# which -----> which
# have -----> have
# been -----> been
# so -----> so
# eloquently -----> eloquently
# proclaimed -----> proclaimed
# by -----> by
# Franklin -----> Franklin
# Roosevelt -----> Roosevelt
# . -----> .
# I -----> I
# want -----> want
# in -----> in
# turn -----> turn
# to -----> to
# assure -----> assure
# my -----> my
# fellow -----> fellow
# Americans -----> Americans
# and -----> and
# all -----> all
# of -----> of
# those -----> those
# who -----> who
# love -----> love
# peace -----> peace
# and -----> and
# liberty -----> liberty
# throughout -----> throughout
# the -----> the
# world -----> world
# that -----> that
# I -----> I
# will -----> will
# support -----> support
# and -----> and
# defend -----> defend
# those -----> those
# ideals -----> ideal
# with -----> with
# all -----> all
# my -----> my
# strength -----> strength
# and -----> and
# all -----> all
# my -----> my
# heart -----> heart
# . -----> .
# That -----> That
# is -----> is
# my -----> my
# duty -----> duty
# and -----> and
# I -----> I
# shall -----> shall
# not -----> not
# shirk -----> shirk
# it -----> it
# . -----> .
# So -----> So
# that -----> that
# there -----> there
# can -----> can
# be -----> be
# no -----> no
# possible -----> possible
# misunderstanding -----> misunderstanding
# , -----> ,
# both -----> both
# Germany -----> Germany
# and -----> and
# Japan -----> Japan
# can -----> can
# be -----> be
# certain -----> certain
# , -----> ,
# beyond -----> beyond
# any -----> any
# shadow -----> shadow
# of -----> of
# a -----> a
# doubt -----> doubt
# , -----> ,
# that -----> that
# America -----> America
# will -----> will
# continue -----> continue
# the -----> the
# fight -----> fight
# for -----> for
# freedom -----> freedom
# until -----> until
# no -----> no
# vestige -----> vestige
# of -----> of
# resistance -----> resistance
# remains -----> remains
# ! -----> !
# We -----> We
# are -----> are
# deeply -----> deeply
# conscious -----> conscious
# of -----> of
# the -----> the
# fact -----> fact
# that -----> that
# much -----> much
# hard -----> hard
# fighting -----> fighting
# is -----> is
# still -----> still
# ahead -----> ahead
# of -----> of
# us -----> u
# . -----> .
# Having -----> Having
# to -----> to
# pay -----> pay
# such -----> such
# a -----> a
# heavy -----> heavy
# price -----> price
# to -----> to
# make -----> make
# complete -----> complete
# victory -----> victory
# certain -----> certain
# , -----> ,
# America -----> America
# will -----> will
# never -----> never
# become -----> become
# a -----> a
# party -----> party
# to -----> to
# any -----> any
# plan -----> plan
# for -----> for
# partial -----> partial
# victory -----> victory
# ! -----> !
# To -----> To
# settle -----> settle
# for -----> for
# merely -----> merely
# another -----> another
# temporary -----> temporary
# respite -----> respite
# would -----> would
# surely -----> surely
# jeopardize -----> jeopardize
# the -----> the
# future -----> future
# security -----> security
# of -----> of
# all -----> all
# the -----> the
# world -----> world
# . -----> .
# Our -----> Our
# demand -----> demand
# has -----> ha
# been -----> been
# , -----> ,
# and -----> and
# it -----> it
# remains-Unconditional -----> remains-Unconditional
# Surrender -----> Surrender
# ! -----> !
# We -----> We
# will -----> will
# not -----> not
# traffic -----> traffic
# with -----> with
# the -----> the
# breakers -----> breaker
# of -----> of
# the -----> the
# peace -----> peace
# on -----> on
# the -----> the
# terms -----> term
# of -----> of
# the -----> the
# peace -----> peace
# . -----> .
# The -----> The
# responsibility -----> responsibility
# for -----> for
# making -----> making
# of -----> of
# the -----> the
# peace-and -----> peace-and
# it -----> it
# is -----> is
# a -----> a
# very -----> very
# grave -----> grave
# responsibility-must -----> responsibility-must
# rest -----> rest
# with -----> with
# the -----> the
# defenders -----> defender
# of -----> of
# the -----> the
# peace -----> peace
# . -----> .
# We -----> We
# are -----> are
# not -----> not
# unconscious -----> unconscious
# of -----> of
# the -----> the
# dictates -----> dictate
# of -----> of
# humanity -----> humanity
# . -----> .
# We -----> We
# do -----> do
# not -----> not
# wish -----> wish
# to -----> to
# see -----> see
# unnecessary -----> unnecessary
# or -----> or
# unjustified -----> unjustified
# suffering -----> suffering
# . -----> .
# But -----> But
# the -----> the
# laws -----> law
# of -----> of
# Go -----> Go
# d -----> d
# and -----> and
# of -----> of
# man -----> man
# have -----> have
# been -----> been
# violated -----> violated
# and -----> and
# the -----> the
# guilty -----> guilty
# must -----> must
# not -----> not
# go -----> go
# unpunished -----> unpunished
# . -----> .
# Nothing -----> Nothing
# shall -----> shall
# shake -----> shake
# our -----> our
# determination -----> determination
# to -----> to
# punish -----> punish
# the -----> the
# war -----> war
# criminals -----> criminal
# even -----> even
# though -----> though
# we -----> we
# must -----> must
# pursue -----> pursue
# them -----> them
# to -----> to
# the -----> the
# ends -----> end
# of -----> of
# the -----> the
# earth -----> earth
# . -----> .
# Lasting -----> Lasting
# peace -----> peace
# can -----> can
# never -----> never
# be -----> be
# secured -----> secured
# if -----> if
# we -----> we
# permit -----> permit
# our -----> our
# dangerous -----> dangerous
# opponents -----> opponent
# to -----> to
# plot -----> plot
# future -----> future
# wars -----> war
# with -----> with
# impunity -----> impunity
# at -----> at
# any -----> any
# mountain -----> mountain
# retreat -----> retreat
# - -----> -
# however -----> however
# distant -----> distant
# . -----> .
# In -----> In
# this -----> this
# shrinking -----> shrinking
# world -----> world
# , -----> ,
# it -----> it
# is -----> is
# futile -----> futile
# to -----> to
# seek -----> seek
# safety -----> safety
# behind -----> behind
# geographical -----> geographical
# barriers -----> barrier
# . -----> .
# Real -----> Real
# security -----> security
# will -----> will
# be -----> be
# found -----> found
# only -----> only
# in -----> in
# law -----> law
# and -----> and
# in -----> in
# justice -----> justice
# . -----> .
# Here -----> Here
# in -----> in
# America -----> America
# , -----> ,
# we -----> we
# have -----> have
# labored -----> labored
# long -----> long
# and -----> and
# hard -----> hard
# to -----> to
# achieve -----> achieve
# a -----> a
# social -----> social
# order -----> order
# worthy -----> worthy
# of -----> of
# our -----> our
# great -----> great
# heritage -----> heritage
# . -----> .
# In -----> In
# our -----> our
# time -----> time
# , -----> ,
# tremendous -----> tremendous
# progress -----> progress
# has -----> ha
# been -----> been
# made -----> made
# toward -----> toward
# a -----> a
# really -----> really
# democratic -----> democratic
# way -----> way
# of -----> of
# life -----> life
# . -----> .
# Let -----> Let
# me -----> me
# assure -----> assure
# the -----> the
# forward-looking -----> forward-looking
# people -----> people
# of -----> of
# America -----> America
# that -----> that
# there -----> there
# w -----> w
# ill -----> ill
# be -----> be
# no -----> no
# relaxation -----> relaxation
# in -----> in
# our -----> our
# efforts -----> effort
# to -----> to
# improve -----> improve
# the -----> the
# lot -----> lot
# of -----> of
# the -----> the
# common -----> common
# people -----> people
# . -----> .
# In -----> In
# the -----> the
# difficult -----> difficult
# days -----> day
# ahead -----> ahead
# , -----> ,
# unquestionably -----> unquestionably
# we -----> we
# shall -----> shall
# face -----> face
# problems -----> problem
# of -----> of
# staggering -----> staggering
# proportions -----> proportion
# . -----> .
# However -----> However
# , -----> ,
# with -----> with
# the -----> the
# faith -----> faith
# of -----> of
# our -----> our
# fathers -----> father
# in -----> in
# our -----> our
# hearts -----> heart
# , -----> ,
# we -----> we
# do -----> do
# not -----> not
# fear -----> fear
# the -----> the
# future -----> future
# . -----> .
# On -----> On
# the -----> the
# battlefields -----> battlefield
# , -----> ,
# we -----> we
# have -----> have
# frequently -----> frequently
# faced -----> faced
# overwhelming -----> overwhelming
# odds -----> odds
# - -----> -
# and -----> and
# won -----> won
# ! -----> !
# At -----> At
# home -----> home
# , -----> ,
# Americans -----> Americans
# will -----> will
# not -----> not
# be -----> be
# less -----> less
# resolute -----> resolute
# ! -----> !
# We -----> We
# shall -----> shall
# never -----> never
# cease -----> cease
# our -----> our
# struggle -----> struggle
# to -----> to
# preserve -----> preserve
# and -----> and
# maintain -----> maintain
# our -----> our
# American -----> American
# way -----> way
# of -----> of
# life -----> life
# . -----> .
# At -----> At
# this -----> this
# moment -----> moment
# , -----> ,
# America -----> America
# , -----> ,
# along -----> along
# with -----> with
# her -----> her
# brave -----> brave
# Allies -----> Allies
# , -----> ,
# is -----> is
# paying -----> paying
# again -----> again
# a -----> a
# heavy -----> heavy
# price -----> price
# for -----> for
# the -----> the
# defense -----> defense
# of -----> of
# our -----> our
# freedom -----> freedom
# . -----> .
# With -----> With
# characteristic -----> characteristic
# energy -----> energy
# , -----> ,
# we -----> we
# are -----> are
# assisting -----> assisting
# in -----> in
# the -----> the
# liberation -----> liberation
# of -----> of
# entire -----> entire
# nations -----> nation
# . -----> .
# Gradually -----> Gradually
# , -----> ,
# the -----> the
# shackles -----> shackle
# of -----> of
# slavery -----> slavery
# are -----> are
# being -----> being
# broken -----> broken
# by -----> by
# t -----> t
# he -----> he
# forces -----> force
# of -----> of
# freedom -----> freedom
# . -----> .
# All -----> All
# of -----> of
# us -----> u
# are -----> are
# praying -----> praying
# for -----> for
# a -----> a
# speedy -----> speedy
# victory -----> victory
# . -----> .
# Every -----> Every
# day -----> day
# peace -----> peace
# is -----> is
# delayed -----> delayed
# costs -----> cost
# a -----> a
# terrible -----> terrible
# toll -----> toll
# . -----> .
# The -----> The
# armies -----> army
# of -----> of
# liberation -----> liberation
# today -----> today
# are -----> are
# bringing -----> bringing
# to -----> to
# an -----> an
# end -----> end
# Hitler -----> Hitler
# 's -----> 's
# ghastly -----> ghastly
# threat -----> threat
# to -----> to
# dominate -----> dominate
# the -----> the
# world -----> world
# . -----> .
# Tokyo -----> Tokyo
# rocks -----> rock
# under -----> under
# the -----> the
# weight -----> weight
# of -----> of
# our -----> our
# bombs -----> bomb
# . -----> .
# The -----> The
# grand -----> grand
# strategy -----> strategy
# of -----> of
# the -----> the
# United -----> United
# Nations -----> Nations
# ' -----> '
# war -----> war
# has -----> ha
# been -----> been
# determined -----> determined
# - -----> -
# due -----> due
# in -----> in
# no -----> no
# small -----> small
# measure -----> measure
# to -----> to
# the -----> the
# vision -----> vision
# of -----> of
# our -----> our
# departed -----> departed
# Commander -----> Commander
# in -----> in
# Chief -----> Chief
# . -----> .
# We -----> We
# are -----> are
# now -----> now
# carrying -----> carrying
# out -----> out
# our -----> our
# part -----> part
# of -----> of
# that -----> that
# strategy -----> strategy
# under -----> under
# the -----> the
# able -----> able
# direction -----> direction
# of -----> of
# Admiral -----> Admiral
# Leahy -----> Leahy
# , -----> ,
# General -----> General
# Marshall -----> Marshall
# , -----> ,
# A -----> A
# dmiral -----> dmiral
# King -----> King
# , -----> ,
# General -----> General
# Arnold -----> Arnold
# , -----> ,
# General -----> General
# Eisenhower -----> Eisenhower
# , -----> ,
# Admiral -----> Admiral
# Nimitz -----> Nimitz
# and -----> and
# General -----> General
# MacArthur -----> MacArthur
# . -----> .
# I -----> I
# want -----> want
# the -----> the
# entire -----> entire
# world -----> world
# to -----> to
# know -----> know
# that -----> that
# this -----> this
# direction -----> direction
# must -----> must
# and -----> and
# will -----> will
# remain-unchanged -----> remain-unchanged
# and -----> and
# unhampered -----> unhampered
# ! -----> !
# Our -----> Our
# debt -----> debt
# to -----> to
# the -----> the
# heroic -----> heroic
# men -----> men
# and -----> and
# valiant -----> valiant
# women -----> woman
# in -----> in
# the -----> the
# service -----> service
# of -----> of
# our -----> our
# country -----> country
# can -----> can
# never -----> never
# be -----> be
# repaid -----> repaid
# . -----> .
# They -----> They
# have -----> have
# earned -----> earned
# our -----> our
# undying -----> undying
# gratitude -----> gratitude
# . -----> .
# America -----> America
# will -----> will
# never -----> never
# forget -----> forget
# their -----> their
# sacrifices -----> sacrifice
# . -----> .
# Because -----> Because
# of -----> of
# these -----> these
# sacrifices -----> sacrifice
# , -----> ,
# the -----> the
# dawn -----> dawn
# of -----> of
# justice -----> justice
# and -----> and
# freedom -----> freedom
# throughout -----> throughout
# th -----> th
# e -----> e
# world -----> world
# slowly -----> slowly
# casts -----> cast
# its -----> it
# gleam -----> gleam
# across -----> across
# the -----> the
# horizon -----> horizon
# . -----> .
# Our -----> Our
# forefathers -----> forefather
# came -----> came
# to -----> to
# our -----> our
# rugged -----> rugged
# shores -----> shore
# in -----> in
# search -----> search
# of -----> of
# religious -----> religious
# tolerance -----> tolerance
# , -----> ,
# political -----> political
# freedom -----> freedom
# and -----> and
# economic -----> economic
# opportunity -----> opportunity
# . -----> .
# For -----> For
# those -----> those
# fundamental -----> fundamental
# rights -----> right
# , -----> ,
# they -----> they
# risked -----> risked
# their -----> their
# lives -----> life
# . -----> .
# We -----> We
# well -----> well
# know -----> know
# today -----> today
# that -----> that
# such -----> such
# rights -----> right
# can -----> can
# be -----> be
# preserved -----> preserved
# only -----> only
# by -----> by
# constant -----> constant
# vigilance -----> vigilance
# , -----> ,
# the -----> the
# eternal -----> eternal
# price -----> price
# of -----> of
# liberty -----> liberty
# ! -----> !
# Within -----> Within
# an -----> an
# hour -----> hour
# after -----> after
# I -----> I
# took -----> took
# the -----> the
# oath -----> oath
# of -----> of
# office -----> office
# , -----> ,
# I -----> I
# announced -----> announced
# that -----> that
# the -----> the
# San -----> San
# Francisco -----> Francisco
# Conference -----> Conference
# would -----> would
# proceed -----> proceed
# . -----> .
# We -----> We
# will -----> will
# face -----> face
# the -----> the
# problems -----> problem
# of -----> of
# peace -----> peace
# with -----> with
# the -----> the
# same -----> same
# courage -----> courage
# that -----> that
# we -----> we
# have -----> have
# faced -----> faced
# and -----> and
# mastered -----> mastered
# the -----> the
# problems -----> problem
# of -----> of
# war -----> war
# . -----> .
# In -----> In
# the -----> the
# memory -----> memory
# of -----> of
# those -----> those
# who -----> who
# have -----> have
# made -----> made
# the -----> the
# supreme -----> supreme
# sacrifice-in -----> sacrifice-in
# the -----> the
# memory -----> memory
# of -----> of
# our -----> our
# fallen -----> fallen
# President-we -----> President-we
# shall -----> shall
# not -----> not
# fail -----> fail
# ! -----> !
# It -----> It
# is -----> is
# not -----> not
# enough -----> enough
# to -----> to
# yearn -----> yearn
# for -----> for
# peace -----> peace
# . -----> .
# We -----> We
# must -----> must
# work -----> work
# , -----> ,
# and -----> and
# if -----> if
# necessary -----> necessary
# , -----> ,
# fight -----> fight
# for -----> for
# it -----> it
# . -----> .
# The -----> The
# task -----> task
# of -----> of
# creating -----> creating
# a -----> a
# sound -----> sound
# international -----> international
# organization -----> organization
# is -----> is
# complicated -----> complicated
# and -----> and
# difficult -----> difficult
# . -----> .
# Yet -----> Yet
# , -----> ,
# without -----> without
# such -----> such
# organization -----> organization
# , -----> ,
# the -----> the
# rights -----> right
# of -----> of
# man -----> man
# on -----> on
# earth -----> earth
# can -----> can
# not -----> not
# be -----> be
# protected -----> protected
# . -----> .
# Machi -----> Machi
# nery -----> nery
# for -----> for
# the -----> the
# just -----> just
# settlement -----> settlement
# of -----> of
# international -----> international
# differences -----> difference
# must -----> must
# be -----> be
# found -----> found
# . -----> .
# Without -----> Without
# such -----> such
# machinery -----> machinery
# , -----> ,
# the -----> the
# entire -----> entire
# world -----> world
# will -----> will
# have -----> have
# to -----> to
# remain -----> remain
# an -----> an
# armed -----> armed
# camp -----> camp
# . -----> .
# The -----> The
# world -----> world
# will -----> will
# be -----> be
# doomed -----> doomed
# to -----> to
# deadly -----> deadly
# conflict -----> conflict
# , -----> ,
# devoid -----> devoid
# of -----> of
# hope -----> hope
# for -----> for
# real -----> real
# peace -----> peace
# . -----> .
# Fortunately -----> Fortunately
# , -----> ,
# people -----> people
# have -----> have
# retained -----> retained
# hope -----> hope
# for -----> for
# a -----> a
# durable -----> durable
# peace -----> peace
# . -----> .
# Thoughtful -----> Thoughtful
# people -----> people
# have -----> have
# always -----> always
# had -----> had
# faith -----> faith
# that -----> that
# ultimately -----> ultimately
# justice -----> justice
# must -----> must
# triumph -----> triumph
# . -----> .
# Past -----> Past
# experience -----> experience
# surely -----> surely
# indicates -----> indicates
# that -----> that
# , -----> ,
# without -----> without
# justice -----> justice
# , -----> ,
# an -----> an
# enduring -----> enduring
# peace -----> peace
# becomes -----> becomes
# impossible -----> impossible
# . -----> .
# In -----> In
# bitter -----> bitter
# despair -----> despair
# , -----> ,
# some -----> some
# people -----> people
# have -----> have
# come -----> come
# to -----> to
# believe -----> believe
# that -----> that
# wars -----> war
# are -----> are
# inevitable -----> inevitable
# . -----> .
# With -----> With
# tragic -----> tragic
# fatalism -----> fatalism
# , -----> ,
# they -----> they
# insist -----> insist
# that -----> that
# wars -----> war
# have -----> have
# always -----> always
# been -----> been
# , -----> ,
# of -----> of
# necessity -----> necessity
# , -----> ,
# and -----> and
# of -----> of
# necessity -----> necessity
# wars -----> war
# always -----> always
# will -----> will
# be -----> be
# . -----> .
# To -----> To
# such -----> such
# defeatism -----> defeatism
# , -----> ,
# men -----> men
# and -----> and
# women -----> woman
# of -----> of
# good -----> good
# will -----> will
# must -----> must
# not -----> not
# and -----> and
# can -----> can
# not -----> not
# yield -----> yield
# . -----> .
# The -----> The
# outlook -----> outlook
# for -----> for
# humanity -----> humanity
# is -----> is
# not -----> not
# so -----> so
# hopeless -----> hopeless
# . -----> .
# During -----> During
# the -----> the
# dark -----> dark
# hours -----> hour
# of -----> of
# this -----> this
# horrible -----> horrible
# war -----> war
# , -----> ,
# entire -----> entire
# nations -----> nation
# were -----> were
# kept -----> kept
# going -----> going
# by -----> by
# something -----> something
# intangible-hope -----> intangible-hope
# ! -----> !
# When -----> When
# warned -----> warned
# that -----> that
# abject -----> abject
# submission -----> submission
# offered -----> offered
# the -----> the
# only -----> only
# salvation -----> salvation
# against -----> against
# overwhelming -----> overwhelming
# power -----> power
# , -----> ,
# hope -----> hope
# showed -----> showed
# the -----> the
# way -----> way
# to -----> to
# victory -----> victory
# . -----> .
# Hope -----> Hope
# has -----> ha
# become -----> become
# the -----> the
# secret -----> secret
# weapon -----> weapon
# of -----> of
# the -----> the
# forces -----> force
# of -----> of
# liberation -----> liberation
# ! -----> !
# Aggressors -----> Aggressors
# could -----> could
# not -----> not
# dominate -----> dominate
# the -----> the
# human -----> human
# mind -----> mind
# . -----> .
# As -----> As
# long -----> long
# as -----> a
# hope -----> hope
# remains -----> remains
# , -----> ,
# the -----> the
# spirit -----> spirit
# of -----> of
# man -----> man
# will -----> will
# never -----> never
# be -----> be
# crushed -----> crushed
# . -----> .
# But -----> But
# hope -----> hope
# alone -----> alone
# was -----> wa
# not -----> not
# and -----> and
# is -----> is
# not -----> not
# sufficient -----> sufficient
# to -----> to
# avert -----> avert
# war -----> war
# . -----> .
# We -----> We
# must -----> must
# not -----> not
# only -----> only
# have -----> have
# hope -----> hope
# but -----> but
# we -----> we
# must -----> must
# have -----> have
# faith -----> faith
# enough -----> enough
# to -----> to
# work -----> work
# with -----> with
# other -----> other
# peace-loving -----> peace-loving
# nations -----> nation
# to -----> to
# maintain -----> maintain
# the -----> the
# peace -----> peace
# . -----> .
# Hope -----> Hope
# was -----> wa
# not -----> not
# enough -----> enough
# to -----> to
# beat -----> beat
# back -----> back
# the -----> the
# aggressors -----> aggressor
# as -----> a
# long -----> long
# as -----> a
# the -----> the
# peace-loving -----> peace-loving
# nations -----> nation
# were -----> were
# unwilling -----> unwilling
# to -----> to
# come -----> come
# to -----> to
# each -----> each
# other -----> other
# 's -----> 's
# defense -----> defense
# . -----> .
# The -----> The
# aggressors -----> aggressor
# were -----> were
# beaten -----> beaten
# back -----> back
# only -----> only
# when -----> when
# the -----> the
# peace-loving -----> peace-loving
# nations -----> nation
# united -----> united
# to -----> to
# defend -----> defend
# themselves -----> themselves
# . -----> .
# If -----> If
# wars -----> war
# in -----> in
# the -----> the
# future -----> future
# are -----> are
# to -----> to
# be -----> be
# prevented -----> prevented
# the -----> the
# nations -----> nation
# must -----> must
# be -----> be
# united -----> united
# in -----> in
# their -----> their
# determination -----> determination
# to -----> to
# keep -----> keep
# the -----> the
# peace -----> peace
# under -----> under
# law -----> law
# . -----> .
# Nothing -----> Nothing
# is -----> is
# more -----> more
# essential -----> essential
# to -----> to
# the -----> the
# future -----> future
# peace -----> peace
# of -----> of
# the -----> the
# world -----> world
# than -----> than
# continued -----> continued
# cooperation -----> cooperation
# of -----> of
# the -----> the
# nations -----> nation
# which -----> which
# had -----> had
# to -----> to
# muster -----> muster
# the -----> the
# force -----> force
# necessary -----> necessary
# to -----> to
# defeat -----> defeat
# the -----> the
# conspiracy -----> conspiracy
# of -----> of
# the -----> the
# Axis -----> Axis
# powers -----> power
# to -----> to
# dominate -----> dominate
# the -----> the
# world -----> world
# . -----> .
# While -----> While
# these -----> these
# great -----> great
# states -----> state
# have -----> have
# a -----> a
# special -----> special
# responsibility -----> responsibility
# to -----> to
# enforce -----> enforce
# the -----> the
# peace -----> peace
# , -----> ,
# their -----> their
# responsibility -----> responsibility
# is -----> is
# based -----> based
# upon -----> upon
# the -----> the
# obligations -----> obligation
# resting -----> resting
# upon -----> upon
# all -----> all
# states -----> state
# , -----> ,
# large -----> large
# and -----> and
# small -----> small
# , -----> ,
# not -----> not
# to -----> to
# use -----> use
# force -----> force
# in -----> in
# international -----> international
# relations -----> relation
# except -----> except
# in -----> in
# the -----> the
# defense -----> defense
# of -----> of
# law -----> law
# . -----> .
# The -----> The
# respon -----> respon
# sibility -----> sibility
# of -----> of
# the -----> the
# great -----> great
# states -----> state
# is -----> is
# to -----> to
# serve -----> serve
# and -----> and
# not -----> not
# to -----> to
# dominate -----> dominate
# the -----> the
# world -----> world
# . -----> .
# To -----> To
# build -----> build
# a -----> a
# foundation -----> foundation
# of -----> of
# enduring -----> enduring
# peace -----> peace
# we -----> we
# must -----> must
# not -----> not
# only -----> only
# work -----> work
# in -----> in
# harmony -----> harmony
# with -----> with
# our -----> our
# friends -----> friend
# abroad -----> abroad
# , -----> ,
# but -----> but
# we -----> we
# must -----> must
# have -----> have
# the -----> the
# united -----> united
# support -----> support
# of -----> of
# our -----> our
# own -----> own
# people -----> people
# . -----> .
# Even -----> Even
# the -----> the
# most -----> most
# experienced -----> experienced
# pilot -----> pilot
# can -----> can
# not -----> not
# bring -----> bring
# a -----> a
# ship -----> ship
# safely -----> safely
# into -----> into
# harbor -----> harbor
# , -----> ,
# unless -----> unless
# he -----> he
# has -----> ha
# the -----> the
# full -----> full
# cooperation -----> cooperation
# of -----> of
# the -----> the
# crew -----> crew
# . -----> .
# For -----> For
# the -----> the
# benefit -----> benefit
# of -----> of
# all -----> all
# , -----> ,
# every -----> every
# individual -----> individual
# must -----> must
# do -----> do
# his -----> his
# duty -----> duty
# . -----> .
# I -----> I
# appeal -----> appeal
# to -----> to
# every -----> every
# American -----> American
# , -----> ,
# regardless -----> regardless
# of -----> of
# party -----> party
# , -----> ,
# race -----> race
# , -----> ,
# creed -----> creed
# , -----> ,
# or -----> or
# color -----> color
# , -----> ,
# to -----> to
# support -----> support
# our -----> our
# efforts -----> effort
# to -----> to
# build -----> build
# a -----> a
# strong -----> strong
# and -----> and
# lasting -----> lasting
# United -----> United
# Nations -----> Nations
# Organization -----> Organization
# . -----> .
# You -----> You
# , -----> ,
# the -----> the
# Members -----> Members
# of -----> of
# the -----> the
# Congress -----> Congress
# , -----> ,
# surely -----> surely
# know -----> know
# how -----> how
# I -----> I
# feel -----> feel
# . -----> .
# Only -----> Only
# with -----> with
# your -----> your
# help -----> help
# can -----> can
# I -----> I
# hope -----> hope
# to -----> to
# complete -----> complete
# one -----> one
# of -----> of
# the -----> the
# greatest -----> greatest
# tasks -----> task
# ever -----> ever
# assigned -----> assigned
# to -----> to
# a -----> a
# public -----> public
# servant -----> servant
# . -----> .
# With -----> With
# Divine -----> Divine
# guidance -----> guidance
# , -----> ,
# and -----> and
# your -----> your
# help -----> help
# , -----> ,
# we -----> we
# will -----> will
# find -----> find
# the -----> the
# new -----> new
# passage -----> passage
# to -----> to
# a -----> a
# far -----> far
# better -----> better
# world -----> world
# , -----> ,
# a -----> a
# kindly -----> kindly
# and -----> and
# friendly -----> friendly
# world -----> world
# , -----> ,
# with -----> with
# just -----> just
# and -----> and
# lasting -----> lasting
# peace -----> peace
# . -----> .
# With -----> With
# confidence -----> confidence
# , -----> ,
# I -----> I
# am -----> am
# depending -----> depending
# upon -----> upon
# all -----> all
# of -----> of
# you -----> you
# . -----> .
# To -----> To
# destroy -----> destroy
# greedy -----> greedy
# tyrants -----> tyrant
# with -----> with
# dreams -----> dream
# of -----> of
# world -----> world
# domination -----> domination
# , -----> ,
# we -----> we
# can -----> can
# not -----> not
# continue -----> continue
# in -----> in
# successive -----> successive
# generations -----> generation
# to -----> to
# sacrifice -----> sacrifice
# our -----> our
# finest -----> finest
# youth -----> youth
# . -----> .
# In -----> In
# the -----> the
# name -----> name
# of -----> of
# human -----> human
# decency -----> decency
# and -----> and
# civilization -----> civilization
# , -----> ,
# a -----> a
# more -----> more
# rational -----> rational
# method -----> method
# of -----> of
# deciding -----> deciding
# national -----> national
# differences -----> difference
# must -----> must
# and -----> and
# will -----> will
# be -----> be
# found -----> found
# ! -----> !
# America -----> America
# must -----> must
# assist -----> assist
# suffering -----> suffering
# humanity -----> humanity
# back -----> back
# along -----> along
# the -----> the
# path -----> path
# of -----> of
# peaceful -----> peaceful
# progress -----> progress
# . -----> .
# This -----> This
# will -----> will
# require -----> require
# time -----> time
# and -----> and
# tolerance -----> tolerance
# . -----> .
# We -----> We
# shall -----> shall
# need -----> need
# also -----> also
# an -----> an
# abiding -----> abiding
# faith -----> faith
# in -----> in
# the -----> the
# people -----> people
# , -----> ,
# the -----> the
# kind -----> kind
# of -----> of
# faith -----> faith
# and -----> and
# courage -----> courage
# which -----> which
# Franklin -----> Franklin
# Delano -----> Delano
# Roosevelt -----> Roosevelt
# always -----> always
# had -----> had
# ! -----> !
# Today -----> Today
# , -----> ,
# America -----> America
# has -----> ha
# become -----> become
# one -----> one
# of -----> of
# the -----> the
# most -----> most
# powerful -----> powerful
# forces -----> force
# for -----> for
# good -----> good
# on -----> on
# earth -----> earth
# . -----> .
# We -----> We
# must -----> must
# keep -----> keep
# it -----> it
# so -----> so
# . -----> .
# We -----> We
# have -----> have
# achieved -----> achieved
# a -----> a
# world -----> world
# leadership -----> leadership
# which -----> which
# does -----> doe
# not -----> not
# depend -----> depend
# solely -----> solely
# upon -----> upon
# our -----> our
# military -----> military
# and -----> and
# naval -----> naval
# might -----> might
# . -----> .
# We -----> We
# have -----> have
# learned -----> learned
# to -----> to
# fight -----> fight
# with -----> with
# other -----> other
# nations -----> nation
# in -----> in
# common -----> common
# defense -----> defense
# of -----> of
# our -----> our
# freedom -----> freedom
# . -----> .
# We -----> We
# must -----> must
# now -----> now
# learn -----> learn
# to -----> to
# live -----> live
# with -----> with
# other -----> other
# nations -----> nation
# for -----> for
# our -----> our
# mutual -----> mutual
# good -----> good
# . -----> .
# We -----> We
# must -----> must
# learn -----> learn
# to -----> to
# trade -----> trade
# more -----> more
# with -----> with
# other -----> other
# nations -----> nation
# so -----> so
# that -----> that
# there -----> there
# may -----> may
# be-for -----> be-for
# our -----> our
# mutual -----> mutual
# advantage-increased -----> advantage-increased
# product -----> product
# ion -----> ion
# , -----> ,
# increased -----> increased
# employment -----> employment
# and -----> and
# better -----> better
# standards -----> standard
# of -----> of
# living -----> living
# throughout -----> throughout
# the -----> the
# world -----> world
# . -----> .
# May -----> May
# we -----> we
# Americans -----> Americans
# all -----> all
# live -----> live
# up -----> up
# to -----> to
# our -----> our
# glorious -----> glorious
# heritage -----> heritage
# . -----> .
# In -----> In
# that -----> that
# way -----> way
# , -----> ,
# America -----> America
# may -----> may
# well -----> well
# lead -----> lead
# the -----> the
# world -----> world
# to -----> to
# peace -----> peace
# and -----> and
# prosperity -----> prosperity
# . -----> .
# At -----> At
# this -----> this
# moment -----> moment
# , -----> ,
# I -----> I
# have -----> have
# in -----> in
# my -----> my
# heart -----> heart
# a -----> a
# prayer -----> prayer
# . -----> .
# As -----> As
# I -----> I
# have -----> have
# assumed -----> assumed
# my -----> my
# heavy -----> heavy
# duties -----> duty
# , -----> ,
# I -----> I
# humbly -----> humbly
# pray -----> pray
# Almighty -----> Almighty
# God -----> God
# , -----> ,
# in -----> in
# the -----> the
# words -----> word
# of -----> of
# King -----> King
# Solomon -----> Solomon
# : -----> :
# '' -----> ''
# Give -----> Give
# therefore -----> therefore
# thy -----> thy
# servant -----> servant
# an -----> an
# understanding -----> understanding
# heart -----> heart
# to -----> to
# judge -----> judge
# thy -----> thy
# people -----> people
# , -----> ,
# that -----> that
# I -----> I
# may -----> may
# discern -----> discern
# between -----> between
# good -----> good
# and -----> and
# bad -----> bad
# ; -----> ;
# for -----> for
# who -----> who
# is -----> is
# able -----> able
# to -----> to
# judge -----> judge
# this -----> this
# thy -----> thy
# so -----> so
# great -----> great
# a -----> a
# people -----> people
# ? -----> ?
# '' -----> ''
# I -----> I
# ask -----> ask
# only -----> only
# to -----> to
# be -----> be
# a -----> a
# good -----> good
# and -----> and
# faithful -----> faithful
# servant -----> servant
# of -----> of
# my -----> my
# Lord -----> Lord
# and -----> and
# my -----> my
# people -----> people
# . -----> .

# %% [markdown]
# Notice that many verbs are not lemmatized correctly.
# This is because NLTK’s lemmatizer defaults to noun POS tags.

# %%
#NLTK lemmatizer with improved POS tags
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
tagged_tokens = pos_tag(tokens_nltk) #hopefully will have no words w/o tags

def get_wordnet_pos(tag): #definition to auto assign POS tag to a word
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

nltk_pos_lemma = []
for word, tag in tagged_tokens:
    nltk_pos_lemma.append(lemmatizer.lemmatize(word, get_wordnet_pos(tag)))
    print(f"{word} ----> {lemmatizer.lemmatize(word, get_wordnet_pos(tag))}")
# Out:
# PRESIDENT ----> PRESIDENT
# HARRY ----> HARRY
# S. ----> S.
# TRUMAN ----> TRUMAN
# 'S ----> 'S
# ADDRESS ----> ADDRESS
# BEFORE ----> BEFORE
# A ----> A
# JOINT ----> JOINT
# SESSION ----> SESSION
# OF ----> OF
# THE ----> THE
# CONGRESS ----> CONGRESS
# April ----> April
# 16 ----> 16
# , ----> ,
# 1945 ----> 1945
# Mr. ----> Mr.
# Speaker ----> Speaker
# , ----> ,
# Mr. ----> Mr.
# President ----> President
# , ----> ,
# Members ----> Members
# of ----> of
# the ----> the
# Congress ----> Congress
# : ----> :
# It ----> It
# is ----> be
# with ----> with
# a ----> a
# heavy ----> heavy
# heart ----> heart
# that ----> that
# I ----> I
# stand ----> stand
# before ----> before
# you ----> you
# , ----> ,
# my ----> my
# friends ----> friend
# and ----> and
# colleagues ----> colleague
# , ----> ,
# in ----> in
# the ----> the
# Congress ----> Congress
# of ----> of
# the ----> the
# United ----> United
# States ----> States
# . ----> .
# Only ----> Only
# yesterday ----> yesterday
# , ----> ,
# we ----> we
# laid ----> lay
# to ----> to
# rest ----> rest
# the ----> the
# mortal ----> mortal
# remains ----> remain
# of ----> of
# our ----> our
# beloved ----> beloved
# President ----> President
# , ----> ,
# Franklin ----> Franklin
# Delano ----> Delano
# Roosevelt ----> Roosevelt
# . ----> .
# At ----> At
# a ----> a
# time ----> time
# like ----> like
# this ----> this
# , ----> ,
# words ----> word
# are ----> be
# inadequate ----> inadequate
# . ----> .
# The ----> The
# most ----> most
# eloquent ----> eloquent
# tribute ----> tribute
# would ----> would
# be ----> be
# a ----> a
# reverent ----> reverent
# silence ----> silence
# . ----> .
# Yet ----> Yet
# , ----> ,
# in ----> in
# this ----> this
# decisive ----> decisive
# hour ----> hour
# , ----> ,
# when ----> when
# world ----> world
# events ----> event
# are ----> be
# moving ----> move
# so ----> so
# rapidly ----> rapidly
# , ----> ,
# our ----> our
# silence ----> silence
# might ----> might
# be ----> be
# misunderstood ----> misunderstand
# and ----> and
# might ----> might
# give ----> give
# comfort ----> comfort
# to ----> to
# our ----> our
# enemies ----> enemy
# . ----> .
# In ----> In
# His ----> His
# infinite ----> infinite
# wisdom ----> wisdom
# , ----> ,
# Almighty ----> Almighty
# God ----> God
# has ----> have
# seen ----> see
# fit ----> fit
# to ----> to
# take ----> take
# from ----> from
# us ----> u
# a ----> a
# great ----> great
# man ----> man
# who ----> who
# loved ----> love
# , ----> ,
# and ----> and
# was ----> be
# beloved ----> beloved
# by ----> by
# , ----> ,
# all ----> all
# humanity ----> humanity
# . ----> .
# No ----> No
# man ----> man
# could ----> could
# possibly ----> possibly
# fill ----> fill
# the ----> the
# tremendous ----> tremendous
# void ----> void
# left ----> leave
# by ----> by
# the ----> the
# passing ----> passing
# of ----> of
# that ----> that
# noble ----> noble
# soul ----> soul
# . ----> .
# No ----> No
# words ----> word
# can ----> can
# ease ----> ease
# the ----> the
# aching ----> ache
# hearts ----> heart
# of ----> of
# untold ----> untold
# millions ----> million
# of ----> of
# every ----> every
# race ----> race
# , ----> ,
# creed ----> creed
# and ----> and
# color ----> color
# . ----> .
# The ----> The
# world ----> world
# knows ----> know
# it ----> it
# has ----> have
# lost ----> lose
# a ----> a
# heroic ----> heroic
# champion ----> champion
# of ----> of
# justice ----> justice
# and ----> and
# freedom ----> freedom
# . ----> .
# Tragic ----> Tragic
# fate ----> fate
# has ----> have
# thrust ----> thrust
# upon ----> upon
# us ----> u
# grave ----> grave
# responsibilities ----> responsibility
# . ----> .
# We ----> We
# must ----> must
# carry ----> carry
# on.Our ----> on.Our
# departed ----> departed
# leader ----> leader
# never ----> never
# looked ----> look
# backward ----> backward
# . ----> .
# He ----> He
# looked ----> look
# forward ----> forward
# and ----> and
# moved ----> move
# forward ----> forward
# . ----> .
# That ----> That
# is ----> be
# what ----> what
# he ----> he
# would ----> would
# want ----> want
# us ----> u
# to ----> to
# do ----> do
# . ----> .
# That ----> That
# is ----> be
# what ----> what
# America ----> America
# will ----> will
# do ----> do
# . ----> .
# So ----> So
# much ----> much
# blood ----> blood
# has ----> have
# already ----> already
# been ----> be
# shed ----> shed
# for ----> for
# the ----> the
# ideals ----> ideal
# which ----> which
# we ----> we
# cherish ----> cherish
# , ----> ,
# and ----> and
# for ----> for
# which ----> which
# Franklin ----> Franklin
# Delano ----> Delano
# Roosevelt ----> Roosevelt
# lived ----> live
# and ----> and
# died ----> die
# , ----> ,
# that ----> that
# we ----> we
# dare ----> dare
# not ----> not
# permit ----> permit
# even ----> even
# a ----> a
# momentary ----> momentary
# pause ----> pause
# in ----> in
# the ----> the
# hard ----> hard
# fight ----> fight
# for ----> for
# victory ----> victory
# . ----> .
# Today ----> Today
# , ----> ,
# the ----> the
# entire ----> entire
# world ----> world
# is ----> be
# looking ----> look
# to ----> to
# America ----> America
# for ----> for
# enlightened ----> enlightened
# leadership ----> leadership
# to ----> to
# peace ----> peace
# and ----> and
# progress ----> progress
# . ----> .
# Such ----> Such
# a ----> a
# leadership ----> leadership
# requires ----> require
# vision ----> vision
# , ----> ,
# courage ----> courage
# and ----> and
# tolerance ----> tolerance
# . ----> .
# It ----> It
# can ----> can
# be ----> be
# provided ----> provide
# only ----> only
# by ----> by
# a ----> a
# united ----> united
# nation ----> nation
# deeply ----> deeply
# devoted ----> devote
# to ----> to
# the ----> the
# highest ----> high
# ideals ----> ideal
# . ----> .
# With ----> With
# great ----> great
# humility ----> humility
# I ----> I
# call ----> call
# upon ----> upon
# all ----> all
# Americans ----> Americans
# to ----> to
# help ----> help
# me ----> me
# keep ----> keep
# our ----> our
# nation ----> nation
# united ----> unite
# in ----> in
# defense ----> defense
# of ----> of
# those ----> those
# ideals ----> ideal
# which ----> which
# have ----> have
# been ----> be
# so ----> so
# eloquently ----> eloquently
# proclaimed ----> proclaim
# by ----> by
# Franklin ----> Franklin
# Roosevelt ----> Roosevelt
# . ----> .
# I ----> I
# want ----> want
# in ----> in
# turn ----> turn
# to ----> to
# assure ----> assure
# my ----> my
# fellow ----> fellow
# Americans ----> Americans
# and ----> and
# all ----> all
# of ----> of
# those ----> those
# who ----> who
# love ----> love
# peace ----> peace
# and ----> and
# liberty ----> liberty
# throughout ----> throughout
# the ----> the
# world ----> world
# that ----> that
# I ----> I
# will ----> will
# support ----> support
# and ----> and
# defend ----> defend
# those ----> those
# ideals ----> ideal
# with ----> with
# all ----> all
# my ----> my
# strength ----> strength
# and ----> and
# all ----> all
# my ----> my
# heart ----> heart
# . ----> .
# That ----> That
# is ----> be
# my ----> my
# duty ----> duty
# and ----> and
# I ----> I
# shall ----> shall
# not ----> not
# shirk ----> shirk
# it ----> it
# . ----> .
# So ----> So
# that ----> that
# there ----> there
# can ----> can
# be ----> be
# no ----> no
# possible ----> possible
# misunderstanding ----> misunderstanding
# , ----> ,
# both ----> both
# Germany ----> Germany
# and ----> and
# Japan ----> Japan
# can ----> can
# be ----> be
# certain ----> certain
# , ----> ,
# beyond ----> beyond
# any ----> any
# shadow ----> shadow
# of ----> of
# a ----> a
# doubt ----> doubt
# , ----> ,
# that ----> that
# America ----> America
# will ----> will
# continue ----> continue
# the ----> the
# fight ----> fight
# for ----> for
# freedom ----> freedom
# until ----> until
# no ----> no
# vestige ----> vestige
# of ----> of
# resistance ----> resistance
# remains ----> remain
# ! ----> !
# We ----> We
# are ----> be
# deeply ----> deeply
# conscious ----> conscious
# of ----> of
# the ----> the
# fact ----> fact
# that ----> that
# much ----> much
# hard ----> hard
# fighting ----> fighting
# is ----> be
# still ----> still
# ahead ----> ahead
# of ----> of
# us ----> u
# . ----> .
# Having ----> Having
# to ----> to
# pay ----> pay
# such ----> such
# a ----> a
# heavy ----> heavy
# price ----> price
# to ----> to
# make ----> make
# complete ----> complete
# victory ----> victory
# certain ----> certain
# , ----> ,
# America ----> America
# will ----> will
# never ----> never
# become ----> become
# a ----> a
# party ----> party
# to ----> to
# any ----> any
# plan ----> plan
# for ----> for
# partial ----> partial
# victory ----> victory
# ! ----> !
# To ----> To
# settle ----> settle
# for ----> for
# merely ----> merely
# another ----> another
# temporary ----> temporary
# respite ----> respite
# would ----> would
# surely ----> surely
# jeopardize ----> jeopardize
# the ----> the
# future ----> future
# security ----> security
# of ----> of
# all ----> all
# the ----> the
# world ----> world
# . ----> .
# Our ----> Our
# demand ----> demand
# has ----> have
# been ----> be
# , ----> ,
# and ----> and
# it ----> it
# remains-Unconditional ----> remains-Unconditional
# Surrender ----> Surrender
# ! ----> !
# We ----> We
# will ----> will
# not ----> not
# traffic ----> traffic
# with ----> with
# the ----> the
# breakers ----> breaker
# of ----> of
# the ----> the
# peace ----> peace
# on ----> on
# the ----> the
# terms ----> term
# of ----> of
# the ----> the
# peace ----> peace
# . ----> .
# The ----> The
# responsibility ----> responsibility
# for ----> for
# making ----> make
# of ----> of
# the ----> the
# peace-and ----> peace-and
# it ----> it
# is ----> be
# a ----> a
# very ----> very
# grave ----> grave
# responsibility-must ----> responsibility-must
# rest ----> rest
# with ----> with
# the ----> the
# defenders ----> defender
# of ----> of
# the ----> the
# peace ----> peace
# . ----> .
# We ----> We
# are ----> be
# not ----> not
# unconscious ----> unconscious
# of ----> of
# the ----> the
# dictates ----> dictate
# of ----> of
# humanity ----> humanity
# . ----> .
# We ----> We
# do ----> do
# not ----> not
# wish ----> wish
# to ----> to
# see ----> see
# unnecessary ----> unnecessary
# or ----> or
# unjustified ----> unjustified
# suffering ----> suffering
# . ----> .
# But ----> But
# the ----> the
# laws ----> law
# of ----> of
# Go ----> Go
# d ----> d
# and ----> and
# of ----> of
# man ----> man
# have ----> have
# been ----> be
# violated ----> violate
# and ----> and
# the ----> the
# guilty ----> guilty
# must ----> must
# not ----> not
# go ----> go
# unpunished ----> unpunished
# . ----> .
# Nothing ----> Nothing
# shall ----> shall
# shake ----> shake
# our ----> our
# determination ----> determination
# to ----> to
# punish ----> punish
# the ----> the
# war ----> war
# criminals ----> criminal
# even ----> even
# though ----> though
# we ----> we
# must ----> must
# pursue ----> pursue
# them ----> them
# to ----> to
# the ----> the
# ends ----> end
# of ----> of
# the ----> the
# earth ----> earth
# . ----> .
# Lasting ----> Lasting
# peace ----> peace
# can ----> can
# never ----> never
# be ----> be
# secured ----> secure
# if ----> if
# we ----> we
# permit ----> permit
# our ----> our
# dangerous ----> dangerous
# opponents ----> opponent
# to ----> to
# plot ----> plot
# future ----> future
# wars ----> war
# with ----> with
# impunity ----> impunity
# at ----> at
# any ----> any
# mountain ----> mountain
# retreat ----> retreat
# - ----> -
# however ----> however
# distant ----> distant
# . ----> .
# In ----> In
# this ----> this
# shrinking ----> shrinking
# world ----> world
# , ----> ,
# it ----> it
# is ----> be
# futile ----> futile
# to ----> to
# seek ----> seek
# safety ----> safety
# behind ----> behind
# geographical ----> geographical
# barriers ----> barrier
# . ----> .
# Real ----> Real
# security ----> security
# will ----> will
# be ----> be
# found ----> find
# only ----> only
# in ----> in
# law ----> law
# and ----> and
# in ----> in
# justice ----> justice
# . ----> .
# Here ----> Here
# in ----> in
# America ----> America
# , ----> ,
# we ----> we
# have ----> have
# labored ----> labor
# long ----> long
# and ----> and
# hard ----> hard
# to ----> to
# achieve ----> achieve
# a ----> a
# social ----> social
# order ----> order
# worthy ----> worthy
# of ----> of
# our ----> our
# great ----> great
# heritage ----> heritage
# . ----> .
# In ----> In
# our ----> our
# time ----> time
# , ----> ,
# tremendous ----> tremendous
# progress ----> progress
# has ----> have
# been ----> be
# made ----> make
# toward ----> toward
# a ----> a
# really ----> really
# democratic ----> democratic
# way ----> way
# of ----> of
# life ----> life
# . ----> .
# Let ----> Let
# me ----> me
# assure ----> assure
# the ----> the
# forward-looking ----> forward-looking
# people ----> people
# of ----> of
# America ----> America
# that ----> that
# there ----> there
# w ----> w
# ill ----> ill
# be ----> be
# no ----> no
# relaxation ----> relaxation
# in ----> in
# our ----> our
# efforts ----> effort
# to ----> to
# improve ----> improve
# the ----> the
# lot ----> lot
# of ----> of
# the ----> the
# common ----> common
# people ----> people
# . ----> .
# In ----> In
# the ----> the
# difficult ----> difficult
# days ----> day
# ahead ----> ahead
# , ----> ,
# unquestionably ----> unquestionably
# we ----> we
# shall ----> shall
# face ----> face
# problems ----> problem
# of ----> of
# staggering ----> stagger
# proportions ----> proportion
# . ----> .
# However ----> However
# , ----> ,
# with ----> with
# the ----> the
# faith ----> faith
# of ----> of
# our ----> our
# fathers ----> father
# in ----> in
# our ----> our
# hearts ----> heart
# , ----> ,
# we ----> we
# do ----> do
# not ----> not
# fear ----> fear
# the ----> the
# future ----> future
# . ----> .
# On ----> On
# the ----> the
# battlefields ----> battlefield
# , ----> ,
# we ----> we
# have ----> have
# frequently ----> frequently
# faced ----> face
# overwhelming ----> overwhelming
# odds ----> odds
# - ----> -
# and ----> and
# won ----> win
# ! ----> !
# At ----> At
# home ----> home
# , ----> ,
# Americans ----> Americans
# will ----> will
# not ----> not
# be ----> be
# less ----> less
# resolute ----> resolute
# ! ----> !
# We ----> We
# shall ----> shall
# never ----> never
# cease ----> cease
# our ----> our
# struggle ----> struggle
# to ----> to
# preserve ----> preserve
# and ----> and
# maintain ----> maintain
# our ----> our
# American ----> American
# way ----> way
# of ----> of
# life ----> life
# . ----> .
# At ----> At
# this ----> this
# moment ----> moment
# , ----> ,
# America ----> America
# , ----> ,
# along ----> along
# with ----> with
# her ----> her
# brave ----> brave
# Allies ----> Allies
# , ----> ,
# is ----> be
# paying ----> pay
# again ----> again
# a ----> a
# heavy ----> heavy
# price ----> price
# for ----> for
# the ----> the
# defense ----> defense
# of ----> of
# our ----> our
# freedom ----> freedom
# . ----> .
# With ----> With
# characteristic ----> characteristic
# energy ----> energy
# , ----> ,
# we ----> we
# are ----> be
# assisting ----> assist
# in ----> in
# the ----> the
# liberation ----> liberation
# of ----> of
# entire ----> entire
# nations ----> nation
# . ----> .
# Gradually ----> Gradually
# , ----> ,
# the ----> the
# shackles ----> shackle
# of ----> of
# slavery ----> slavery
# are ----> be
# being ----> be
# broken ----> break
# by ----> by
# t ----> t
# he ----> he
# forces ----> force
# of ----> of
# freedom ----> freedom
# . ----> .
# All ----> All
# of ----> of
# us ----> u
# are ----> be
# praying ----> pray
# for ----> for
# a ----> a
# speedy ----> speedy
# victory ----> victory
# . ----> .
# Every ----> Every
# day ----> day
# peace ----> peace
# is ----> be
# delayed ----> delay
# costs ----> cost
# a ----> a
# terrible ----> terrible
# toll ----> toll
# . ----> .
# The ----> The
# armies ----> army
# of ----> of
# liberation ----> liberation
# today ----> today
# are ----> be
# bringing ----> bring
# to ----> to
# an ----> an
# end ----> end
# Hitler ----> Hitler
# 's ----> 's
# ghastly ----> ghastly
# threat ----> threat
# to ----> to
# dominate ----> dominate
# the ----> the
# world ----> world
# . ----> .
# Tokyo ----> Tokyo
# rocks ----> rock
# under ----> under
# the ----> the
# weight ----> weight
# of ----> of
# our ----> our
# bombs ----> bomb
# . ----> .
# The ----> The
# grand ----> grand
# strategy ----> strategy
# of ----> of
# the ----> the
# United ----> United
# Nations ----> Nations
# ' ----> '
# war ----> war
# has ----> have
# been ----> be
# determined ----> determine
# - ----> -
# due ----> due
# in ----> in
# no ----> no
# small ----> small
# measure ----> measure
# to ----> to
# the ----> the
# vision ----> vision
# of ----> of
# our ----> our
# departed ----> departed
# Commander ----> Commander
# in ----> in
# Chief ----> Chief
# . ----> .
# We ----> We
# are ----> be
# now ----> now
# carrying ----> carry
# out ----> out
# our ----> our
# part ----> part
# of ----> of
# that ----> that
# strategy ----> strategy
# under ----> under
# the ----> the
# able ----> able
# direction ----> direction
# of ----> of
# Admiral ----> Admiral
# Leahy ----> Leahy
# , ----> ,
# General ----> General
# Marshall ----> Marshall
# , ----> ,
# A ----> A
# dmiral ----> dmiral
# King ----> King
# , ----> ,
# General ----> General
# Arnold ----> Arnold
# , ----> ,
# General ----> General
# Eisenhower ----> Eisenhower
# , ----> ,
# Admiral ----> Admiral
# Nimitz ----> Nimitz
# and ----> and
# General ----> General
# MacArthur ----> MacArthur
# . ----> .
# I ----> I
# want ----> want
# the ----> the
# entire ----> entire
# world ----> world
# to ----> to
# know ----> know
# that ----> that
# this ----> this
# direction ----> direction
# must ----> must
# and ----> and
# will ----> will
# remain-unchanged ----> remain-unchanged
# and ----> and
# unhampered ----> unhampered
# ! ----> !
# Our ----> Our
# debt ----> debt
# to ----> to
# the ----> the
# heroic ----> heroic
# men ----> men
# and ----> and
# valiant ----> valiant
# women ----> woman
# in ----> in
# the ----> the
# service ----> service
# of ----> of
# our ----> our
# country ----> country
# can ----> can
# never ----> never
# be ----> be
# repaid ----> repay
# . ----> .
# They ----> They
# have ----> have
# earned ----> earn
# our ----> our
# undying ----> undying
# gratitude ----> gratitude
# . ----> .
# America ----> America
# will ----> will
# never ----> never
# forget ----> forget
# their ----> their
# sacrifices ----> sacrifice
# . ----> .
# Because ----> Because
# of ----> of
# these ----> these
# sacrifices ----> sacrifice
# , ----> ,
# the ----> the
# dawn ----> dawn
# of ----> of
# justice ----> justice
# and ----> and
# freedom ----> freedom
# throughout ----> throughout
# th ----> th
# e ----> e
# world ----> world
# slowly ----> slowly
# casts ----> cast
# its ----> it
# gleam ----> gleam
# across ----> across
# the ----> the
# horizon ----> horizon
# . ----> .
# Our ----> Our
# forefathers ----> forefather
# came ----> come
# to ----> to
# our ----> our
# rugged ----> rugged
# shores ----> shore
# in ----> in
# search ----> search
# of ----> of
# religious ----> religious
# tolerance ----> tolerance
# , ----> ,
# political ----> political
# freedom ----> freedom
# and ----> and
# economic ----> economic
# opportunity ----> opportunity
# . ----> .
# For ----> For
# those ----> those
# fundamental ----> fundamental
# rights ----> right
# , ----> ,
# they ----> they
# risked ----> risk
# their ----> their
# lives ----> life
# . ----> .
# We ----> We
# well ----> well
# know ----> know
# today ----> today
# that ----> that
# such ----> such
# rights ----> right
# can ----> can
# be ----> be
# preserved ----> preserve
# only ----> only
# by ----> by
# constant ----> constant
# vigilance ----> vigilance
# , ----> ,
# the ----> the
# eternal ----> eternal
# price ----> price
# of ----> of
# liberty ----> liberty
# ! ----> !
# Within ----> Within
# an ----> an
# hour ----> hour
# after ----> after
# I ----> I
# took ----> take
# the ----> the
# oath ----> oath
# of ----> of
# office ----> office
# , ----> ,
# I ----> I
# announced ----> announce
# that ----> that
# the ----> the
# San ----> San
# Francisco ----> Francisco
# Conference ----> Conference
# would ----> would
# proceed ----> proceed
# . ----> .
# We ----> We
# will ----> will
# face ----> face
# the ----> the
# problems ----> problem
# of ----> of
# peace ----> peace
# with ----> with
# the ----> the
# same ----> same
# courage ----> courage
# that ----> that
# we ----> we
# have ----> have
# faced ----> face
# and ----> and
# mastered ----> master
# the ----> the
# problems ----> problem
# of ----> of
# war ----> war
# . ----> .
# In ----> In
# the ----> the
# memory ----> memory
# of ----> of
# those ----> those
# who ----> who
# have ----> have
# made ----> make
# the ----> the
# supreme ----> supreme
# sacrifice-in ----> sacrifice-in
# the ----> the
# memory ----> memory
# of ----> of
# our ----> our
# fallen ----> fall
# President-we ----> President-we
# shall ----> shall
# not ----> not
# fail ----> fail
# ! ----> !
# It ----> It
# is ----> be
# not ----> not
# enough ----> enough
# to ----> to
# yearn ----> yearn
# for ----> for
# peace ----> peace
# . ----> .
# We ----> We
# must ----> must
# work ----> work
# , ----> ,
# and ----> and
# if ----> if
# necessary ----> necessary
# , ----> ,
# fight ----> fight
# for ----> for
# it ----> it
# . ----> .
# The ----> The
# task ----> task
# of ----> of
# creating ----> create
# a ----> a
# sound ----> sound
# international ----> international
# organization ----> organization
# is ----> be
# complicated ----> complicate
# and ----> and
# difficult ----> difficult
# . ----> .
# Yet ----> Yet
# , ----> ,
# without ----> without
# such ----> such
# organization ----> organization
# , ----> ,
# the ----> the
# rights ----> right
# of ----> of
# man ----> man
# on ----> on
# earth ----> earth
# can ----> can
# not ----> not
# be ----> be
# protected ----> protect
# . ----> .
# Machi ----> Machi
# nery ----> nery
# for ----> for
# the ----> the
# just ----> just
# settlement ----> settlement
# of ----> of
# international ----> international
# differences ----> difference
# must ----> must
# be ----> be
# found ----> find
# . ----> .
# Without ----> Without
# such ----> such
# machinery ----> machinery
# , ----> ,
# the ----> the
# entire ----> entire
# world ----> world
# will ----> will
# have ----> have
# to ----> to
# remain ----> remain
# an ----> an
# armed ----> armed
# camp ----> camp
# . ----> .
# The ----> The
# world ----> world
# will ----> will
# be ----> be
# doomed ----> doom
# to ----> to
# deadly ----> deadly
# conflict ----> conflict
# , ----> ,
# devoid ----> devoid
# of ----> of
# hope ----> hope
# for ----> for
# real ----> real
# peace ----> peace
# . ----> .
# Fortunately ----> Fortunately
# , ----> ,
# people ----> people
# have ----> have
# retained ----> retain
# hope ----> hope
# for ----> for
# a ----> a
# durable ----> durable
# peace ----> peace
# . ----> .
# Thoughtful ----> Thoughtful
# people ----> people
# have ----> have
# always ----> always
# had ----> have
# faith ----> faith
# that ----> that
# ultimately ----> ultimately
# justice ----> justice
# must ----> must
# triumph ----> triumph
# . ----> .
# Past ----> Past
# experience ----> experience
# surely ----> surely
# indicates ----> indicate
# that ----> that
# , ----> ,
# without ----> without
# justice ----> justice
# , ----> ,
# an ----> an
# enduring ----> endure
# peace ----> peace
# becomes ----> become
# impossible ----> impossible
# . ----> .
# In ----> In
# bitter ----> bitter
# despair ----> despair
# , ----> ,
# some ----> some
# people ----> people
# have ----> have
# come ----> come
# to ----> to
# believe ----> believe
# that ----> that
# wars ----> war
# are ----> be
# inevitable ----> inevitable
# . ----> .
# With ----> With
# tragic ----> tragic
# fatalism ----> fatalism
# , ----> ,
# they ----> they
# insist ----> insist
# that ----> that
# wars ----> war
# have ----> have
# always ----> always
# been ----> be
# , ----> ,
# of ----> of
# necessity ----> necessity
# , ----> ,
# and ----> and
# of ----> of
# necessity ----> necessity
# wars ----> war
# always ----> always
# will ----> will
# be ----> be
# . ----> .
# To ----> To
# such ----> such
# defeatism ----> defeatism
# , ----> ,
# men ----> men
# and ----> and
# women ----> woman
# of ----> of
# good ----> good
# will ----> will
# must ----> must
# not ----> not
# and ----> and
# can ----> can
# not ----> not
# yield ----> yield
# . ----> .
# The ----> The
# outlook ----> outlook
# for ----> for
# humanity ----> humanity
# is ----> be
# not ----> not
# so ----> so
# hopeless ----> hopeless
# . ----> .
# During ----> During
# the ----> the
# dark ----> dark
# hours ----> hour
# of ----> of
# this ----> this
# horrible ----> horrible
# war ----> war
# , ----> ,
# entire ----> entire
# nations ----> nation
# were ----> be
# kept ----> keep
# going ----> go
# by ----> by
# something ----> something
# intangible-hope ----> intangible-hope
# ! ----> !
# When ----> When
# warned ----> warn
# that ----> that
# abject ----> abject
# submission ----> submission
# offered ----> offer
# the ----> the
# only ----> only
# salvation ----> salvation
# against ----> against
# overwhelming ----> overwhelm
# power ----> power
# , ----> ,
# hope ----> hope
# showed ----> show
# the ----> the
# way ----> way
# to ----> to
# victory ----> victory
# . ----> .
# Hope ----> Hope
# has ----> have
# become ----> become
# the ----> the
# secret ----> secret
# weapon ----> weapon
# of ----> of
# the ----> the
# forces ----> force
# of ----> of
# liberation ----> liberation
# ! ----> !
# Aggressors ----> Aggressors
# could ----> could
# not ----> not
# dominate ----> dominate
# the ----> the
# human ----> human
# mind ----> mind
# . ----> .
# As ----> As
# long ----> long
# as ----> a
# hope ----> hope
# remains ----> remain
# , ----> ,
# the ----> the
# spirit ----> spirit
# of ----> of
# man ----> man
# will ----> will
# never ----> never
# be ----> be
# crushed ----> crush
# . ----> .
# But ----> But
# hope ----> hope
# alone ----> alone
# was ----> be
# not ----> not
# and ----> and
# is ----> be
# not ----> not
# sufficient ----> sufficient
# to ----> to
# avert ----> avert
# war ----> war
# . ----> .
# We ----> We
# must ----> must
# not ----> not
# only ----> only
# have ----> have
# hope ----> hope
# but ----> but
# we ----> we
# must ----> must
# have ----> have
# faith ----> faith
# enough ----> enough
# to ----> to
# work ----> work
# with ----> with
# other ----> other
# peace-loving ----> peace-loving
# nations ----> nation
# to ----> to
# maintain ----> maintain
# the ----> the
# peace ----> peace
# . ----> .
# Hope ----> Hope
# was ----> be
# not ----> not
# enough ----> enough
# to ----> to
# beat ----> beat
# back ----> back
# the ----> the
# aggressors ----> aggressor
# as ----> as
# long ----> long
# as ----> a
# the ----> the
# peace-loving ----> peace-loving
# nations ----> nation
# were ----> be
# unwilling ----> unwilling
# to ----> to
# come ----> come
# to ----> to
# each ----> each
# other ----> other
# 's ----> 's
# defense ----> defense
# . ----> .
# The ----> The
# aggressors ----> aggressor
# were ----> be
# beaten ----> beat
# back ----> back
# only ----> only
# when ----> when
# the ----> the
# peace-loving ----> peace-loving
# nations ----> nation
# united ----> unite
# to ----> to
# defend ----> defend
# themselves ----> themselves
# . ----> .
# If ----> If
# wars ----> war
# in ----> in
# the ----> the
# future ----> future
# are ----> be
# to ----> to
# be ----> be
# prevented ----> prevent
# the ----> the
# nations ----> nation
# must ----> must
# be ----> be
# united ----> unite
# in ----> in
# their ----> their
# determination ----> determination
# to ----> to
# keep ----> keep
# the ----> the
# peace ----> peace
# under ----> under
# law ----> law
# . ----> .
# Nothing ----> Nothing
# is ----> be
# more ----> more
# essential ----> essential
# to ----> to
# the ----> the
# future ----> future
# peace ----> peace
# of ----> of
# the ----> the
# world ----> world
# than ----> than
# continued ----> continued
# cooperation ----> cooperation
# of ----> of
# the ----> the
# nations ----> nation
# which ----> which
# had ----> have
# to ----> to
# muster ----> muster
# the ----> the
# force ----> force
# necessary ----> necessary
# to ----> to
# defeat ----> defeat
# the ----> the
# conspiracy ----> conspiracy
# of ----> of
# the ----> the
# Axis ----> Axis
# powers ----> power
# to ----> to
# dominate ----> dominate
# the ----> the
# world ----> world
# . ----> .
# While ----> While
# these ----> these
# great ----> great
# states ----> state
# have ----> have
# a ----> a
# special ----> special
# responsibility ----> responsibility
# to ----> to
# enforce ----> enforce
# the ----> the
# peace ----> peace
# , ----> ,
# their ----> their
# responsibility ----> responsibility
# is ----> be
# based ----> base
# upon ----> upon
# the ----> the
# obligations ----> obligation
# resting ----> rest
# upon ----> upon
# all ----> all
# states ----> state
# , ----> ,
# large ----> large
# and ----> and
# small ----> small
# , ----> ,
# not ----> not
# to ----> to
# use ----> use
# force ----> force
# in ----> in
# international ----> international
# relations ----> relation
# except ----> except
# in ----> in
# the ----> the
# defense ----> defense
# of ----> of
# law ----> law
# . ----> .
# The ----> The
# respon ----> respon
# sibility ----> sibility
# of ----> of
# the ----> the
# great ----> great
# states ----> state
# is ----> be
# to ----> to
# serve ----> serve
# and ----> and
# not ----> not
# to ----> to
# dominate ----> dominate
# the ----> the
# world ----> world
# . ----> .
# To ----> To
# build ----> build
# a ----> a
# foundation ----> foundation
# of ----> of
# enduring ----> endure
# peace ----> peace
# we ----> we
# must ----> must
# not ----> not
# only ----> only
# work ----> work
# in ----> in
# harmony ----> harmony
# with ----> with
# our ----> our
# friends ----> friend
# abroad ----> abroad
# , ----> ,
# but ----> but
# we ----> we
# must ----> must
# have ----> have
# the ----> the
# united ----> united
# support ----> support
# of ----> of
# our ----> our
# own ----> own
# people ----> people
# . ----> .
# Even ----> Even
# the ----> the
# most ----> most
# experienced ----> experienced
# pilot ----> pilot
# can ----> can
# not ----> not
# bring ----> bring
# a ----> a
# ship ----> ship
# safely ----> safely
# into ----> into
# harbor ----> harbor
# , ----> ,
# unless ----> unless
# he ----> he
# has ----> have
# the ----> the
# full ----> full
# cooperation ----> cooperation
# of ----> of
# the ----> the
# crew ----> crew
# . ----> .
# For ----> For
# the ----> the
# benefit ----> benefit
# of ----> of
# all ----> all
# , ----> ,
# every ----> every
# individual ----> individual
# must ----> must
# do ----> do
# his ----> his
# duty ----> duty
# . ----> .
# I ----> I
# appeal ----> appeal
# to ----> to
# every ----> every
# American ----> American
# , ----> ,
# regardless ----> regardless
# of ----> of
# party ----> party
# , ----> ,
# race ----> race
# , ----> ,
# creed ----> creed
# , ----> ,
# or ----> or
# color ----> color
# , ----> ,
# to ----> to
# support ----> support
# our ----> our
# efforts ----> effort
# to ----> to
# build ----> build
# a ----> a
# strong ----> strong
# and ----> and
# lasting ----> lasting
# United ----> United
# Nations ----> Nations
# Organization ----> Organization
# . ----> .
# You ----> You
# , ----> ,
# the ----> the
# Members ----> Members
# of ----> of
# the ----> the
# Congress ----> Congress
# , ----> ,
# surely ----> surely
# know ----> know
# how ----> how
# I ----> I
# feel ----> feel
# . ----> .
# Only ----> Only
# with ----> with
# your ----> your
# help ----> help
# can ----> can
# I ----> I
# hope ----> hope
# to ----> to
# complete ----> complete
# one ----> one
# of ----> of
# the ----> the
# greatest ----> great
# tasks ----> task
# ever ----> ever
# assigned ----> assign
# to ----> to
# a ----> a
# public ----> public
# servant ----> servant
# . ----> .
# With ----> With
# Divine ----> Divine
# guidance ----> guidance
# , ----> ,
# and ----> and
# your ----> your
# help ----> help
# , ----> ,
# we ----> we
# will ----> will
# find ----> find
# the ----> the
# new ----> new
# passage ----> passage
# to ----> to
# a ----> a
# far ----> far
# better ----> good
# world ----> world
# , ----> ,
# a ----> a
# kindly ----> kindly
# and ----> and
# friendly ----> friendly
# world ----> world
# , ----> ,
# with ----> with
# just ----> just
# and ----> and
# lasting ----> lasting
# peace ----> peace
# . ----> .
# With ----> With
# confidence ----> confidence
# , ----> ,
# I ----> I
# am ----> be
# depending ----> depend
# upon ----> upon
# all ----> all
# of ----> of
# you ----> you
# . ----> .
# To ----> To
# destroy ----> destroy
# greedy ----> greedy
# tyrants ----> tyrant
# with ----> with
# dreams ----> dream
# of ----> of
# world ----> world
# domination ----> domination
# , ----> ,
# we ----> we
# can ----> can
# not ----> not
# continue ----> continue
# in ----> in
# successive ----> successive
# generations ----> generation
# to ----> to
# sacrifice ----> sacrifice
# our ----> our
# finest ----> fine
# youth ----> youth
# . ----> .
# In ----> In
# the ----> the
# name ----> name
# of ----> of
# human ----> human
# decency ----> decency
# and ----> and
# civilization ----> civilization
# , ----> ,
# a ----> a
# more ----> more
# rational ----> rational
# method ----> method
# of ----> of
# deciding ----> decide
# national ----> national
# differences ----> difference
# must ----> must
# and ----> and
# will ----> will
# be ----> be
# found ----> find
# ! ----> !
# America ----> America
# must ----> must
# assist ----> assist
# suffering ----> suffer
# humanity ----> humanity
# back ----> back
# along ----> along
# the ----> the
# path ----> path
# of ----> of
# peaceful ----> peaceful
# progress ----> progress
# . ----> .
# This ----> This
# will ----> will
# require ----> require
# time ----> time
# and ----> and
# tolerance ----> tolerance
# . ----> .
# We ----> We
# shall ----> shall
# need ----> need
# also ----> also
# an ----> an
# abiding ----> abide
# faith ----> faith
# in ----> in
# the ----> the
# people ----> people
# , ----> ,
# the ----> the
# kind ----> kind
# of ----> of
# faith ----> faith
# and ----> and
# courage ----> courage
# which ----> which
# Franklin ----> Franklin
# Delano ----> Delano
# Roosevelt ----> Roosevelt
# always ----> always
# had ----> have
# ! ----> !
# Today ----> Today
# , ----> ,
# America ----> America
# has ----> have
# become ----> become
# one ----> one
# of ----> of
# the ----> the
# most ----> most
# powerful ----> powerful
# forces ----> force
# for ----> for
# good ----> good
# on ----> on
# earth ----> earth
# . ----> .
# We ----> We
# must ----> must
# keep ----> keep
# it ----> it
# so ----> so
# . ----> .
# We ----> We
# have ----> have
# achieved ----> achieve
# a ----> a
# world ----> world
# leadership ----> leadership
# which ----> which
# does ----> do
# not ----> not
# depend ----> depend
# solely ----> solely
# upon ----> upon
# our ----> our
# military ----> military
# and ----> and
# naval ----> naval
# might ----> might
# . ----> .
# We ----> We
# have ----> have
# learned ----> learn
# to ----> to
# fight ----> fight
# with ----> with
# other ----> other
# nations ----> nation
# in ----> in
# common ----> common
# defense ----> defense
# of ----> of
# our ----> our
# freedom ----> freedom
# . ----> .
# We ----> We
# must ----> must
# now ----> now
# learn ----> learn
# to ----> to
# live ----> live
# with ----> with
# other ----> other
# nations ----> nation
# for ----> for
# our ----> our
# mutual ----> mutual
# good ----> good
# . ----> .
# We ----> We
# must ----> must
# learn ----> learn
# to ----> to
# trade ----> trade
# more ----> more
# with ----> with
# other ----> other
# nations ----> nation
# so ----> so
# that ----> that
# there ----> there
# may ----> may
# be-for ----> be-for
# our ----> our
# mutual ----> mutual
# advantage-increased ----> advantage-increased
# product ----> product
# ion ----> ion
# , ----> ,
# increased ----> increased
# employment ----> employment
# and ----> and
# better ----> good
# standards ----> standard
# of ----> of
# living ----> living
# throughout ----> throughout
# the ----> the
# world ----> world
# . ----> .
# May ----> May
# we ----> we
# Americans ----> Americans
# all ----> all
# live ----> live
# up ----> up
# to ----> to
# our ----> our
# glorious ----> glorious
# heritage ----> heritage
# . ----> .
# In ----> In
# that ----> that
# way ----> way
# , ----> ,
# America ----> America
# may ----> may
# well ----> well
# lead ----> lead
# the ----> the
# world ----> world
# to ----> to
# peace ----> peace
# and ----> and
# prosperity ----> prosperity
# . ----> .
# At ----> At
# this ----> this
# moment ----> moment
# , ----> ,
# I ----> I
# have ----> have
# in ----> in
# my ----> my
# heart ----> heart
# a ----> a
# prayer ----> prayer
# . ----> .
# As ----> As
# I ----> I
# have ----> have
# assumed ----> assume
# my ----> my
# heavy ----> heavy
# duties ----> duty
# , ----> ,
# I ----> I
# humbly ----> humbly
# pray ----> pray
# Almighty ----> Almighty
# God ----> God
# , ----> ,
# in ----> in
# the ----> the
# words ----> word
# of ----> of
# King ----> King
# Solomon ----> Solomon
# : ----> :
# '' ----> ''
# Give ----> Give
# therefore ----> therefore
# thy ----> thy
# servant ----> servant
# an ----> an
# understanding ----> understanding
# heart ----> heart
# to ----> to
# judge ----> judge
# thy ----> thy
# people ----> people
# , ----> ,
# that ----> that
# I ----> I
# may ----> may
# discern ----> discern
# between ----> between
# good ----> good
# and ----> and
# bad ----> bad
# ; ----> ;
# for ----> for
# who ----> who
# is ----> be
# able ----> able
# to ----> to
# judge ----> judge
# this ----> this
# thy ----> thy
# so ----> so
# great ----> great
# a ----> a
# people ----> people
# ? ----> ?
# '' ----> ''
# I ----> I
# ask ----> ask
# only ----> only
# to ----> to
# be ----> be
# a ----> a
# good ----> good
# and ----> and
# faithful ----> faithful
# servant ----> servant
# of ----> of
# my ----> my
# Lord ----> Lord
# and ----> and
# my ----> my
# people ----> people
# . ----> .

# %% [markdown]
# # From Words to Subwords: Byte Pair Encoding (BPE)

# %% [markdown]
# So far, we have treated words as the basic unit of meaning.
# Modern NLP systems often go one step further and operate on subword units.
#
# One of the most common subword tokenization methods is Byte Pair Encoding (BPE).

# %% [markdown]
# In large corpora like the State of the Union addresses, word-level tokenization creates several problems:
#
# Rare words appear very infrequently
#
# New words appear over time (e.g. cybersecurity, biotechnology)
#
# Related words are treated as completely separate tokens
#
# Subword tokenization solves this by breaking words into frequently occurring pieces.

# %%
# We will use a small subset of real policy-related words that appear in State of the Union speeches.

words = [
    "democracy",
    "democratic",
    "democratization",
    "economy",
    "economic",
    "economics"
]

words
# At the word level, all of these are treated as separate tokens.
# Out:
# ['democracy',
#  'democratic',
#  'democratization',
#  'economy',
#  'economic',
#  'economics']

# %% [markdown]
# ## Step 1 – Character-Level Representation

# %% [markdown]
# BPE starts by representing each word as a sequence of characters
# (with a special end-of-word marker).

# %%
char_tokens = [list(word) + ["</w>"] for word in words]
char_tokens
# Out:
# [['d', 'e', 'm', 'o', 'c', 'r', 'a', 'c', 'y', '</w>'],
#  ['d', 'e', 'm', 'o', 'c', 'r', 'a', 't', 'i', 'c', '</w>'],
#  ['d',
#   'e',
#   'm',
#   'o',
#   'c',
#   'r',
#   'a',
#   't',
#   'i',
#   'z',
#   'a',
#   't',
#   'i',
#   'o',
#   'n',
#   '</w>'],
#  ['e', 'c', 'o', 'n', 'o', 'm', 'y', '</w>'],
#  ['e', 'c', 'o', 'n', 'o', 'm', 'i', 'c', '</w>'],
#  ['e', 'c', 'o', 'n', 'o', 'm', 'i', 'c', 's', '</w>']]

# %% [markdown]
# ## Step 2 – Count Frequent Character Pairs

# %% [markdown]
# BPE repeatedly merges the most frequent adjacent character pairs across the corpus.

# %%
from collections import Counter

pair_counts = Counter()

for word in char_tokens:
    for i in range(len(word) - 1):
        pair = (word[i], word[i+1])
        pair_counts[pair] += 1

pair_counts.most_common(10)
# Out:
# [(('o', 'n'), 4),
#  (('d', 'e'), 3),
#  (('e', 'm'), 3),
#  (('m', 'o'), 3),
#  (('o', 'c'), 3),
#  (('c', 'r'), 3),
#  (('r', 'a'), 3),
#  (('a', 't'), 3),
#  (('t', 'i'), 3),
#  (('i', 'c'), 3)]

# %% [markdown]
# ## Step 3 – Merge Frequent Pairs (Conceptual)

# %% [markdown]
# The most frequent pair is ('o', 'n').
# BPE merges it into a new token: "on".
#
# This process repeats many times, gradually forming meaningful subwords.

# %%
bpe_tokens_example = [
    ["democr", "acy</w>"],
    ["democr", "atic</w>"],
    ["democr", "atization</w>"],
    ["econ", "omy</w>"],
    ["econ", "omic</w>"],
    ["econ", "omics</w>"]
]

bpe_tokens_example
# Out:
# [['democr', 'acy</w>'],
#  ['democr', 'atic</w>'],
#  ['democr', 'atization</w>'],
#  ['econ', 'omy</w>'],
#  ['econ', 'omic</w>'],
#  ['econ', 'omics</w>']]
