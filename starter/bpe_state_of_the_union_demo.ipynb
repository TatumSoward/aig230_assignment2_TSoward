# %% [markdown]
# # AIG 230 – BPE Demo Notebook
# ## Byte Pair Encoding (BPE) with the State of the Union Corpus
#
# **Purpose of this notebook**
# This notebook demonstrates, end-to-end, how **Byte Pair Encoding (BPE)** works using a *real corpus*: the U.S. State of the Union addresses.
#
# This notebook is intentionally simple and conceptual. It exists to build correct mental models about subword tokenization.

# %% [markdown]
# ## 1. Setup
#
# We use:
# - NLTK to access the State of the Union corpus
# - Hugging Face `tokenizers` to train a simple BPE tokenizer

# %%
# Install if needed
# !pip install nltk tokenizers

import nltk
from nltk.corpus import state_union

nltk.download("state_union")
# Out:
# Requirement already satisfied: nltk in c:\users\sowar\anaconda3\lib\site-packages (3.9.2)
# Collecting tokenizers
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: click in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\sowar\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers)
#   Downloading huggingface_hub-1.3.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.10.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (1.0.9)
# Requirement already satisfied: idna in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sowar\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (0.16.0)
# Requirement already satisfied: colorama in c:\users\sowar\anaconda3\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sowar\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (1.3.0)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 3.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.5 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.4 MB/s  0:00:00
# Downloading huggingface_hub-1.3.3-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    ---------------------------------------- 536.6/536.6 kB 2.7 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 3.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.1/2.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 3.5 MB/s  0:00:00
# Installing collected packages: hf-xet, huggingface-hub, tokenizers
#
#    ---------------------------------------- 0/3 [hf-xet]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    -------------------------- ------------- 2/3 [tokenizers]
#    -------------------------- ------------- 2/3 [tokenizers]
#    ---------------------------------------- 3/3 [tokenizers]
#
# Successfully installed hf-xet-1.2.0 huggingface-hub-1.3.3 tokenizers-0.22.2
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\sowar\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# True

# %% [markdown]
# ## 2. Load and Inspect the Corpus

# %%
fileids = state_union.fileids()
len(fileids), fileids[:5]
# Out:
# (65,
#  ['1945-Truman.txt',
#   '1946-Truman.txt',
#   '1947-Truman.txt',
#   '1948-Truman.txt',
#   '1949-Truman.txt'])

# %%
texts = [state_union.raw(fid) for fid in fileids[:10]]
corpus_text = "\n".join(texts)

corpus_text[:500]
# Out:
# "PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.\nOnly yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.\nYet, in this decisive hour, when worl"

# %% [markdown]
# ## 3. Why BPE?
#
# BPE learns **subword units** from data instead of relying on predefined words.

# %% [markdown]
# ## 4. Train a Simple BPE Tokenizer

# %%
# !pip install tokenizers
# Out:
# Requirement already satisfied: tokenizers in c:\users\sowar\anaconda3\lib\site-packages (0.22.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\sowar\anaconda3\lib\site-packages (from tokenizers) (1.3.3)
# Requirement already satisfied: filelock in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sowar\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (1.0.9)
# Requirement already satisfied: idna in c:\users\sowar\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sowar\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (0.16.0)
# Requirement already satisfied: colorama in c:\users\sowar\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sowar\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\sowar\anaconda3\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers) (8.2.1)

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()

trainer = BpeTrainer(
    vocab_size=200,
    special_tokens=["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]"]
)

tokenizer.train_from_iterator([corpus_text], trainer=trainer)

# %% [markdown]
# ## 5. Inspect the Learned Vocabulary

# %%
vocab = tokenizer.get_vocab()
list(vocab.items())[:30]
# Out:
# [('se', 125),
#  ('ations', 188),
#  ('am', 153),
#  ("'", 9),
#  ('T', 48),
#  ('x', 79),
#  ('ter', 182),
#  ('f', 61),
#  ('and', 101),
#  ('de', 122),
#  ('res', 121),
#  ('D', 32),
#  ('ol', 135),
#  ('ong', 183),
#  ('0', 16),
#  ('ha', 146),
#  ('at', 90),
#  ('the', 88),
#  ('ow', 143),
#  ('O', 43),
#  ('k', 66),
#  ('sh', 150),
#  ('ex', 139),
#  ('we', 130),
#  ('[CLS]', 2),
#  ('(', 10),
#  ('al', 95),
#  ('em', 181),
#  ('[MASK]', 4),
#  ('as', 113)]

# %% [markdown]
# ## 6. BPE Tokenization Example

# %%
sentence = "Democracy and democratic institutions must be protected."
tokenizer.encode(sentence).tokens
# Out:
# ['D',
#  'e',
#  'mo',
#  'c',
#  'r',
#  'ac',
#  'y',
#  'and',
#  'de',
#  'mo',
#  'c',
#  'r',
#  'at',
#  'ic',
#  'in',
#  'st',
#  'it',
#  'u',
#  'tion',
#  's',
#  'm',
#  'ust',
#  'be',
#  'pro',
#  't',
#  'ec',
#  't',
#  'ed',
#  '.']

# %% [markdown]
# ## 7. Key Takeaways
#
# - BPE tokenization is **learned from data**
# - It captures shared structure across related words
# - It is used by modern language models
# - It is intentionally outside NLTK and spaCy
